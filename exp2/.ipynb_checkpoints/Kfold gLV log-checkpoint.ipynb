# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy.stats import norm, linregress

import os
import time
import itertools

from glove.log_model import *

from sklearn.model_selection import KFold
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# import file names
files = os.listdir("data/")
files = [f for f in files if "processed" in f]
files = files[:1]
files
# Out:
# ['EXP0019_MS001_processed.csv']

# %% [markdown]
# # fit gLV models

# %%
def predict(df, species):
    
    # save measured and predicted values
    pred_species = []
    pred = []
    stdv = []
    true = []

    # pull just the community data
    test_data = process_df(df, species) 

    # plot the results
    for exp, t_span, Y_m, s_present in test_data:

        # increase evaluation time
        t_eval = np.linspace(t_span[0], t_span[-1])

        # predict 
        Y_p, Y_l, _ = model.predict(Y_m, t_eval, log=True)
        Y_std = Y_p - Y_l
        
        # set NaN to zero
        Y_p = np.nan_to_num(Y_p)
        Y_std = np.nan_to_num(Y_std)
        
        # unscale log 
        Y_m = np.einsum("ij,j->ij", np.exp(Y_m), s_present)

        ### append only end-point prediction results after initial condition! ###
        inds_pos = Y_m[-1,:] > 0 
        pred_species.append(np.array(species)[inds_pos])
        true.append(Y_m[-1,:][inds_pos])
        pred.append(Y_p[-1,:][inds_pos])
        stdv.append(Y_std[-1,:][inds_pos])
        
    # concatenate list
    pred_species = np.concatenate(pred_species)
    true = np.concatenate(true)
    pred = np.concatenate(pred)
    stdv = np.concatenate(stdv)
        
    return pred_species, true, pred, stdv

# %%
# run kfold for each file 
for file in files:
    
    # import data
    df = pd.read_csv(f"data/{file}")

    # determine species names 
    species = df.columns.values[2:]

    # separate mono culture data 
    # mono_df = pd.concat([df_i for name, df_i in df.groupby("Treatments") if "Mono" in name])
    dfs = [df_i for name, df_i in df.groupby("Treatments") if "Mono" not in name]

    # init kfold object
    kf = KFold(n_splits=20, shuffle=True, random_state=21)

    # keep track of all predictions
    all_pred_species = []
    all_true = []
    all_pred = []
    all_stdv = []

    # run Kfold 
    for train_index, test_index in kf.split(dfs):
        # get train df 
        train_df = pd.concat([dfs[i] for i in train_index])
        # train_df = pd.concat((mono_df, train_df))

        # get test df
        test_df = pd.concat([dfs[i] for i in test_index])

        # instantiate gLV fit 
        model = gLV(species, train_df) 

        # fit to data 
        model.fit()

        # plot fitness to data
        pred_species, true, pred, stdv = predict(test_df, species)

        # append predictions 
        all_pred_species = np.append(all_pred_species, pred_species)
        all_true = np.append(all_true, true)
        all_pred = np.append(all_pred, pred)
        all_stdv = np.append(all_stdv, stdv)

    # save prediction results to a .csv
    strain = file.split("_")[1]
    kfold_df = pd.DataFrame()
    kfold_df['species'] = all_pred_species
    kfold_df['true'] = all_true
    kfold_df['pred'] = all_pred
    kfold_df['stdv'] = all_stdv
    kfold_df.to_csv(f"kfold/{strain}_kfold_log.csv", index=False)
        
    # show prediction performance of individual species
    for sp in species:
        sp_inds = all_pred_species == sp
        R = linregress(all_true[sp_inds], all_pred[sp_inds]).rvalue
        plt.scatter(all_true[sp_inds], all_pred[sp_inds], label=f"{sp} " + "R={:.3f}".format(R))
        plt.errorbar(all_true[sp_inds], all_pred[sp_inds], yerr=all_stdv[sp_inds], 
                     fmt='.', capsize=3)

    plt.xlabel("Measured OD")
    plt.ylabel("Predicted OD")
    plt.legend()
    plt.title(strain)
    plt.savefig(f"kfold/{strain}_kfold_log.pdf", dpi=300)
    plt.show()
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Total samples: 100, Updated regularization: 1.00e-05
# Total weighted fitting error: 410.838
# Total weighted fitting error: 308.875
# Total weighted fitting error: 271.141
# Total weighted fitting error: 247.717
# Total weighted fitting error: 194.458
# Total weighted fitting error: 181.162
# Total weighted fitting error: 177.343
# Total weighted fitting error: 170.099
# Total weighted fitting error: 157.177
# Total weighted fitting error: 142.462
# Total weighted fitting error: 137.660
# Total weighted fitting error: 128.928
# Total weighted fitting error: 121.618
# Total weighted fitting error: 120.840
# Total weighted fitting error: 114.334
# Total weighted fitting error: 111.436
# Total weighted fitting error: 111.329
# Total weighted fitting error: 107.368
# Total weighted fitting error: 101.672
# Total weighted fitting error: 101.430
# Total weighted fitting error: 99.204
# Total weighted fitting error: 95.390
# Total weighted fitting error: 95.028
# Total weighted fitting error: 92.085
# Total weighted fitting error: 92.030
# Total weighted fitting error: 91.927
# Total weighted fitting error: 91.737
# Total weighted fitting error: 90.044
# Total weighted fitting error: 89.991
# Total weighted fitting error: 89.533
# Total weighted fitting error: 88.667
# Total weighted fitting error: 88.372
# Total weighted fitting error: 86.016
# Total weighted fitting error: 85.983
# Total weighted fitting error: 85.929
# Total weighted fitting error: 85.871
# Total weighted fitting error: 83.908
# Total weighted fitting error: 83.896
# Total weighted fitting error: 83.877
# Total weighted fitting error: 83.700
# Total weighted fitting error: 83.379
# Total weighted fitting error: 82.792
# Total weighted fitting error: 82.653
# Total weighted fitting error: 81.478
# Total weighted fitting error: 81.468
# Total weighted fitting error: 81.081
# Total weighted fitting error: 80.977
# Total weighted fitting error: 80.783
# Total weighted fitting error: 80.429
# Total weighted fitting error: 80.422
# Total weighted fitting error: 80.367
# Total weighted fitting error: 79.854
# Total weighted fitting error: 79.001
# Total weighted fitting error: 78.896
# Total weighted fitting error: 78.889
# Total weighted fitting error: 77.957
# Total weighted fitting error: 77.948
# Total weighted fitting error: 77.637
# Total weighted fitting error: 77.633
# Total weighted fitting error: 77.117
# Total weighted fitting error: 76.991
# Total weighted fitting error: 76.751
# Total weighted fitting error: 76.748
# Total weighted fitting error: 75.602
# Total weighted fitting error: 75.542
# Total weighted fitting error: 75.436
# Total weighted fitting error: 75.281
# Total weighted fitting error: 75.170
# Total weighted fitting error: 74.968
# Total weighted fitting error: 74.960
# Total weighted fitting error: 74.631
# Total weighted fitting error: 74.624
# Total weighted fitting error: 74.329
# Total weighted fitting error: 74.327
# Total weighted fitting error: 74.232
# Total weighted fitting error: 74.056
# Total weighted fitting error: 74.055
# Total weighted fitting error: 74.042
# Total weighted fitting error: 73.537
# Total weighted fitting error: 73.529
# Total weighted fitting error: 73.514
# Total weighted fitting error: 72.938
# Total weighted fitting error: 72.936
# Total weighted fitting error: 72.920
# Total weighted fitting error: 72.780
# Total weighted fitting error: 72.776
# Total weighted fitting error: 72.193
# Total weighted fitting error: 72.191
# Total weighted fitting error: 72.177
# Total weighted fitting error: 72.051
# Total weighted fitting error: 72.049
# Total weighted fitting error: 71.733
# Total weighted fitting error: 71.731
# Total weighted fitting error: 71.622
# Total weighted fitting error: 71.621
# Total weighted fitting error: 71.504
# Total weighted fitting error: 71.476
# Total weighted fitting error: 70.539
# Total weighted fitting error: 70.527
# Total weighted fitting error: 70.521
# Total weighted fitting error: 70.516
# Total weighted fitting error: 70.311
# Total weighted fitting error: 70.305
# Total weighted fitting error: 70.048
# Total weighted fitting error: 70.047
# Total weighted fitting error: 69.837
# Total weighted fitting error: 69.793
# Total weighted fitting error: 69.785
# Total weighted fitting error: 69.723
# Total weighted fitting error: 69.723
# Total weighted fitting error: 69.299
# Total weighted fitting error: 69.298
# Evidence -549.655
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 2.66e-02
# Total weighted fitting error: 254.031
# Total weighted fitting error: 253.096
# Total weighted fitting error: 252.479
# Total weighted fitting error: 252.207
# Total weighted fitting error: 251.735
# Total weighted fitting error: 251.065
# Total weighted fitting error: 250.137
# Total weighted fitting error: 250.090
# Total weighted fitting error: 248.504
# Total weighted fitting error: 248.478
# Total weighted fitting error: 248.442
# Total weighted fitting error: 248.423
# Total weighted fitting error: 247.762
# Total weighted fitting error: 247.758
# Evidence 134.799
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 5.32e-02
# Total weighted fitting error: 368.945
# Total weighted fitting error: 367.876
# Total weighted fitting error: 367.605
# Total weighted fitting error: 367.123
# Total weighted fitting error: 366.344
# Total weighted fitting error: 366.282
# Total weighted fitting error: 364.101
# Total weighted fitting error: 364.084
# Total weighted fitting error: 363.541
# Total weighted fitting error: 363.539
# Total weighted fitting error: 362.296
# Total weighted fitting error: 362.287
# Evidence 213.457
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 5.79e-02
# Total weighted fitting error: 392.606
# Total weighted fitting error: 392.237
# Total weighted fitting error: 391.635
# Total weighted fitting error: 391.622
# Total weighted fitting error: 391.087
# Total weighted fitting error: 390.367
# Total weighted fitting error: 390.363
# Total weighted fitting error: 389.759
# Total weighted fitting error: 389.752
# Total weighted fitting error: 388.680
# Total weighted fitting error: 388.675
# Evidence 227.437
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 5.97e-02
# Total weighted fitting error: 397.260
# Total weighted fitting error: 397.135
# Total weighted fitting error: 396.910
# Total weighted fitting error: 396.527
# Total weighted fitting error: 396.514
# Total weighted fitting error: 396.032
# Total weighted fitting error: 396.000
# Total weighted fitting error: 394.794
# Total weighted fitting error: 394.780
# Total weighted fitting error: 394.277
# Total weighted fitting error: 394.276
# Evidence 233.258
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 6.24e-02
# Total weighted fitting error: 398.269
# Total weighted fitting error: 398.207
# Total weighted fitting error: 397.691
# Total weighted fitting error: 397.684
# Total weighted fitting error: 396.576
# Total weighted fitting error: 396.573
# Total weighted fitting error: 394.516
# Total weighted fitting error: 394.513
# Total weighted fitting error: 394.487
# Total weighted fitting error: 394.235
# Total weighted fitting error: 393.815
# Total weighted fitting error: 393.814
# Evidence 236.995
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 7.60e-02
# Total weighted fitting error: 398.253
# Total weighted fitting error: 398.194
# Total weighted fitting error: 398.088
# Total weighted fitting error: 397.893
# Total weighted fitting error: 397.549
# Total weighted fitting error: 397.542
# Total weighted fitting error: 396.454
# Total weighted fitting error: 396.450
# Total weighted fitting error: 394.452
# Total weighted fitting error: 394.446
# Evidence 240.457
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 9.24e-02
# Total weighted fitting error: 398.158
# Total weighted fitting error: 398.094
# Total weighted fitting error: 398.028
# Total weighted fitting error: 397.412
# Total weighted fitting error: 396.316
# Total weighted fitting error: 396.315
# Total weighted fitting error: 395.583
# Total weighted fitting error: 395.429
# Total weighted fitting error: 395.387
# Total weighted fitting error: 395.372
# Total weighted fitting error: 394.761
# Total weighted fitting error: 394.759
# Total weighted fitting error: 393.971
# Total weighted fitting error: 393.970
# Total weighted fitting error: 393.967
# Total weighted fitting error: 393.963
# Total weighted fitting error: 393.797
# Total weighted fitting error: 393.753
# Total weighted fitting error: 393.747
# Total weighted fitting error: 393.742
# Total weighted fitting error: 393.572
# Total weighted fitting error: 393.569
# Total weighted fitting error: 393.248
# Total weighted fitting error: 393.247
# Evidence 243.248
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.26e-01
# Total weighted fitting error: 397.715
# Total weighted fitting error: 397.646
# Total weighted fitting error: 397.517
# Total weighted fitting error: 397.291
# Total weighted fitting error: 396.862
# Total weighted fitting error: 396.110
# Total weighted fitting error: 396.057
# Total weighted fitting error: 395.574
# Total weighted fitting error: 395.565
# Total weighted fitting error: 395.234
# Total weighted fitting error: 394.712
# Total weighted fitting error: 394.703
# Total weighted fitting error: 394.632
# Total weighted fitting error: 394.624
# Total weighted fitting error: 394.339
# Total weighted fitting error: 394.337
# Total weighted fitting error: 394.262
# Total weighted fitting error: 394.137
# Total weighted fitting error: 394.136
# Evidence 247.715
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.61e-01
# Total weighted fitting error: 398.008
# Total weighted fitting error: 397.927
# Total weighted fitting error: 397.777
# Total weighted fitting error: 397.530
# Total weighted fitting error: 397.140
# Total weighted fitting error: 397.137
# Total weighted fitting error: 396.745
# Total weighted fitting error: 396.107
# Total weighted fitting error: 396.073
# Total weighted fitting error: 396.020
# Total weighted fitting error: 395.564
# Total weighted fitting error: 395.562
# Total weighted fitting error: 395.164
# Total weighted fitting error: 395.164
# Evidence 251.594
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 2.00e-01
# Total weighted fitting error: 398.019
# Total weighted fitting error: 397.877
# Total weighted fitting error: 397.633
# Total weighted fitting error: 397.588
# Total weighted fitting error: 397.175
# Total weighted fitting error: 396.494
# Total weighted fitting error: 396.489
# Total weighted fitting error: 396.303
# Total weighted fitting error: 395.976
# Total weighted fitting error: 395.942
# Total weighted fitting error: 395.931
# Total weighted fitting error: 395.547
# Total weighted fitting error: 395.546
# Evidence 254.687
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 2.35e-01
# Total weighted fitting error: 397.928
# Total weighted fitting error: 397.593
# Total weighted fitting error: 397.585
# Total weighted fitting error: 397.283
# Total weighted fitting error: 396.945
# Total weighted fitting error: 396.944
# Evidence 257.453
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 2.41e-01
# Total weighted fitting error: 398.119
# Total weighted fitting error: 398.073
# Total weighted fitting error: 397.984
# Total weighted fitting error: 397.290
# Total weighted fitting error: 397.267
# Total weighted fitting error: 397.046
# Total weighted fitting error: 396.666
# Total weighted fitting error: 396.642
# Total weighted fitting error: 396.638
# Total weighted fitting error: 396.475
# Total weighted fitting error: 396.430
# Total weighted fitting error: 396.422
# Total weighted fitting error: 396.349
# Total weighted fitting error: 396.211
# Total weighted fitting error: 396.208
# Total weighted fitting error: 396.106
# Total weighted fitting error: 395.931
# Total weighted fitting error: 395.930
# Total weighted fitting error: 395.899
# Total weighted fitting error: 395.845
# Total weighted fitting error: 395.842
# Total weighted fitting error: 395.837
# Total weighted fitting error: 395.792
# Total weighted fitting error: 395.791
# Evidence 259.073
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.00e-01
# Total weighted fitting error: 398.129
# Total weighted fitting error: 398.039
# Total weighted fitting error: 397.895
# Total weighted fitting error: 397.685
# Total weighted fitting error: 397.652
# Total weighted fitting error: 397.380
# Total weighted fitting error: 397.044
# Total weighted fitting error: 397.040
# Total weighted fitting error: 397.033
# Total weighted fitting error: 397.022
# Total weighted fitting error: 397.003
# Total weighted fitting error: 397.000
# Total weighted fitting error: 396.967
# Total weighted fitting error: 396.908
# Total weighted fitting error: 396.898
# Total weighted fitting error: 396.897
# Total weighted fitting error: 396.869
# Total weighted fitting error: 396.868
# Total weighted fitting error: 396.853
# Total weighted fitting error: 396.829
# Total weighted fitting error: 396.828
# Total weighted fitting error: 396.828
# Total weighted fitting error: 396.824
# Total weighted fitting error: 396.822
# Total weighted fitting error: 396.821
# Total weighted fitting error: 396.821
# Total weighted fitting error: 396.817
# Total weighted fitting error: 396.817
# Total weighted fitting error: 396.813
# Total weighted fitting error: 396.813
# Total weighted fitting error: 396.810
# Total weighted fitting error: 396.809
# Evidence 261.450
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.48e-01
# Total weighted fitting error: 398.337
# Total weighted fitting error: 398.317
# Total weighted fitting error: 398.279
# Total weighted fitting error: 398.213
# Total weighted fitting error: 398.101
# Total weighted fitting error: 397.907
# Total weighted fitting error: 397.892
# Total weighted fitting error: 397.755
# Total weighted fitting error: 397.563
# Total weighted fitting error: 397.554
# Total weighted fitting error: 397.543
# Total weighted fitting error: 397.542
# Total weighted fitting error: 397.536
# Total weighted fitting error: 397.525
# Total weighted fitting error: 397.505
# Total weighted fitting error: 397.501
# Total weighted fitting error: 397.492
# Total weighted fitting error: 397.479
# Total weighted fitting error: 397.479
# Total weighted fitting error: 397.477
# Total weighted fitting error: 397.475
# Total weighted fitting error: 397.472
# Total weighted fitting error: 397.472
# Total weighted fitting error: 397.471
# Total weighted fitting error: 397.470
# Total weighted fitting error: 397.469
# Evidence 263.519
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.72e-01
# Total weighted fitting error: 398.546
# Total weighted fitting error: 398.527
# Total weighted fitting error: 398.495
# Total weighted fitting error: 398.438
# Total weighted fitting error: 398.345
# Total weighted fitting error: 398.183
# Total weighted fitting error: 398.182
# Total weighted fitting error: 398.054
# Total weighted fitting error: 398.008
# Total weighted fitting error: 397.993
# Total weighted fitting error: 397.966
# Total weighted fitting error: 397.919
# Total weighted fitting error: 397.871
# Total weighted fitting error: 397.868
# Total weighted fitting error: 397.867
# Total weighted fitting error: 397.867
# Total weighted fitting error: 397.865
# Total weighted fitting error: 397.863
# Total weighted fitting error: 397.862
# Total weighted fitting error: 397.862
# Total weighted fitting error: 397.859
# Total weighted fitting error: 397.858
# Total weighted fitting error: 397.857
# Total weighted fitting error: 397.856
# Total weighted fitting error: 397.856
# Evidence 265.275
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.82e-01
# Total weighted fitting error: 398.670
# Total weighted fitting error: 398.652
# Total weighted fitting error: 398.619
# Total weighted fitting error: 398.566
# Total weighted fitting error: 398.469
# Total weighted fitting error: 398.305
# Total weighted fitting error: 398.259
# Total weighted fitting error: 398.182
# Total weighted fitting error: 398.176
# Total weighted fitting error: 398.128
# Total weighted fitting error: 398.076
# Total weighted fitting error: 398.071
# Total weighted fitting error: 398.070
# Total weighted fitting error: 398.069
# Total weighted fitting error: 398.061
# Total weighted fitting error: 398.059
# Total weighted fitting error: 398.059
# Total weighted fitting error: 398.056
# Total weighted fitting error: 398.051
# Total weighted fitting error: 398.051
# Total weighted fitting error: 398.051
# Total weighted fitting error: 398.051
# Total weighted fitting error: 398.051
# Evidence 266.847
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.83e-01
# Total weighted fitting error: 398.677
# Evidence 267.697
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.84e-01
# Total weighted fitting error: 399.054
# Total weighted fitting error: 399.021
# Total weighted fitting error: 398.968
# Total weighted fitting error: 398.886
# Total weighted fitting error: 398.740
# Total weighted fitting error: 398.525
# Total weighted fitting error: 398.525
# Total weighted fitting error: 398.510
# Total weighted fitting error: 398.488
# Total weighted fitting error: 398.483
# Total weighted fitting error: 398.446
# Total weighted fitting error: 398.402
# Total weighted fitting error: 398.399
# Total weighted fitting error: 398.398
# Total weighted fitting error: 398.396
# Total weighted fitting error: 398.393
# Total weighted fitting error: 398.391
# Total weighted fitting error: 398.390
# Total weighted fitting error: 398.390
# Total weighted fitting error: 398.384
# Total weighted fitting error: 398.384
# Evidence 268.558
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.83e-01
# Total weighted fitting error: 398.718
# Evidence 269.300
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.83e-01
# Total weighted fitting error: 398.997
# Total weighted fitting error: 398.945
# Total weighted fitting error: 398.858
# Total weighted fitting error: 398.726
# Total weighted fitting error: 398.551
# Total weighted fitting error: 398.551
# Evidence 269.901
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.85e-01
# Total weighted fitting error: 398.868
# Evidence 270.323
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.85e-01
# Total weighted fitting error: 398.996
# Total weighted fitting error: 398.944
# Total weighted fitting error: 398.858
# Total weighted fitting error: 398.728
# Total weighted fitting error: 398.726
# Total weighted fitting error: 398.644
# Total weighted fitting error: 398.637
# Total weighted fitting error: 398.572
# Total weighted fitting error: 398.477
# Total weighted fitting error: 398.476
# Total weighted fitting error: 398.474
# Total weighted fitting error: 398.470
# Total weighted fitting error: 398.464
# Total weighted fitting error: 398.453
# Total weighted fitting error: 398.452
# Total weighted fitting error: 398.438
# Total weighted fitting error: 398.438
# Total weighted fitting error: 398.424
# Total weighted fitting error: 398.424
# Evidence 271.130
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.87e-01
# Total weighted fitting error: 398.862
# Evidence 271.706
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.87e-01
# Total weighted fitting error: 398.961
# Total weighted fitting error: 398.918
# Total weighted fitting error: 398.840
# Total weighted fitting error: 398.812
# Total weighted fitting error: 398.761
# Total weighted fitting error: 398.748
# Total weighted fitting error: 398.648
# Total weighted fitting error: 398.512
# Total weighted fitting error: 398.510
# Total weighted fitting error: 398.496
# Total weighted fitting error: 398.469
# Total weighted fitting error: 398.458
# Total weighted fitting error: 398.438
# Total weighted fitting error: 398.437
# Total weighted fitting error: 398.417
# Total weighted fitting error: 398.414
# Total weighted fitting error: 398.393
# Total weighted fitting error: 398.393
# Evidence 272.616
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 3.91e-01
# Total weighted fitting error: 398.947
# Total weighted fitting error: 398.933
# Total weighted fitting error: 398.911
# Total weighted fitting error: 398.871
# Total weighted fitting error: 398.867
# Total weighted fitting error: 398.825
# Total weighted fitting error: 398.749
# Total weighted fitting error: 398.638
# Total weighted fitting error: 398.623
# Total weighted fitting error: 398.501
# Total weighted fitting error: 398.498
# Total weighted fitting error: 398.384
# Total weighted fitting error: 398.381
# Total weighted fitting error: 398.373
# Total weighted fitting error: 398.361
# Total weighted fitting error: 398.338
# Total weighted fitting error: 398.330
# Total weighted fitting error: 398.319
# Total weighted fitting error: 398.297
# Total weighted fitting error: 398.296
# Total weighted fitting error: 398.261
# Total weighted fitting error: 398.260
# Total weighted fitting error: 398.239
# Total weighted fitting error: 398.234
# Total weighted fitting error: 398.195
# Total weighted fitting error: 398.194
# Total weighted fitting error: 398.186
# Total weighted fitting error: 398.178
# Total weighted fitting error: 398.177
# Total weighted fitting error: 398.162
# Total weighted fitting error: 398.162
# Total weighted fitting error: 398.138
# Total weighted fitting error: 398.138
# Total weighted fitting error: 398.114
# Total weighted fitting error: 398.113
# Total weighted fitting error: 398.112
# Total weighted fitting error: 398.109
# Total weighted fitting error: 398.104
# Total weighted fitting error: 398.096
# Total weighted fitting error: 398.096
# Total weighted fitting error: 398.079
# Total weighted fitting error: 398.078
# Total weighted fitting error: 398.077
# Total weighted fitting error: 398.076
# Total weighted fitting error: 398.059
# Total weighted fitting error: 398.059
# Total weighted fitting error: 398.057
# Total weighted fitting error: 398.055
# Total weighted fitting error: 398.052
# Total weighted fitting error: 398.046
# Total weighted fitting error: 398.046
# Evidence 274.580
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 4.17e-01
# Total weighted fitting error: 399.025
# Total weighted fitting error: 398.983
# Total weighted fitting error: 398.922
# Total weighted fitting error: 398.807
# Total weighted fitting error: 398.716
# Total weighted fitting error: 398.549
# Total weighted fitting error: 398.266
# Total weighted fitting error: 398.142
# Total weighted fitting error: 398.121
# Total weighted fitting error: 397.918
# Total weighted fitting error: 397.914
# Total weighted fitting error: 397.758
# Total weighted fitting error: 397.499
# Total weighted fitting error: 397.490
# Total weighted fitting error: 397.414
# Total weighted fitting error: 397.389
# Total weighted fitting error: 397.175
# Total weighted fitting error: 397.169
# Total weighted fitting error: 396.952
# Total weighted fitting error: 396.944
# Total weighted fitting error: 396.929
# Total weighted fitting error: 396.902
# Total weighted fitting error: 396.855
# Total weighted fitting error: 396.844
# Total weighted fitting error: 396.746
# Total weighted fitting error: 396.743
# Total weighted fitting error: 396.638
# Total weighted fitting error: 396.632
# Total weighted fitting error: 396.589
# Total weighted fitting error: 396.588
# Total weighted fitting error: 396.441
# Total weighted fitting error: 396.434
# Total weighted fitting error: 396.420
# Total weighted fitting error: 396.395
# Total weighted fitting error: 396.388
# Total weighted fitting error: 396.321
# Total weighted fitting error: 396.319
# Total weighted fitting error: 396.272
# Total weighted fitting error: 396.202
# Total weighted fitting error: 396.199
# Total weighted fitting error: 396.194
# Total weighted fitting error: 396.148
# Total weighted fitting error: 396.139
# Total weighted fitting error: 396.126
# Total weighted fitting error: 396.023
# Total weighted fitting error: 396.020
# Total weighted fitting error: 396.013
# Total weighted fitting error: 396.000
# Total weighted fitting error: 395.977
# Total weighted fitting error: 395.972
# Total weighted fitting error: 395.929
# Total weighted fitting error: 395.927
# Total weighted fitting error: 395.856
# Total weighted fitting error: 395.853
# Total weighted fitting error: 395.846
# Total weighted fitting error: 395.835
# Total weighted fitting error: 395.817
# Total weighted fitting error: 395.814
# Total weighted fitting error: 395.779
# Total weighted fitting error: 395.778
# Total weighted fitting error: 395.728
# Total weighted fitting error: 395.726
# Total weighted fitting error: 395.711
# Total weighted fitting error: 395.686
# Total weighted fitting error: 395.683
# Total weighted fitting error: 395.653
# Total weighted fitting error: 395.651
# Total weighted fitting error: 395.646
# Total weighted fitting error: 395.609
# Total weighted fitting error: 395.608
# Total weighted fitting error: 395.598
# Total weighted fitting error: 395.581
# Total weighted fitting error: 395.579
# Total weighted fitting error: 395.554
# Total weighted fitting error: 395.551
# Total weighted fitting error: 395.547
# Total weighted fitting error: 395.511
# Total weighted fitting error: 395.510
# Total weighted fitting error: 395.500
# Total weighted fitting error: 395.487
# Total weighted fitting error: 395.486
# Total weighted fitting error: 395.473
# Total weighted fitting error: 395.471
# Total weighted fitting error: 395.455
# Total weighted fitting error: 395.452
# Total weighted fitting error: 395.448
# Total weighted fitting error: 395.441
# Total weighted fitting error: 395.437
# Total weighted fitting error: 395.437
# Total weighted fitting error: 395.433
# Total weighted fitting error: 395.426
# Total weighted fitting error: 395.425
# Total weighted fitting error: 395.424
# Total weighted fitting error: 395.416
# Total weighted fitting error: 395.415
# Total weighted fitting error: 395.413
# Total weighted fitting error: 395.410
# Total weighted fitting error: 395.408
# Total weighted fitting error: 395.404
# Total weighted fitting error: 395.403
# Total weighted fitting error: 395.402
# Total weighted fitting error: 395.400
# Total weighted fitting error: 395.397
# Total weighted fitting error: 395.396
# Total weighted fitting error: 395.395
# Total weighted fitting error: 395.390
# Total weighted fitting error: 395.390
# Total weighted fitting error: 395.389
# Total weighted fitting error: 395.388
# Total weighted fitting error: 395.386
# Total weighted fitting error: 395.386
# Total weighted fitting error: 395.385
# Total weighted fitting error: 395.384
# Total weighted fitting error: 395.384
# Total weighted fitting error: 395.383
# Total weighted fitting error: 395.381
# Total weighted fitting error: 395.381
# Total weighted fitting error: 395.380
# Total weighted fitting error: 395.380
# Total weighted fitting error: 395.380
# Total weighted fitting error: 395.379
# Total weighted fitting error: 395.378
# Total weighted fitting error: 395.378
# Total weighted fitting error: 395.378
# Total weighted fitting error: 395.377
# Total weighted fitting error: 395.377
# Total weighted fitting error: 395.377
# Total weighted fitting error: 395.377
# Total weighted fitting error: 395.376
# Total weighted fitting error: 395.376
# Total weighted fitting error: 395.376
# Total weighted fitting error: 395.376
# Total weighted fitting error: 395.375
# Total weighted fitting error: 395.375
# Total weighted fitting error: 395.375
# Evidence 277.398
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 5.99e-01
# Total weighted fitting error: 397.661
# Total weighted fitting error: 396.970
# Total weighted fitting error: 395.998
# Total weighted fitting error: 394.294
# Total weighted fitting error: 392.664
# Total weighted fitting error: 392.414
# Total weighted fitting error: 391.955
# Total weighted fitting error: 391.201
# Total weighted fitting error: 391.175
# Total weighted fitting error: 390.933
# Total weighted fitting error: 390.544
# Total weighted fitting error: 390.482
# Total weighted fitting error: 390.365
# Total weighted fitting error: 390.167
# Total weighted fitting error: 390.122
# Total weighted fitting error: 390.040
# Total weighted fitting error: 389.917
# Total weighted fitting error: 389.903
# Total weighted fitting error: 389.885
# Total weighted fitting error: 389.882
# Total weighted fitting error: 389.856
# Total weighted fitting error: 389.828
# Total weighted fitting error: 389.826
# Total weighted fitting error: 389.822
# Total weighted fitting error: 389.820
# Total weighted fitting error: 389.820
# Evidence 293.448
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 7.17e-01
# Total weighted fitting error: 396.412
# Total weighted fitting error: 395.612
# Total weighted fitting error: 394.640
# Total weighted fitting error: 394.613
# Total weighted fitting error: 394.377
# Total weighted fitting error: 394.020
# Total weighted fitting error: 393.987
# Total weighted fitting error: 393.978
# Total weighted fitting error: 393.897
# Total weighted fitting error: 393.764
# Total weighted fitting error: 393.742
# Total weighted fitting error: 393.707
# Total weighted fitting error: 393.649
# Total weighted fitting error: 393.594
# Total weighted fitting error: 393.587
# Total weighted fitting error: 393.582
# Total weighted fitting error: 393.581
# Total weighted fitting error: 393.578
# Total weighted fitting error: 393.574
# Total weighted fitting error: 393.573
# Total weighted fitting error: 393.569
# Total weighted fitting error: 393.569
# Total weighted fitting error: 393.569
# Total weighted fitting error: 393.567
# Total weighted fitting error: 393.567
# Total weighted fitting error: 393.567
# Total weighted fitting error: 393.567
# Total weighted fitting error: 393.567
# Total weighted fitting error: 393.566
# Total weighted fitting error: 393.566
# Total weighted fitting error: 393.566
# Total weighted fitting error: 393.566
# Total weighted fitting error: 393.566
# Evidence 301.285
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 8.05e-01
# Total weighted fitting error: 397.494
# Total weighted fitting error: 397.323
# Total weighted fitting error: 397.014
# Total weighted fitting error: 396.535
# Total weighted fitting error: 396.439
# Total weighted fitting error: 396.274
# Total weighted fitting error: 396.074
# Total weighted fitting error: 396.069
# Total weighted fitting error: 396.060
# Total weighted fitting error: 396.043
# Total weighted fitting error: 396.013
# Total weighted fitting error: 396.005
# Total weighted fitting error: 395.990
# Total weighted fitting error: 395.967
# Total weighted fitting error: 395.964
# Total weighted fitting error: 395.963
# Total weighted fitting error: 395.960
# Total weighted fitting error: 395.956
# Total weighted fitting error: 395.950
# Total weighted fitting error: 395.950
# Evidence 304.548
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 8.64e-01
# Total weighted fitting error: 397.989
# Total weighted fitting error: 397.724
# Total weighted fitting error: 397.324
# Total weighted fitting error: 397.058
# Total weighted fitting error: 397.046
# Total weighted fitting error: 397.032
# Total weighted fitting error: 397.006
# Total weighted fitting error: 396.963
# Total weighted fitting error: 396.926
# Total weighted fitting error: 396.923
# Total weighted fitting error: 396.918
# Total weighted fitting error: 396.918
# Total weighted fitting error: 396.917
# Total weighted fitting error: 396.914
# Total weighted fitting error: 396.914
# Evidence 306.613
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 9.14e-01
# Total weighted fitting error: 398.195
# Total weighted fitting error: 397.915
# Total weighted fitting error: 397.462
# Total weighted fitting error: 397.210
# Total weighted fitting error: 397.179
# Total weighted fitting error: 397.131
# Total weighted fitting error: 397.080
# Total weighted fitting error: 397.077
# Total weighted fitting error: 397.074
# Total weighted fitting error: 397.069
# Total weighted fitting error: 397.068
# Total weighted fitting error: 397.063
# Total weighted fitting error: 397.063
# Total weighted fitting error: 397.061
# Total weighted fitting error: 397.059
# Total weighted fitting error: 397.059
# Evidence 308.762
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 9.69e-01
# Total weighted fitting error: 398.176
# Total weighted fitting error: 397.974
# Total weighted fitting error: 397.666
# Total weighted fitting error: 397.380
# Total weighted fitting error: 397.363
# Total weighted fitting error: 397.331
# Total weighted fitting error: 397.285
# Total weighted fitting error: 397.284
# Total weighted fitting error: 397.273
# Total weighted fitting error: 397.262
# Total weighted fitting error: 397.262
# Total weighted fitting error: 397.262
# Total weighted fitting error: 397.260
# Total weighted fitting error: 397.260
# Evidence 310.976
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.01e+00
# Total weighted fitting error: 398.322
# Total weighted fitting error: 398.207
# Total weighted fitting error: 398.035
# Total weighted fitting error: 397.880
# Total weighted fitting error: 397.838
# Total weighted fitting error: 397.795
# Total weighted fitting error: 397.792
# Total weighted fitting error: 397.792
# Total weighted fitting error: 397.785
# Total weighted fitting error: 397.783
# Total weighted fitting error: 397.781
# Evidence 312.413
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.03e+00
# Total weighted fitting error: 398.408
# Total weighted fitting error: 398.340
# Total weighted fitting error: 398.256
# Total weighted fitting error: 398.168
# Total weighted fitting error: 398.158
# Total weighted fitting error: 398.141
# Total weighted fitting error: 398.120
# Total weighted fitting error: 398.119
# Total weighted fitting error: 398.119
# Total weighted fitting error: 398.118
# Total weighted fitting error: 398.116
# Total weighted fitting error: 398.116
# Total weighted fitting error: 398.116
# Total weighted fitting error: 398.116
# Total weighted fitting error: 398.116
# Total weighted fitting error: 398.116
# Total weighted fitting error: 398.116
# Total weighted fitting error: 398.116
# Evidence 313.113
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.04e+00
# Total weighted fitting error: 398.453
# Total weighted fitting error: 398.411
# Total weighted fitting error: 398.361
# Total weighted fitting error: 398.320
# Total weighted fitting error: 398.317
# Total weighted fitting error: 398.311
# Total weighted fitting error: 398.302
# Total weighted fitting error: 398.301
# Total weighted fitting error: 398.299
# Total weighted fitting error: 398.296
# Evidence 313.432
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.04e+00
# Total weighted fitting error: 398.505
# Total weighted fitting error: 398.478
# Total weighted fitting error: 398.440
# Total weighted fitting error: 398.420
# Total weighted fitting error: 398.419
# Total weighted fitting error: 398.413
# Total weighted fitting error: 398.408
# Total weighted fitting error: 398.408
# Evidence 313.573
# Pass count  1
# Total samples: 100, Updated regularization: 1.00e-05
# Total weighted fitting error: 408.290
# Total weighted fitting error: 302.186
# Total weighted fitting error: 277.899
# Total weighted fitting error: 251.375
# Total weighted fitting error: 247.627
# Total weighted fitting error: 189.207
# Total weighted fitting error: 174.417
# Total weighted fitting error: 170.982
# Total weighted fitting error: 143.163
# Total weighted fitting error: 137.661
# Total weighted fitting error: 127.317
# Total weighted fitting error: 121.879
# Total weighted fitting error: 113.380
# Total weighted fitting error: 112.542
# Total weighted fitting error: 105.964
# Total weighted fitting error: 105.544
# Total weighted fitting error: 104.774
# Total weighted fitting error: 98.766
# Total weighted fitting error: 98.721
# Total weighted fitting error: 98.308
# Total weighted fitting error: 94.775
# Total weighted fitting error: 94.011
# Total weighted fitting error: 93.965
# Total weighted fitting error: 92.215
# Total weighted fitting error: 92.196
# Total weighted fitting error: 89.512
# Total weighted fitting error: 89.484
# Total weighted fitting error: 89.237
# Total weighted fitting error: 88.772
# Total weighted fitting error: 87.887
# Total weighted fitting error: 87.450
# Total weighted fitting error: 86.747
# Total weighted fitting error: 85.455
# Total weighted fitting error: 85.452
# Total weighted fitting error: 85.423
# Total weighted fitting error: 84.279
# Total weighted fitting error: 84.267
# Total weighted fitting error: 82.438
# Total weighted fitting error: 82.433
# Total weighted fitting error: 82.394
# Total weighted fitting error: 82.085
# Total weighted fitting error: 82.061
# Total weighted fitting error: 81.134
# Total weighted fitting error: 81.130
# Total weighted fitting error: 80.562
# Total weighted fitting error: 80.554
# Total weighted fitting error: 79.391
# Total weighted fitting error: 79.385
# Total weighted fitting error: 79.329
# Total weighted fitting error: 79.226
# Total weighted fitting error: 78.279
# Total weighted fitting error: 78.268
# Total weighted fitting error: 77.877
# Total weighted fitting error: 77.863
# Total weighted fitting error: 77.837
# Total weighted fitting error: 77.618
# Total weighted fitting error: 77.540
# Total weighted fitting error: 77.504
# Total weighted fitting error: 77.460
# Total weighted fitting error: 75.911
# Total weighted fitting error: 75.880
# Total weighted fitting error: 75.826
# Total weighted fitting error: 75.315
# Total weighted fitting error: 75.300
# Total weighted fitting error: 75.183
# Total weighted fitting error: 74.387
# Total weighted fitting error: 74.339
# Total weighted fitting error: 74.318
# Total weighted fitting error: 74.147
# Total weighted fitting error: 73.819
# Total weighted fitting error: 73.206
# Total weighted fitting error: 73.200
# Total weighted fitting error: 73.135
# Total weighted fitting error: 72.519
# Total weighted fitting error: 72.483
# Total weighted fitting error: 72.199
# Total weighted fitting error: 72.196
# Total weighted fitting error: 70.550
# Total weighted fitting error: 70.523
# Total weighted fitting error: 70.493
# Total weighted fitting error: 70.469
# Total weighted fitting error: 70.263
# Total weighted fitting error: 70.225
# Total weighted fitting error: 69.914
# Total weighted fitting error: 69.913
# Total weighted fitting error: 69.902
# Total weighted fitting error: 69.454
# Total weighted fitting error: 69.427
# Total weighted fitting error: 69.180
# Total weighted fitting error: 69.180
# Total weighted fitting error: 68.384
# Total weighted fitting error: 68.381
# Total weighted fitting error: 67.936
# Total weighted fitting error: 67.936
# Total weighted fitting error: 67.419
# Total weighted fitting error: 67.419
# Evidence -531.010
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 2.57e-02
# Total weighted fitting error: 254.694
# Total weighted fitting error: 253.599
# Total weighted fitting error: 252.730
# Total weighted fitting error: 251.443
# Total weighted fitting error: 251.321
# Total weighted fitting error: 251.095
# Total weighted fitting error: 250.708
# Total weighted fitting error: 250.189
# Total weighted fitting error: 249.300
# Total weighted fitting error: 249.294
# Total weighted fitting error: 248.469
# Total weighted fitting error: 248.464
# Total weighted fitting error: 247.753
# Total weighted fitting error: 247.736
# Total weighted fitting error: 247.153
# Total weighted fitting error: 247.144
# Total weighted fitting error: 246.822
# Total weighted fitting error: 246.822
# Evidence 155.718
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 5.38e-02
# Total weighted fitting error: 368.711
# Total weighted fitting error: 368.098
# Total weighted fitting error: 367.064
# Total weighted fitting error: 365.700
# Total weighted fitting error: 365.674
# Total weighted fitting error: 364.690
# Total weighted fitting error: 363.701
# Total weighted fitting error: 363.669
# Total weighted fitting error: 363.652
# Total weighted fitting error: 363.618
# Total weighted fitting error: 363.341
# Total weighted fitting error: 362.827
# Total weighted fitting error: 361.987
# Total weighted fitting error: 361.955
# Total weighted fitting error: 361.652
# Total weighted fitting error: 361.138
# Total weighted fitting error: 361.134
# Total weighted fitting error: 360.679
# Total weighted fitting error: 360.674
# Total weighted fitting error: 360.666
# Total weighted fitting error: 360.381
# Total weighted fitting error: 360.381
# Evidence 236.612
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 6.00e-02
# Total weighted fitting error: 391.645
# Total weighted fitting error: 391.453
# Total weighted fitting error: 391.098
# Total weighted fitting error: 390.515
# Total weighted fitting error: 389.849
# Total weighted fitting error: 389.846
# Evidence 251.594
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 6.10e-02
# Total weighted fitting error: 397.274
# Total weighted fitting error: 397.169
# Total weighted fitting error: 396.969
# Total weighted fitting error: 396.602
# Total weighted fitting error: 396.585
# Total weighted fitting error: 395.932
# Total weighted fitting error: 394.841
# Total weighted fitting error: 394.388
# Total weighted fitting error: 394.384
# Evidence 257.710
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 6.14e-02
# Total weighted fitting error: 397.672
# Total weighted fitting error: 397.534
# Total weighted fitting error: 397.335
# Total weighted fitting error: 396.958
# Total weighted fitting error: 396.296
# Total weighted fitting error: 396.290
# Total weighted fitting error: 395.376
# Total weighted fitting error: 395.352
# Total weighted fitting error: 395.116
# Total weighted fitting error: 394.702
# Total weighted fitting error: 394.698
# Total weighted fitting error: 394.058
# Total weighted fitting error: 394.057
# Total weighted fitting error: 394.023
# Total weighted fitting error: 393.962
# Total weighted fitting error: 393.928
# Total weighted fitting error: 393.601
# Total weighted fitting error: 393.599
# Total weighted fitting error: 393.203
# Total weighted fitting error: 393.195
# Total weighted fitting error: 393.125
# Total weighted fitting error: 392.503
# Total weighted fitting error: 392.497
# Total weighted fitting error: 392.485
# Total weighted fitting error: 392.465
# Total weighted fitting error: 392.432
# Total weighted fitting error: 392.372
# Total weighted fitting error: 392.371
# Total weighted fitting error: 391.606
# Total weighted fitting error: 391.591
# Total weighted fitting error: 391.564
# Total weighted fitting error: 391.523
# Total weighted fitting error: 391.447
# Total weighted fitting error: 391.445
# Total weighted fitting error: 391.115
# Total weighted fitting error: 391.108
# Total weighted fitting error: 391.095
# Total weighted fitting error: 391.073
# Total weighted fitting error: 391.039
# Total weighted fitting error: 390.979
# Total weighted fitting error: 390.977
# Total weighted fitting error: 390.115
# Total weighted fitting error: 390.103
# Total weighted fitting error: 390.084
# Total weighted fitting error: 390.055
# Total weighted fitting error: 389.814
# Total weighted fitting error: 389.811
# Total weighted fitting error: 389.398
# Total weighted fitting error: 389.388
# Total weighted fitting error: 389.370
# Total weighted fitting error: 389.338
# Total weighted fitting error: 389.035
# Total weighted fitting error: 389.029
# Total weighted fitting error: 388.975
# Total weighted fitting error: 388.954
# Total weighted fitting error: 388.914
# Total weighted fitting error: 387.537
# Total weighted fitting error: 387.480
# Total weighted fitting error: 387.463
# Total weighted fitting error: 387.433
# Total weighted fitting error: 387.378
# Total weighted fitting error: 387.278
# Total weighted fitting error: 387.113
# Total weighted fitting error: 387.097
# Total weighted fitting error: 387.090
# Total weighted fitting error: 386.142
# Total weighted fitting error: 386.106
# Total weighted fitting error: 386.056
# Total weighted fitting error: 385.973
# Total weighted fitting error: 385.839
# Total weighted fitting error: 385.823
# Total weighted fitting error: 385.675
# Total weighted fitting error: 385.516
# Total weighted fitting error: 385.510
# Total weighted fitting error: 385.500
# Total weighted fitting error: 385.124
# Total weighted fitting error: 385.121
# Total weighted fitting error: 385.117
# Total weighted fitting error: 384.944
# Total weighted fitting error: 384.930
# Total weighted fitting error: 384.467
# Total weighted fitting error: 384.458
# Total weighted fitting error: 384.442
# Total weighted fitting error: 384.421
# Total weighted fitting error: 384.385
# Total weighted fitting error: 384.330
# Total weighted fitting error: 384.328
# Total weighted fitting error: 384.301
# Total weighted fitting error: 384.249
# Total weighted fitting error: 384.248
# Evidence 267.158
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.21e-01
# Total weighted fitting error: 393.071
# Total weighted fitting error: 392.558
# Total weighted fitting error: 391.777
# Total weighted fitting error: 391.050
# Total weighted fitting error: 390.753
# Total weighted fitting error: 390.742
# Total weighted fitting error: 390.290
# Total weighted fitting error: 389.541
# Total weighted fitting error: 389.534
# Total weighted fitting error: 388.329
# Total weighted fitting error: 388.284
# Total weighted fitting error: 386.626
# Total weighted fitting error: 386.625
# Evidence 295.335
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.29e-01
# Total weighted fitting error: 395.923
# Total weighted fitting error: 395.545
# Total weighted fitting error: 394.897
# Total weighted fitting error: 394.680
# Total weighted fitting error: 392.729
# Total weighted fitting error: 392.720
# Total weighted fitting error: 392.374
# Total weighted fitting error: 391.718
# Total weighted fitting error: 390.580
# Total weighted fitting error: 390.569
# Total weighted fitting error: 390.482
# Total weighted fitting error: 390.325
# Total weighted fitting error: 390.027
# Total weighted fitting error: 389.507
# Total weighted fitting error: 389.458
# Total weighted fitting error: 389.373
# Total weighted fitting error: 389.321
# Total weighted fitting error: 389.312
# Total weighted fitting error: 388.959
# Total weighted fitting error: 388.903
# Total weighted fitting error: 388.886
# Total weighted fitting error: 388.882
# Total weighted fitting error: 388.730
# Total weighted fitting error: 388.502
# Total weighted fitting error: 388.500
# Total weighted fitting error: 388.483
# Total weighted fitting error: 388.480
# Total weighted fitting error: 388.445
# Total weighted fitting error: 388.444
# Total weighted fitting error: 388.411
# Total weighted fitting error: 388.410
# Total weighted fitting error: 388.398
# Total weighted fitting error: 388.375
# Total weighted fitting error: 388.373
# Total weighted fitting error: 388.370
# Total weighted fitting error: 388.366
# Total weighted fitting error: 388.366
# Total weighted fitting error: 388.356
# Total weighted fitting error: 388.352
# Total weighted fitting error: 388.352
# Total weighted fitting error: 388.352
# Total weighted fitting error: 388.346
# Total weighted fitting error: 388.346
# Total weighted fitting error: 388.345
# Total weighted fitting error: 388.342
# Total weighted fitting error: 388.338
# Total weighted fitting error: 388.337
# Total weighted fitting error: 388.337
# Evidence 300.976
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.52e-01
# Total weighted fitting error: 394.561
# Total weighted fitting error: 394.218
# Total weighted fitting error: 393.705
# Total weighted fitting error: 393.646
# Total weighted fitting error: 393.534
# Total weighted fitting error: 393.327
# Total weighted fitting error: 392.992
# Total weighted fitting error: 392.987
# Total weighted fitting error: 392.813
# Total weighted fitting error: 392.576
# Total weighted fitting error: 392.571
# Total weighted fitting error: 392.562
# Total weighted fitting error: 392.560
# Total weighted fitting error: 392.541
# Total weighted fitting error: 392.507
# Total weighted fitting error: 392.506
# Total weighted fitting error: 392.494
# Total weighted fitting error: 392.473
# Total weighted fitting error: 392.472
# Total weighted fitting error: 392.465
# Total weighted fitting error: 392.462
# Total weighted fitting error: 392.462
# Total weighted fitting error: 392.459
# Total weighted fitting error: 392.454
# Total weighted fitting error: 392.454
# Evidence 309.706
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.61e-01
# Total weighted fitting error: 396.429
# Total weighted fitting error: 396.300
# Total weighted fitting error: 396.201
# Total weighted fitting error: 396.052
# Total weighted fitting error: 396.038
# Total weighted fitting error: 395.931
# Total weighted fitting error: 395.847
# Total weighted fitting error: 395.838
# Total weighted fitting error: 395.822
# Total weighted fitting error: 395.820
# Total weighted fitting error: 395.818
# Total weighted fitting error: 395.818
# Total weighted fitting error: 395.809
# Total weighted fitting error: 395.809
# Total weighted fitting error: 395.799
# Total weighted fitting error: 395.784
# Total weighted fitting error: 395.784
# Total weighted fitting error: 395.780
# Total weighted fitting error: 395.778
# Total weighted fitting error: 395.778
# Evidence 312.544
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.65e-01
# Total weighted fitting error: 397.568
# Total weighted fitting error: 397.521
# Total weighted fitting error: 397.442
# Total weighted fitting error: 397.434
# Total weighted fitting error: 397.376
# Total weighted fitting error: 397.302
# Total weighted fitting error: 397.296
# Total weighted fitting error: 397.291
# Total weighted fitting error: 397.288
# Total weighted fitting error: 397.264
# Total weighted fitting error: 397.230
# Total weighted fitting error: 397.230
# Total weighted fitting error: 397.223
# Total weighted fitting error: 397.212
# Total weighted fitting error: 397.211
# Total weighted fitting error: 397.210
# Total weighted fitting error: 397.208
# Total weighted fitting error: 397.208
# Evidence 313.673
# Updating hyper-parameters...
# Total samples: 100, Updated regularization: 1.67e-01
# Total weighted fitting error: 398.060
# Total weighted fitting error: 398.034
# Total weighted fitting error: 397.989
# Total weighted fitting error: 397.936
# Total weighted fitting error: 397.929
# Total weighted fitting error: 397.878
# Total weighted fitting error: 397.818
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17427/2851016277.py in <module>
#      34
#      35         # fit to data
# ---> 36         model.fit()
#      37
#      38         # plot fitness to data
#
# ~/anaconda3/lib/python3.9/site-packages/glove/log_model.py in fit(self, evidence_tol, nlp_tol, alpha_0, patience, max_fails, beta)
#     289
#     290             # fit using updated Alpha and Beta
# --> 291             self.res = minimize(fun=self.objective,
#     292                                 jac=self.jacobian_fwd,
#     293                                 hess=self.hessian,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     691         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     692     elif meth == 'newton-cg':
# --> 693         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     694                                  **options)
#     695     elif meth == 'l-bfgs-b':
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback, xtol, eps, maxiter, disp, return_all, **unknown_options)
#    2057         try:
#    2058             alphak, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 2059                      _line_search_wolfe12(f, fprime, xk, pk, gfk,
#    2060                                           old_fval, old_old_fval)
#    2061         except _LineSearchError:
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1158     extra_condition = kwargs.pop('extra_condition', None)
#    1159
# -> 1160     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1161                              old_fval, old_old_fval,
#    1162                              **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      82     derphi0 = np.dot(gfk, pk)
#      83
# ---> 84     stp, fval, old_fval = scalar_search_wolfe1(
#      85             phi, derphi, old_fval, old_old_fval, derphi0,
#      86             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     159             alpha1 = stp
#     160             phi1 = phi(stp)
# --> 161             derphi1 = derphi(stp)
#     162         else:
#     163             break
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_linesearch.py in derphi(s)
#      76
#      77     def derphi(s):
# ---> 78         gval[0] = fprime(xk + s*pk, *args)
#      79         gc[0] += 1
#      80         return np.dot(gval[0], pk)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in grad(self, x)
#     271         if not np.array_equal(x, self.x):
#     272             self._update_x_impl(x)
# --> 273         self._update_grad()
#     274         return self.g
#     275
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     254     def _update_grad(self):
#     255         if not self.g_updated:
# --> 256             self._update_grad_impl()
#     257             self.g_updated = True
#     258
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     165
#     166             def update_grad():
# --> 167                 self.g = grad_wrapped(self.x)
#     168
#     169         elif grad in FD_METHODS:
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in grad_wrapped(x)
#     162             def grad_wrapped(x):
#     163                 self.ngev += 1
# --> 164                 return np.atleast_1d(grad(np.copy(x), *args))
#     165
#     166             def update_grad():
#
# ~/anaconda3/lib/python3.9/site-packages/glove/log_model.py in jacobian_fwd(self, params)
#     465
#     466             # for each output
# --> 467             output, G = self.runODEZ(t_eval, Y_measured, params, s_present)
#     468
#     469             # Determine error
#
# KeyboardInterrupt:

# %%
for file in files:
    strain = file.split("_")[1]
    kfold_df = pd.read_csv(f"kfold/{strain}_kfold_log.csv")
        
    all_pred_species = kfold_df['species'].values
    all_true = kfold_df['true'].values 
    all_pred = kfold_df['pred'].values
    all_stdv = kfold_df['stdv'].values
        
    R_overall = linregress(all_true, all_pred).rvalue
        
    # show prediction performance of individual species
    for sp in species:
        sp_inds = all_pred_species == sp
        R = linregress(all_true[sp_inds], all_pred[sp_inds]).rvalue
        plt.scatter(all_true[sp_inds], all_pred[sp_inds], label=f"{sp} " + "R={:.3f}".format(R))
        plt.errorbar(all_true[sp_inds], all_pred[sp_inds], yerr=all_stdv[sp_inds], 
                     fmt='.', capsize=3)

    plt.xlabel("Measured OD")
    plt.ylabel("Predicted OD")
    plt.legend()
    plt.title(strain + " R={:.2f}".format(R_overall))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_17427/3285359843.py in <module>
#       1 for file in files:
#       2     strain = file.split("_")[1]
# ----> 3     kfold_df = pd.read_csv(f"kfold/{strain}_kfold_log.csv")
#       4
#       5     all_pred_species = kfold_df['species'].values
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     678     kwds.update(kwds_defaults)
#     679
# --> 680     return _read(filepath_or_buffer, kwds)
#     681
#     682
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     931
#     932         self.handles: IOHandles | None = None
# --> 933         self._engine = self._make_engine(f, self.engine)
#     934
#     935     def close(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1215             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217             self.handles = get_handle(  # type: ignore[call-overload]
#    1218                 f,
#    1219                 mode,
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     787         if ioargs.encoding and "b" not in ioargs.mode:
#     788             # Encoding
# --> 789             handle = open(
#     790                 handle,
#     791                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kfold/MS001_kfold_log.csv'
