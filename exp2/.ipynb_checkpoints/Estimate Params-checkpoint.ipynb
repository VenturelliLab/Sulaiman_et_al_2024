# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy.stats import norm

import os
import time
import itertools

from glove.mse_model import *
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# import file names
files = os.listdir("data/")
files = [f for f in files if "processed" in f]
files
# Out:
# ['EXP0019_MS001_processed.csv',
#  'EXP0019_MS014_processed.csv',
#  'EXP0019_MS008_processed.csv',
#  'EXP0019_DSM27147_processed.csv']

# %% [markdown]
# # fit gLV models

# %%
# for each data set 
for file in files:
    # import data
    df = pd.read_csv(f"data/{file}")

    # determine species names 
    species = df.columns.values[2:]
    n_species = len(species)

    # instantiate gLV fit 
    model = gLV(species, df) 

    # fit to data 
    t0 = time.time()
    model.fit()
    print("Elapsed time {:.2f}s".format(time.time()-t0))
    
    # plot parameter distribution
    Avec = model.params[n_species:]
    Aij_std = np.sqrt(np.diag(model.Ainv))[n_species:]
    
    plt.figure(figsize=(18,18))
    # set counter for parameter std. 
    k = 0

    for i in range(n_species):
        for j in range(n_species):
            plt.subplot(n_species, n_species, k+1)
            a = np.linspace(Avec[k]-np.std(Avec), Avec[k]+np.std(Avec))
            plt.plot(a, norm.pdf(a,Avec[k],Aij_std[k]))
            plt.axvline(x=0, c='k', alpha=.5)
            k += 1
            if j == 0:
                plt.ylabel(species[i], fontsize=18)
            if i == n_species-1:
                plt.xlabel(species[j], fontsize=18)
            #plt.xlim([-2,2])

    plt.suptitle(file.split("_")[1], fontsize=24)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.savefig("params/"+file.split("_")[1]+".pdf")
    plt.close()
    
    # compute Wald test for each parameter
    std_errors = np.sqrt(np.diag(model.Ainv))
    walds = model.params/std_errors
    wald_p_vals = 2*norm.cdf(-np.abs(walds))

    # list of parameter names 
    param_names = []
    for s1 in species:
        for s2 in species:
            param_names += [s1+"*"+s2]
    param_names = list(species) + param_names
    
    # save to df 
    df = pd.DataFrame()
    df["Param name"] = param_names
    df["Param value"] = model.params
    df["Param stdv"]  = np.sqrt(np.diag(model.Ainv))
    df["Param p-value"] = wald_p_vals
    for j, param_name in enumerate(param_names):
        df[param_name]  = model.Ainv[:, j]
    df.to_csv("params/"+file.split("_")[1]+".csv", index=False)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Total samples: 282, Updated regularization: 1.00e-03
# Total weighted fitting error: 17.595
# Total weighted fitting error: 10.667
# Total weighted fitting error: 7.692
# Total weighted fitting error: 7.490
# Total weighted fitting error: 7.114
# Total weighted fitting error: 6.574
# Total weighted fitting error: 6.108
# Total weighted fitting error: 6.025
# Total weighted fitting error: 5.971
# Total weighted fitting error: 5.897
# Total weighted fitting error: 5.880
# Total weighted fitting error: 5.849
# Total weighted fitting error: 5.797
# Total weighted fitting error: 5.796
# Total weighted fitting error: 5.786
# Total weighted fitting error: 5.767
# Total weighted fitting error: 5.745
# Total weighted fitting error: 5.710
# Total weighted fitting error: 5.708
# Total weighted fitting error: 5.706
# Total weighted fitting error: 5.687
# Total weighted fitting error: 5.687
# Total weighted fitting error: 5.667
# Total weighted fitting error: 5.666
# Total weighted fitting error: 5.657
# Total weighted fitting error: 5.657
# Total weighted fitting error: 5.640
# Total weighted fitting error: 5.640
# Total weighted fitting error: 5.610
# Total weighted fitting error: 5.608
# Total weighted fitting error: 5.607
# Total weighted fitting error: 5.600
# Total weighted fitting error: 5.600
# Evidence -236.141
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 3.32e-02
# Total weighted fitting error: 136.823
# Total weighted fitting error: 136.712
# Total weighted fitting error: 136.545
# Total weighted fitting error: 136.265
# Total weighted fitting error: 136.154
# Total weighted fitting error: 136.141
# Total weighted fitting error: 135.675
# Total weighted fitting error: 135.674
# Evidence 3525.170
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 6.53e-01
# Total weighted fitting error: 783.536
# Total weighted fitting error: 779.184
# Total weighted fitting error: 772.615
# Total weighted fitting error: 772.600
# Evidence 5329.535
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 1.81e+00
# Total weighted fitting error: 1076.226
# Total weighted fitting error: 1075.128
# Total weighted fitting error: 1065.120
# Total weighted fitting error: 1048.871
# Total weighted fitting error: 1048.826
# Total weighted fitting error: 1048.402
# Total weighted fitting error: 1034.256
# Total weighted fitting error: 1033.920
# Total weighted fitting error: 1033.906
# Evidence 5544.599
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 1.91e+00
# Total weighted fitting error: 1119.059
# Total weighted fitting error: 1117.115
# Total weighted fitting error: 1113.935
# Total weighted fitting error: 1108.052
# Total weighted fitting error: 1107.774
# Total weighted fitting error: 1098.289
# Total weighted fitting error: 1098.232
# Total weighted fitting error: 1098.123
# Total weighted fitting error: 1094.107
# Total weighted fitting error: 1088.419
# Total weighted fitting error: 1088.366
# Total weighted fitting error: 1088.278
# Total weighted fitting error: 1088.120
# Total weighted fitting error: 1086.730
# Total weighted fitting error: 1086.729
# Evidence 5603.984
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 1.57e+00
# Total weighted fitting error: 1123.116
# Total weighted fitting error: 1122.497
# Total weighted fitting error: 1121.467
# Total weighted fitting error: 1119.610
# Total weighted fitting error: 1118.574
# Total weighted fitting error: 1118.571
# Evidence 5621.299
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 1.53e+00
# Total weighted fitting error: 1125.088
# Evidence 5623.127
# Pass count  1
# Elapsed time 27.91s
# Total samples: 128, Updated regularization: 1.00e-03
# Total weighted fitting error: 14.745
# Total weighted fitting error: 7.432
# Total weighted fitting error: 5.500
# Total weighted fitting error: 4.652
# Total weighted fitting error: 4.206
# Total weighted fitting error: 4.175
# Total weighted fitting error: 3.916
# Total weighted fitting error: 3.892
# Total weighted fitting error: 3.685
# Total weighted fitting error: 3.399
# Total weighted fitting error: 3.372
# Total weighted fitting error: 3.325
# Total weighted fitting error: 3.248
# Total weighted fitting error: 3.241
# Total weighted fitting error: 3.189
# Total weighted fitting error: 3.177
# Total weighted fitting error: 3.156
# Total weighted fitting error: 3.123
# Total weighted fitting error: 3.120
# Total weighted fitting error: 3.115
# Total weighted fitting error: 3.105
# Total weighted fitting error: 3.089
# Total weighted fitting error: 3.086
# Total weighted fitting error: 3.081
# Total weighted fitting error: 3.073
# Total weighted fitting error: 3.070
# Total weighted fitting error: 3.064
# Total weighted fitting error: 3.054
# Total weighted fitting error: 3.040
# Total weighted fitting error: 3.040
# Total weighted fitting error: 3.039
# Total weighted fitting error: 3.030
# Total weighted fitting error: 3.028
# Total weighted fitting error: 3.024
# Total weighted fitting error: 3.017
# Total weighted fitting error: 3.006
# Total weighted fitting error: 3.006
# Total weighted fitting error: 3.006
# Total weighted fitting error: 3.006
# Total weighted fitting error: 3.005
# Total weighted fitting error: 3.004
# Total weighted fitting error: 3.004
# Total weighted fitting error: 3.001
# Total weighted fitting error: 3.000
# Evidence -249.917
# Updating hyper-parameters...
# Total samples: 128, Updated regularization: 3.16e-02
# Total weighted fitting error: 40.983
# Total weighted fitting error: 40.874
# Total weighted fitting error: 40.719
# Total weighted fitting error: 40.718
# Total weighted fitting error: 40.685
# Total weighted fitting error: 40.627
# Total weighted fitting error: 40.538
# Total weighted fitting error: 40.529
# Total weighted fitting error: 40.454
# Total weighted fitting error: 40.449
# Total weighted fitting error: 40.440
# Total weighted fitting error: 40.422
# Total weighted fitting error: 40.422
# Total weighted fitting error: 40.375
# Total weighted fitting error: 40.373
# Total weighted fitting error: 40.372
# Total weighted fitting error: 40.359
# Total weighted fitting error: 40.338
# Total weighted fitting error: 40.336
# Total weighted fitting error: 40.312
# Total weighted fitting error: 40.312
# Evidence 1187.054
# Updating hyper-parameters...
# Total samples: 128, Updated regularization: 1.43e-01
# Total weighted fitting error: 227.577
# Total weighted fitting error: 226.595
# Total weighted fitting error: 225.253
# Total weighted fitting error: 224.606
# Total weighted fitting error: 223.705
# Total weighted fitting error: 223.597
# Total weighted fitting error: 222.775
# Total weighted fitting error: 222.727
# Total weighted fitting error: 222.716
# Total weighted fitting error: 222.697
# Total weighted fitting error: 222.666
# Total weighted fitting error: 222.071
# Total weighted fitting error: 222.016
# Total weighted fitting error: 221.998
# Total weighted fitting error: 221.968
# Total weighted fitting error: 221.926
# Total weighted fitting error: 220.029
# Total weighted fitting error: 219.681
# Total weighted fitting error: 219.635
# Total weighted fitting error: 219.566
# Total weighted fitting error: 219.441
# Total weighted fitting error: 219.240
# Total weighted fitting error: 219.213
# Total weighted fitting error: 219.161
# Total weighted fitting error: 219.072
# Total weighted fitting error: 219.057
# Total weighted fitting error: 218.921
# Total weighted fitting error: 218.920
# Total weighted fitting error: 218.883
# Total weighted fitting error: 218.811
# Total weighted fitting error: 218.808
# Total weighted fitting error: 218.687
# Total weighted fitting error: 218.686
# Evidence 2087.791
# Updating hyper-parameters...
# Total samples: 128, Updated regularization: 6.02e-01
# Total weighted fitting error: 437.213
# Total weighted fitting error: 432.284
# Total weighted fitting error: 429.310
# Total weighted fitting error: 428.477
# Total weighted fitting error: 427.868
# Total weighted fitting error: 427.804
# Total weighted fitting error: 427.265
# Total weighted fitting error: 427.254
# Total weighted fitting error: 426.810
# Total weighted fitting error: 426.793
# Total weighted fitting error: 426.770
# Total weighted fitting error: 426.548
# Total weighted fitting error: 426.141
# Total weighted fitting error: 425.885
# Total weighted fitting error: 425.825
# Total weighted fitting error: 425.272
# Total weighted fitting error: 424.955
# Total weighted fitting error: 424.408
# Total weighted fitting error: 424.097
# Total weighted fitting error: 423.809
# Total weighted fitting error: 421.652
# Total weighted fitting error: 421.533
# Total weighted fitting error: 421.317
# Total weighted fitting error: 420.982
# Total weighted fitting error: 420.819
# Total weighted fitting error: 419.624
# Total weighted fitting error: 419.550
# Total weighted fitting error: 419.426
# Total weighted fitting error: 419.279
# Total weighted fitting error: 419.007
# Total weighted fitting error: 418.899
# Total weighted fitting error: 418.702
# Total weighted fitting error: 418.682
# Total weighted fitting error: 418.508
# Total weighted fitting error: 418.249
# Total weighted fitting error: 418.208
# Total weighted fitting error: 418.192
# Total weighted fitting error: 418.168
# Total weighted fitting error: 418.127
# Total weighted fitting error: 418.124
# Total weighted fitting error: 418.097
# Total weighted fitting error: 418.093
# Total weighted fitting error: 418.087
# Total weighted fitting error: 418.076
# Total weighted fitting error: 418.074
# Total weighted fitting error: 418.073
# Total weighted fitting error: 418.071
# Total weighted fitting error: 418.070
# Total weighted fitting error: 418.068
# Total weighted fitting error: 418.066
# Total weighted fitting error: 418.066
# Total weighted fitting error: 418.066
# Total weighted fitting error: 418.065
# Total weighted fitting error: 418.065
# Total weighted fitting error: 418.065
# Total weighted fitting error: 418.065
# Evidence 2346.755
# Updating hyper-parameters...
# Total samples: 128, Updated regularization: 1.12e+00
# Total weighted fitting error: 495.594
# Total weighted fitting error: 493.960
# Total weighted fitting error: 493.017
# Total weighted fitting error: 492.739
# Total weighted fitting error: 492.617
# Total weighted fitting error: 492.402
# Total weighted fitting error: 492.107
# Total weighted fitting error: 492.088
# Total weighted fitting error: 492.053
# Total weighted fitting error: 491.999
# Total weighted fitting error: 491.993
# Total weighted fitting error: 491.980
# Total weighted fitting error: 491.975
# Total weighted fitting error: 491.965
# Total weighted fitting error: 491.949
# Total weighted fitting error: 491.949
# Total weighted fitting error: 491.943
# Total weighted fitting error: 491.943
# Total weighted fitting error: 491.938
# Total weighted fitting error: 491.938
# Total weighted fitting error: 491.937
# Total weighted fitting error: 491.935
# Total weighted fitting error: 491.935
# Total weighted fitting error: 491.934
# Evidence 2394.004
# Updating hyper-parameters...
# Total samples: 128, Updated regularization: 1.07e+00
# Total weighted fitting error: 507.854
# Total weighted fitting error: 507.690
# Total weighted fitting error: 507.514
# Total weighted fitting error: 507.361
# Total weighted fitting error: 507.349
# Total weighted fitting error: 507.326
# Total weighted fitting error: 507.289
# Total weighted fitting error: 507.288
# Total weighted fitting error: 507.276
# Total weighted fitting error: 507.258
# Total weighted fitting error: 507.257
# Total weighted fitting error: 507.254
# Total weighted fitting error: 507.250
# Total weighted fitting error: 507.249
# Total weighted fitting error: 507.248
# Total weighted fitting error: 507.246
# Total weighted fitting error: 507.246
# Total weighted fitting error: 507.246
# Total weighted fitting error: 507.245
# Total weighted fitting error: 507.243
# Evidence 2398.396
# Updating hyper-parameters...
# Total samples: 128, Updated regularization: 1.10e+00
# Total weighted fitting error: 509.758
# Total weighted fitting error: 509.679
# Total weighted fitting error: 509.595
# Total weighted fitting error: 509.536
# Total weighted fitting error: 509.526
# Total weighted fitting error: 509.510
# Total weighted fitting error: 509.488
# Total weighted fitting error: 509.486
# Total weighted fitting error: 509.483
# Total weighted fitting error: 509.478
# Total weighted fitting error: 509.477
# Total weighted fitting error: 509.473
# Total weighted fitting error: 509.469
# Total weighted fitting error: 509.468
# Total weighted fitting error: 509.468
# Total weighted fitting error: 509.468
# Evidence 2399.531
# Pass count  1
# Elapsed time 70.43s
# Total samples: 282, Updated regularization: 1.00e-03
# Total weighted fitting error: 17.596
# Total weighted fitting error: 10.413
# Total weighted fitting error: 8.155
# Total weighted fitting error: 7.834
# Total weighted fitting error: 7.322
# Total weighted fitting error: 6.674
# Total weighted fitting error: 6.426
# Total weighted fitting error: 6.401
# Total weighted fitting error: 6.355
# Total weighted fitting error: 6.278
# Total weighted fitting error: 6.164
# Total weighted fitting error: 6.159
# Total weighted fitting error: 6.113
# Total weighted fitting error: 6.038
# Total weighted fitting error: 6.033
# Total weighted fitting error: 6.025
# Total weighted fitting error: 5.985
# Total weighted fitting error: 5.953
# Total weighted fitting error: 5.950
# Total weighted fitting error: 5.921
# Total weighted fitting error: 5.920
# Total weighted fitting error: 5.849
# Total weighted fitting error: 5.841
# Total weighted fitting error: 5.834
# Total weighted fitting error: 5.820
# Total weighted fitting error: 5.798
# Total weighted fitting error: 5.798
# Evidence -243.315
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 6.03e-02
# Total weighted fitting error: 137.576
# Total weighted fitting error: 137.059
# Total weighted fitting error: 136.109
# Total weighted fitting error: 134.930
# Total weighted fitting error: 134.908
# Total weighted fitting error: 131.720
# Total weighted fitting error: 131.699
# Total weighted fitting error: 131.517
# Total weighted fitting error: 131.210
# Total weighted fitting error: 130.809
# Total weighted fitting error: 130.055
# Total weighted fitting error: 128.707
# Total weighted fitting error: 128.649
# Total weighted fitting error: 126.665
# Total weighted fitting error: 126.632
# Total weighted fitting error: 126.576
# Total weighted fitting error: 126.476
# Total weighted fitting error: 126.293
# Total weighted fitting error: 124.751
# Total weighted fitting error: 124.710
# Total weighted fitting error: 124.695
# Total weighted fitting error: 124.568
# Total weighted fitting error: 124.429
# Total weighted fitting error: 124.428
# Evidence 3513.073
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 5.88e-01
# Total weighted fitting error: 775.656
# Total weighted fitting error: 769.911
# Total weighted fitting error: 761.035
# Total weighted fitting error: 754.907
# Total weighted fitting error: 750.439
# Total weighted fitting error: 750.427
# Evidence 5414.432
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 8.32e-01
# Total weighted fitting error: 1095.654
# Total weighted fitting error: 1092.412
# Total weighted fitting error: 1087.243
# Total weighted fitting error: 1081.084
# Total weighted fitting error: 1071.288
# Total weighted fitting error: 1071.195
# Total weighted fitting error: 1070.432
# Total weighted fitting error: 1064.003
# Total weighted fitting error: 1063.964
# Total weighted fitting error: 1058.202
# Total weighted fitting error: 1058.175
# Total weighted fitting error: 1057.950
# Total weighted fitting error: 1055.811
# Total weighted fitting error: 1052.482
# Total weighted fitting error: 1052.475
# Evidence 5637.855
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 7.19e-01
# Total weighted fitting error: 1121.041
# Total weighted fitting error: 1120.749
# Total weighted fitting error: 1118.480
# Total weighted fitting error: 1116.561
# Total weighted fitting error: 1116.056
# Total weighted fitting error: 1111.730
# Total weighted fitting error: 1111.677
# Total weighted fitting error: 1109.599
# Total weighted fitting error: 1109.597
# Evidence 5668.839
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 6.39e-01
# Total weighted fitting error: 1124.645
# Total weighted fitting error: 1124.545
# Total weighted fitting error: 1123.709
# Total weighted fitting error: 1123.006
# Total weighted fitting error: 1123.004
# Evidence 5674.811
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 6.38e-01
# Total weighted fitting error: 1125.567
# Total weighted fitting error: 1124.857
# Total weighted fitting error: 1123.663
# Total weighted fitting error: 1123.597
# Total weighted fitting error: 1121.068
# Total weighted fitting error: 1120.775
# Total weighted fitting error: 1120.760
# Total weighted fitting error: 1118.445
# Total weighted fitting error: 1118.429
# Evidence 5683.182
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 5.81e-01
# Total weighted fitting error: 1125.575
# Evidence 5684.914
# Pass count  1
# Elapsed time 30.93s
# Total samples: 282, Updated regularization: 1.00e-03
# Total weighted fitting error: 15.633
# Total weighted fitting error: 9.186
# Total weighted fitting error: 7.415
# Total weighted fitting error: 6.806
# Total weighted fitting error: 6.511
# Total weighted fitting error: 6.055
# Total weighted fitting error: 5.567
# Total weighted fitting error: 5.495
# Total weighted fitting error: 5.368
# Total weighted fitting error: 5.284
# Total weighted fitting error: 5.153
# Total weighted fitting error: 5.143
# Total weighted fitting error: 5.124
# Total weighted fitting error: 5.088
# Total weighted fitting error: 5.028
# Total weighted fitting error: 5.024
# Total weighted fitting error: 4.991
# Total weighted fitting error: 4.947
# Total weighted fitting error: 4.943
# Total weighted fitting error: 4.908
# Total weighted fitting error: 4.846
# Total weighted fitting error: 4.839
# Total weighted fitting error: 4.825
# Total weighted fitting error: 4.800
# Total weighted fitting error: 4.796
# Total weighted fitting error: 4.759
# Total weighted fitting error: 4.726
# Total weighted fitting error: 4.723
# Total weighted fitting error: 4.693
# Total weighted fitting error: 4.692
# Total weighted fitting error: 4.637
# Total weighted fitting error: 4.636
# Total weighted fitting error: 4.630
# Total weighted fitting error: 4.618
# Total weighted fitting error: 4.599
# Total weighted fitting error: 4.598
# Total weighted fitting error: 4.597
# Total weighted fitting error: 4.584
# Total weighted fitting error: 4.584
# Evidence -235.369
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 4.10e-02
# Total weighted fitting error: 113.231
# Total weighted fitting error: 113.228
# Total weighted fitting error: 113.097
# Total weighted fitting error: 112.852
# Total weighted fitting error: 112.418
# Total weighted fitting error: 112.339
# Total weighted fitting error: 112.302
# Total weighted fitting error: 112.233
# Total weighted fitting error: 112.106
# Total weighted fitting error: 111.892
# Total weighted fitting error: 111.892
# Evidence 3599.535
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 4.48e-01
# Total weighted fitting error: 797.851
# Total weighted fitting error: 794.727
# Total weighted fitting error: 790.400
# Total weighted fitting error: 789.931
# Total weighted fitting error: 785.625
# Total weighted fitting error: 777.987
# Total weighted fitting error: 777.968
# Total weighted fitting error: 775.092
# Total weighted fitting error: 770.315
# Total weighted fitting error: 770.300
# Total weighted fitting error: 769.740
# Total weighted fitting error: 768.801
# Total weighted fitting error: 767.049
# Total weighted fitting error: 766.941
# Total weighted fitting error: 763.314
# Total weighted fitting error: 763.280
# Total weighted fitting error: 763.216
# Total weighted fitting error: 763.104
# Total weighted fitting error: 762.905
# Total weighted fitting error: 761.159
# Total weighted fitting error: 761.137
# Total weighted fitting error: 760.943
# Total weighted fitting error: 759.328
# Total weighted fitting error: 759.300
# Total weighted fitting error: 759.085
# Total weighted fitting error: 758.685
# Total weighted fitting error: 758.657
# Total weighted fitting error: 757.623
# Total weighted fitting error: 757.606
# Total weighted fitting error: 757.572
# Total weighted fitting error: 757.511
# Total weighted fitting error: 757.406
# Total weighted fitting error: 757.397
# Total weighted fitting error: 757.035
# Total weighted fitting error: 756.472
# Total weighted fitting error: 756.456
# Total weighted fitting error: 756.424
# Total weighted fitting error: 756.368
# Total weighted fitting error: 755.945
# Total weighted fitting error: 755.878
# Total weighted fitting error: 755.817
# Total weighted fitting error: 755.803
# Total weighted fitting error: 755.671
# Total weighted fitting error: 755.445
# Total weighted fitting error: 755.437
# Total weighted fitting error: 755.376
# Total weighted fitting error: 755.375
# Total weighted fitting error: 755.284
# Total weighted fitting error: 755.201
# Total weighted fitting error: 755.201
# Total weighted fitting error: 755.151
# Total weighted fitting error: 755.144
# Total weighted fitting error: 755.082
# Total weighted fitting error: 755.082
# Total weighted fitting error: 755.061
# Total weighted fitting error: 755.025
# Total weighted fitting error: 755.024
# Total weighted fitting error: 755.021
# Total weighted fitting error: 755.016
# Total weighted fitting error: 754.976
# Total weighted fitting error: 754.975
# Total weighted fitting error: 754.968
# Total weighted fitting error: 754.953
# Total weighted fitting error: 754.951
# Total weighted fitting error: 754.946
# Total weighted fitting error: 754.946
# Total weighted fitting error: 754.934
# Total weighted fitting error: 754.933
# Evidence 5456.367
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 5.71e-01
# Total weighted fitting error: 1089.739
# Total weighted fitting error: 1089.178
# Total weighted fitting error: 1088.182
# Total weighted fitting error: 1086.796
# Total weighted fitting error: 1084.370
# Total weighted fitting error: 1081.145
# Total weighted fitting error: 1081.107
# Total weighted fitting error: 1081.034
# Total weighted fitting error: 1080.901
# Total weighted fitting error: 1079.852
# Total weighted fitting error: 1079.841
# Total weighted fitting error: 1079.747
# Total weighted fitting error: 1078.938
# Total weighted fitting error: 1078.924
# Total weighted fitting error: 1078.411
# Total weighted fitting error: 1078.330
# Total weighted fitting error: 1078.176
# Total weighted fitting error: 1077.903
# Total weighted fitting error: 1077.889
# Total weighted fitting error: 1077.757
# Total weighted fitting error: 1077.535
# Total weighted fitting error: 1077.510
# Total weighted fitting error: 1077.298
# Total weighted fitting error: 1077.272
# Total weighted fitting error: 1077.261
# Total weighted fitting error: 1077.256
# Total weighted fitting error: 1077.209
# Total weighted fitting error: 1077.207
# Total weighted fitting error: 1077.133
# Total weighted fitting error: 1077.068
# Total weighted fitting error: 1077.060
# Total weighted fitting error: 1077.057
# Total weighted fitting error: 1077.028
# Total weighted fitting error: 1077.027
# Total weighted fitting error: 1076.989
# Total weighted fitting error: 1076.987
# Total weighted fitting error: 1076.973
# Total weighted fitting error: 1076.970
# Total weighted fitting error: 1076.969
# Total weighted fitting error: 1076.969
# Evidence 5646.497
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 4.84e-01
# Total weighted fitting error: 1120.926
# Total weighted fitting error: 1119.794
# Total weighted fitting error: 1118.734
# Total weighted fitting error: 1117.606
# Total weighted fitting error: 1117.596
# Evidence 5664.433
# Updating hyper-parameters...
# Total samples: 282, Updated regularization: 4.87e-01
# Total weighted fitting error: 1124.493
# Total weighted fitting error: 1124.124
# Total weighted fitting error: 1123.709
# Total weighted fitting error: 1123.116
# Total weighted fitting error: 1123.115
# Evidence 5668.734
# Pass count  1
# Elapsed time 52.69s
