# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy.stats import norm, linregress

import os
import time
import itertools

from glove.mse_model import *

from sklearn.model_selection import KFold
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# import file names
files = os.listdir("data/")
files = [f for f in files if "processed" in f]
files = files[:1]
files
# Out:
# ['EXP0019_MS001_processed.csv']

# %% [markdown]
# # Function to make predictions on test data

# %%
def predict(df, species):
    
    # save measured and predicted values
    pred_species = []
    pred = []
    stdv = []
    true = []

    # pull just the community data
    test_data = process_df(df, species) 

    # plot the results
    for exp, t_span, Y_m in test_data:

        # increase evaluation time
        t_eval = np.linspace(t_span[0], t_span[-1])

        # predict 
        Y_p, Y_l, _ = model.predict(Y_m, t_eval)
        Y_std = Y_p - Y_l
        
        # set NaN to zero
        Y_p = np.nan_to_num(Y_p)
        Y_std = np.nan_to_num(Y_std)

        ### append only end-point prediction results for non-zero outcomes ###
        inds_pos = Y_m[-1,:] > 0 
        pred_species.append(np.array(species)[inds_pos])
        true.append(Y_m[-1,:][inds_pos])
        pred.append(Y_p[-1,:][inds_pos])
        stdv.append(Y_std[-1,:][inds_pos])
        
    # concatenate list
    pred_species = np.concatenate(pred_species)
    true = np.concatenate(true)
    pred = np.concatenate(pred)
    stdv = np.concatenate(stdv)
        
    return pred_species, true, pred, stdv

# %%
# run kfold for each file 
for file in files:
    
    # import data
    df = pd.read_csv(f"data/{file}")

    # determine species names 
    species = df.columns.values[2:]

    # separate mono culture data 
    # mono_df = pd.concat([df_i for name, df_i in df.groupby("Treatments") if "Mono" in name])
    dfs = [df_i for name, df_i in df.groupby("Treatments") if "Mono" not in name]

    # init kfold object
    kf = KFold(n_splits=10, shuffle=True, random_state=21)

    # keep track of all predictions
    all_pred_species = []
    all_true = []
    all_pred = []
    all_stdv = []

    # run Kfold 
    for train_index, test_index in kf.split(dfs):
        # get train df 
        train_df = pd.concat([dfs[i] for i in train_index])
        # train_df = pd.concat((mono_df, train_df))

        # get test df
        test_df = pd.concat([dfs[i] for i in test_index])

        # instantiate gLV fit 
        model = gLV(species, train_df)

        # fit to data 
        model.fit(alpha_0=1.)

        # plot fitness to data
        pred_species, true, pred, stdv = predict(test_df, species)

        # append predictions 
        all_pred_species = np.append(all_pred_species, pred_species)
        all_true = np.append(all_true, true)
        all_pred = np.append(all_pred, pred)
        all_stdv = np.append(all_stdv, stdv)

    # save prediction results to a .csv
    strain = file.split("_")[1]
    kfold_df = pd.DataFrame()
    kfold_df['species'] = all_pred_species
    kfold_df['true'] = all_true
    kfold_df['pred'] = all_pred
    kfold_df['stdv'] = all_stdv
    kfold_df.to_csv(f"kfold/{strain}_kfold.csv", index=False)
        
    # show prediction performance of individual species
    for sp in species:
        sp_inds = all_pred_species == sp
        R = linregress(all_true[sp_inds], all_pred[sp_inds]).rvalue
        plt.scatter(all_true[sp_inds], all_pred[sp_inds], label=f"{sp} " + "R={:.3f}".format(R))
        plt.errorbar(all_true[sp_inds], all_pred[sp_inds], yerr=all_stdv[sp_inds], 
                     fmt='.', capsize=3)

    plt.xlabel("Measured OD")
    plt.ylabel("Predicted OD")
    plt.legend()
    plt.title(strain)
    plt.savefig(f"kfold/{strain}_kfold.pdf", dpi=300)
    plt.show()
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Total samples: 94, Updated regularization: 1.00e+00
# Total weighted fitting error: 12.349
# Total weighted fitting error: 7.900
# Total weighted fitting error: 6.227
# Total weighted fitting error: 6.006
# Total weighted fitting error: 5.755
# Total weighted fitting error: 5.649
# Total weighted fitting error: 5.595
# Total weighted fitting error: 5.578
# Total weighted fitting error: 5.574
# Total weighted fitting error: 5.568
# Total weighted fitting error: 5.567
# Total weighted fitting error: 5.566
# Total weighted fitting error: 5.566
# Total weighted fitting error: 5.566
# Total weighted fitting error: 5.566
# Total weighted fitting error: 5.566
# Total weighted fitting error: 5.566
# Total weighted fitting error: 5.566
# Total weighted fitting error: 5.565
# Total weighted fitting error: 5.565
# Evidence -51.365
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.84e+00
# Total weighted fitting error: 60.240
# Total weighted fitting error: 58.324
# Total weighted fitting error: 58.178
# Total weighted fitting error: 57.916
# Total weighted fitting error: 57.516
# Total weighted fitting error: 56.874
# Total weighted fitting error: 56.162
# Total weighted fitting error: 56.038
# Total weighted fitting error: 55.911
# Total weighted fitting error: 55.766
# Total weighted fitting error: 55.745
# Total weighted fitting error: 55.733
# Total weighted fitting error: 55.728
# Total weighted fitting error: 55.720
# Total weighted fitting error: 55.714
# Total weighted fitting error: 55.713
# Total weighted fitting error: 55.713
# Total weighted fitting error: 55.712
# Total weighted fitting error: 55.712
# Total weighted fitting error: 55.712
# Total weighted fitting error: 55.712
# Total weighted fitting error: 55.712
# Total weighted fitting error: 55.712
# Total weighted fitting error: 55.712
# Total weighted fitting error: 55.712
# Total weighted fitting error: 55.712
# Evidence 935.487
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 3.38e+00
# Total weighted fitting error: 193.636
# Total weighted fitting error: 192.409
# Total weighted fitting error: 190.684
# Total weighted fitting error: 189.157
# Total weighted fitting error: 189.098
# Total weighted fitting error: 188.985
# Total weighted fitting error: 188.788
# Total weighted fitting error: 188.487
# Total weighted fitting error: 188.427
# Total weighted fitting error: 187.921
# Total weighted fitting error: 187.914
# Total weighted fitting error: 187.658
# Total weighted fitting error: 187.321
# Total weighted fitting error: 187.298
# Total weighted fitting error: 187.262
# Total weighted fitting error: 187.205
# Total weighted fitting error: 187.199
# Total weighted fitting error: 187.188
# Total weighted fitting error: 187.171
# Total weighted fitting error: 187.168
# Total weighted fitting error: 187.161
# Total weighted fitting error: 187.161
# Total weighted fitting error: 187.158
# Total weighted fitting error: 187.153
# Total weighted fitting error: 187.152
# Total weighted fitting error: 187.149
# Total weighted fitting error: 187.145
# Total weighted fitting error: 187.145
# Total weighted fitting error: 187.144
# Total weighted fitting error: 187.143
# Total weighted fitting error: 187.143
# Total weighted fitting error: 187.143
# Total weighted fitting error: 187.143
# Total weighted fitting error: 187.142
# Total weighted fitting error: 187.142
# Total weighted fitting error: 187.142
# Total weighted fitting error: 187.142
# Evidence 1453.575
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.72e+00
# Total weighted fitting error: 321.782
# Total weighted fitting error: 318.932
# Total weighted fitting error: 314.782
# Total weighted fitting error: 312.172
# Total weighted fitting error: 312.123
# Total weighted fitting error: 312.042
# Total weighted fitting error: 311.902
# Total weighted fitting error: 311.676
# Total weighted fitting error: 311.382
# Total weighted fitting error: 311.376
# Total weighted fitting error: 311.327
# Total weighted fitting error: 311.251
# Total weighted fitting error: 311.250
# Total weighted fitting error: 311.238
# Total weighted fitting error: 311.235
# Total weighted fitting error: 311.227
# Total weighted fitting error: 311.215
# Total weighted fitting error: 311.214
# Total weighted fitting error: 311.204
# Total weighted fitting error: 311.204
# Total weighted fitting error: 311.199
# Total weighted fitting error: 311.199
# Total weighted fitting error: 311.198
# Total weighted fitting error: 311.197
# Evidence 1612.898
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.88e+00
# Total weighted fitting error: 362.917
# Total weighted fitting error: 362.058
# Total weighted fitting error: 360.929
# Total weighted fitting error: 360.902
# Total weighted fitting error: 360.647
# Total weighted fitting error: 360.521
# Total weighted fitting error: 360.289
# Total weighted fitting error: 359.920
# Total weighted fitting error: 359.914
# Total weighted fitting error: 359.705
# Total weighted fitting error: 359.701
# Total weighted fitting error: 359.564
# Total weighted fitting error: 359.558
# Total weighted fitting error: 359.506
# Total weighted fitting error: 359.421
# Total weighted fitting error: 359.420
# Total weighted fitting error: 359.391
# Total weighted fitting error: 359.389
# Total weighted fitting error: 359.389
# Total weighted fitting error: 359.373
# Total weighted fitting error: 359.371
# Total weighted fitting error: 359.371
# Total weighted fitting error: 359.371
# Total weighted fitting error: 359.367
# Total weighted fitting error: 359.367
# Total weighted fitting error: 359.365
# Total weighted fitting error: 359.365
# Evidence 1638.750
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.38e+00
# Total weighted fitting error: 371.216
# Total weighted fitting error: 370.900
# Total weighted fitting error: 370.430
# Total weighted fitting error: 370.416
# Total weighted fitting error: 370.280
# Total weighted fitting error: 370.062
# Total weighted fitting error: 370.035
# Total weighted fitting error: 369.794
# Total weighted fitting error: 369.787
# Total weighted fitting error: 369.713
# Total weighted fitting error: 369.581
# Total weighted fitting error: 369.512
# Total weighted fitting error: 369.511
# Total weighted fitting error: 369.508
# Total weighted fitting error: 369.504
# Total weighted fitting error: 369.463
# Total weighted fitting error: 369.394
# Total weighted fitting error: 369.392
# Total weighted fitting error: 369.341
# Total weighted fitting error: 369.341
# Total weighted fitting error: 369.340
# Total weighted fitting error: 369.321
# Total weighted fitting error: 369.320
# Total weighted fitting error: 369.316
# Total weighted fitting error: 369.308
# Total weighted fitting error: 369.308
# Evidence 1646.477
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 9.79e-01
# Total weighted fitting error: 372.929
# Total weighted fitting error: 372.646
# Total weighted fitting error: 372.638
# Total weighted fitting error: 372.563
# Total weighted fitting error: 372.434
# Total weighted fitting error: 372.296
# Total weighted fitting error: 372.287
# Total weighted fitting error: 372.274
# Total weighted fitting error: 372.163
# Total weighted fitting error: 372.011
# Total weighted fitting error: 372.003
# Total weighted fitting error: 371.997
# Total weighted fitting error: 371.986
# Total weighted fitting error: 371.976
# Total weighted fitting error: 371.974
# Total weighted fitting error: 371.964
# Total weighted fitting error: 371.963
# Total weighted fitting error: 371.957
# Total weighted fitting error: 371.945
# Total weighted fitting error: 371.943
# Total weighted fitting error: 371.934
# Total weighted fitting error: 371.934
# Total weighted fitting error: 371.931
# Total weighted fitting error: 371.926
# Total weighted fitting error: 371.926
# Total weighted fitting error: 371.926
# Evidence 1650.485
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 6.73e-01
# Total weighted fitting error: 373.610
# Total weighted fitting error: 373.545
# Total weighted fitting error: 373.437
# Total weighted fitting error: 373.262
# Total weighted fitting error: 373.238
# Total weighted fitting error: 373.195
# Total weighted fitting error: 373.130
# Total weighted fitting error: 373.126
# Total weighted fitting error: 373.092
# Total weighted fitting error: 373.087
# Total weighted fitting error: 373.077
# Total weighted fitting error: 373.060
# Total weighted fitting error: 373.060
# Total weighted fitting error: 373.049
# Total weighted fitting error: 373.028
# Total weighted fitting error: 372.998
# Total weighted fitting error: 372.996
# Total weighted fitting error: 372.994
# Total weighted fitting error: 372.990
# Total weighted fitting error: 372.989
# Total weighted fitting error: 372.988
# Total weighted fitting error: 372.968
# Total weighted fitting error: 372.937
# Total weighted fitting error: 372.936
# Total weighted fitting error: 372.935
# Total weighted fitting error: 372.927
# Total weighted fitting error: 372.927
# Evidence 1652.796
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 4.97e-01
# Total weighted fitting error: 373.786
# Total weighted fitting error: 373.738
# Total weighted fitting error: 373.657
# Total weighted fitting error: 373.539
# Total weighted fitting error: 373.526
# Total weighted fitting error: 373.501
# Total weighted fitting error: 373.490
# Total weighted fitting error: 373.470
# Total weighted fitting error: 373.466
# Total weighted fitting error: 373.432
# Total weighted fitting error: 373.380
# Total weighted fitting error: 373.380
# Total weighted fitting error: 373.375
# Total weighted fitting error: 373.365
# Total weighted fitting error: 373.349
# Total weighted fitting error: 373.348
# Total weighted fitting error: 373.345
# Total weighted fitting error: 373.339
# Total weighted fitting error: 373.339
# Total weighted fitting error: 373.330
# Total weighted fitting error: 373.314
# Total weighted fitting error: 373.310
# Total weighted fitting error: 373.309
# Total weighted fitting error: 373.309
# Total weighted fitting error: 373.299
# Total weighted fitting error: 373.291
# Total weighted fitting error: 373.290
# Total weighted fitting error: 373.290
# Total weighted fitting error: 373.289
# Total weighted fitting error: 373.288
# Total weighted fitting error: 373.278
# Total weighted fitting error: 373.278
# Total weighted fitting error: 373.278
# Total weighted fitting error: 373.273
# Total weighted fitting error: 373.273
# Total weighted fitting error: 373.272
# Total weighted fitting error: 373.272
# Total weighted fitting error: 373.272
# Total weighted fitting error: 373.270
# Total weighted fitting error: 373.270
# Evidence 1654.514
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 3.72e-01
# Total weighted fitting error: 373.769
# Total weighted fitting error: 373.721
# Total weighted fitting error: 373.645
# Total weighted fitting error: 373.539
# Total weighted fitting error: 373.535
# Total weighted fitting error: 373.500
# Total weighted fitting error: 373.441
# Total weighted fitting error: 373.430
# Total weighted fitting error: 373.410
# Total weighted fitting error: 373.376
# Total weighted fitting error: 373.375
# Total weighted fitting error: 373.348
# Total weighted fitting error: 373.343
# Total weighted fitting error: 373.335
# Total weighted fitting error: 373.330
# Total weighted fitting error: 373.330
# Total weighted fitting error: 373.323
# Total weighted fitting error: 373.322
# Total weighted fitting error: 373.318
# Total weighted fitting error: 373.316
# Total weighted fitting error: 373.316
# Total weighted fitting error: 373.315
# Total weighted fitting error: 373.312
# Total weighted fitting error: 373.312
# Total weighted fitting error: 373.312
# Total weighted fitting error: 373.311
# Total weighted fitting error: 373.311
# Total weighted fitting error: 373.304
# Total weighted fitting error: 373.304
# Total weighted fitting error: 373.303
# Total weighted fitting error: 373.301
# Total weighted fitting error: 373.299
# Total weighted fitting error: 373.299
# Evidence 1656.206
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 3.04e-01
# Total weighted fitting error: 373.610
# Total weighted fitting error: 373.556
# Total weighted fitting error: 373.462
# Total weighted fitting error: 373.383
# Total weighted fitting error: 373.267
# Total weighted fitting error: 373.264
# Total weighted fitting error: 373.238
# Total weighted fitting error: 373.193
# Total weighted fitting error: 373.128
# Total weighted fitting error: 373.124
# Total weighted fitting error: 373.119
# Total weighted fitting error: 373.110
# Total weighted fitting error: 373.094
# Total weighted fitting error: 373.091
# Total weighted fitting error: 373.085
# Total weighted fitting error: 373.075
# Total weighted fitting error: 373.075
# Total weighted fitting error: 373.072
# Total weighted fitting error: 373.066
# Total weighted fitting error: 373.063
# Total weighted fitting error: 373.063
# Total weighted fitting error: 373.059
# Total weighted fitting error: 373.059
# Total weighted fitting error: 373.059
# Total weighted fitting error: 373.058
# Total weighted fitting error: 373.057
# Total weighted fitting error: 373.057
# Total weighted fitting error: 373.056
# Total weighted fitting error: 373.055
# Total weighted fitting error: 373.055
# Evidence 1658.098
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.67e-01
# Total weighted fitting error: 373.358
# Total weighted fitting error: 373.307
# Total weighted fitting error: 373.216
# Total weighted fitting error: 373.065
# Total weighted fitting error: 373.015
# Total weighted fitting error: 372.930
# Total weighted fitting error: 372.842
# Total weighted fitting error: 372.840
# Total weighted fitting error: 372.837
# Total weighted fitting error: 372.813
# Total weighted fitting error: 372.778
# Total weighted fitting error: 372.774
# Total weighted fitting error: 372.768
# Total weighted fitting error: 372.757
# Total weighted fitting error: 372.757
# Total weighted fitting error: 372.753
# Total weighted fitting error: 372.745
# Total weighted fitting error: 372.745
# Total weighted fitting error: 372.745
# Total weighted fitting error: 372.740
# Total weighted fitting error: 372.740
# Evidence 1660.143
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.45e-01
# Total weighted fitting error: 372.998
# Total weighted fitting error: 372.813
# Total weighted fitting error: 372.804
# Total weighted fitting error: 372.732
# Total weighted fitting error: 372.653
# Total weighted fitting error: 372.650
# Total weighted fitting error: 372.647
# Total weighted fitting error: 372.620
# Total weighted fitting error: 372.596
# Total weighted fitting error: 372.595
# Total weighted fitting error: 372.593
# Total weighted fitting error: 372.592
# Total weighted fitting error: 372.588
# Total weighted fitting error: 372.588
# Evidence 1661.972
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.32e-01
# Total weighted fitting error: 372.925
# Total weighted fitting error: 372.894
# Total weighted fitting error: 372.838
# Total weighted fitting error: 372.760
# Total weighted fitting error: 372.729
# Total weighted fitting error: 372.725
# Total weighted fitting error: 372.719
# Total weighted fitting error: 372.708
# Total weighted fitting error: 372.708
# Total weighted fitting error: 372.708
# Evidence 1663.239
# Pass count  1
# Total samples: 94, Updated regularization: 1.00e+00
# Total weighted fitting error: 12.795
# Total weighted fitting error: 7.956
# Total weighted fitting error: 6.580
# Total weighted fitting error: 6.354
# Total weighted fitting error: 6.019
# Total weighted fitting error: 5.747
# Total weighted fitting error: 5.643
# Total weighted fitting error: 5.585
# Total weighted fitting error: 5.550
# Total weighted fitting error: 5.541
# Total weighted fitting error: 5.536
# Total weighted fitting error: 5.534
# Total weighted fitting error: 5.532
# Total weighted fitting error: 5.532
# Total weighted fitting error: 5.532
# Total weighted fitting error: 5.532
# Total weighted fitting error: 5.531
# Total weighted fitting error: 5.531
# Total weighted fitting error: 5.531
# Evidence -50.134
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.78e+00
# Total weighted fitting error: 61.141
# Total weighted fitting error: 59.463
# Total weighted fitting error: 58.896
# Total weighted fitting error: 58.054
# Total weighted fitting error: 57.341
# Total weighted fitting error: 57.164
# Total weighted fitting error: 57.045
# Total weighted fitting error: 56.943
# Total weighted fitting error: 56.895
# Total weighted fitting error: 56.840
# Total weighted fitting error: 56.805
# Total weighted fitting error: 56.784
# Total weighted fitting error: 56.777
# Total weighted fitting error: 56.774
# Total weighted fitting error: 56.770
# Total weighted fitting error: 56.765
# Total weighted fitting error: 56.765
# Total weighted fitting error: 56.763
# Total weighted fitting error: 56.761
# Total weighted fitting error: 56.761
# Total weighted fitting error: 56.760
# Total weighted fitting error: 56.760
# Total weighted fitting error: 56.760
# Total weighted fitting error: 56.759
# Total weighted fitting error: 56.759
# Total weighted fitting error: 56.759
# Total weighted fitting error: 56.759
# Total weighted fitting error: 56.759
# Total weighted fitting error: 56.759
# Total weighted fitting error: 56.759
# Total weighted fitting error: 56.759
# Evidence 954.499
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.98e+00
# Total weighted fitting error: 200.018
# Total weighted fitting error: 196.583
# Total weighted fitting error: 195.246
# Total weighted fitting error: 192.972
# Total weighted fitting error: 190.117
# Total weighted fitting error: 190.026
# Total weighted fitting error: 189.852
# Total weighted fitting error: 189.540
# Total weighted fitting error: 189.454
# Total weighted fitting error: 189.297
# Total weighted fitting error: 189.283
# Total weighted fitting error: 189.154
# Total weighted fitting error: 188.960
# Total weighted fitting error: 188.954
# Total weighted fitting error: 188.899
# Total weighted fitting error: 188.893
# Total weighted fitting error: 188.850
# Total weighted fitting error: 188.849
# Total weighted fitting error: 188.840
# Total weighted fitting error: 188.826
# Total weighted fitting error: 188.825
# Total weighted fitting error: 188.824
# Total weighted fitting error: 188.822
# Total weighted fitting error: 188.822
# Total weighted fitting error: 188.820
# Total weighted fitting error: 188.819
# Total weighted fitting error: 188.819
# Total weighted fitting error: 188.819
# Total weighted fitting error: 188.818
# Total weighted fitting error: 188.818
# Evidence 1482.096
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.13e+00
# Total weighted fitting error: 322.275
# Total weighted fitting error: 318.975
# Total weighted fitting error: 313.736
# Total weighted fitting error: 312.862
# Total weighted fitting error: 311.244
# Total weighted fitting error: 308.581
# Total weighted fitting error: 305.850
# Total weighted fitting error: 305.763
# Total weighted fitting error: 305.618
# Total weighted fitting error: 305.453
# Total weighted fitting error: 305.172
# Total weighted fitting error: 304.777
# Total weighted fitting error: 304.766
# Total weighted fitting error: 304.680
# Total weighted fitting error: 304.679
# Total weighted fitting error: 304.659
# Total weighted fitting error: 304.625
# Total weighted fitting error: 304.623
# Total weighted fitting error: 304.607
# Total weighted fitting error: 304.605
# Total weighted fitting error: 304.592
# Total weighted fitting error: 304.592
# Evidence 1657.876
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.16e+00
# Total weighted fitting error: 361.180
# Total weighted fitting error: 355.985
# Total weighted fitting error: 354.561
# Total weighted fitting error: 352.164
# Total weighted fitting error: 352.123
# Total weighted fitting error: 350.662
# Total weighted fitting error: 350.546
# Total weighted fitting error: 349.592
# Total weighted fitting error: 349.582
# Total weighted fitting error: 349.485
# Total weighted fitting error: 349.300
# Total weighted fitting error: 349.021
# Total weighted fitting error: 348.953
# Total weighted fitting error: 348.418
# Total weighted fitting error: 348.410
# Total weighted fitting error: 348.335
# Total weighted fitting error: 348.198
# Total weighted fitting error: 348.189
# Total weighted fitting error: 348.102
# Total weighted fitting error: 348.015
# Total weighted fitting error: 348.002
# Total weighted fitting error: 347.880
# Total weighted fitting error: 347.879
# Total weighted fitting error: 347.660
# Total weighted fitting error: 347.658
# Total weighted fitting error: 347.635
# Total weighted fitting error: 347.593
# Total weighted fitting error: 347.545
# Total weighted fitting error: 347.494
# Total weighted fitting error: 347.481
# Total weighted fitting error: 347.372
# Total weighted fitting error: 347.371
# Total weighted fitting error: 347.341
# Total weighted fitting error: 347.338
# Total weighted fitting error: 347.314
# Total weighted fitting error: 347.299
# Total weighted fitting error: 347.271
# Total weighted fitting error: 347.270
# Total weighted fitting error: 347.268
# Total weighted fitting error: 347.254
# Total weighted fitting error: 347.241
# Total weighted fitting error: 347.241
# Evidence 1704.640
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 5.49e-01
# Total weighted fitting error: 366.777
# Total weighted fitting error: 365.080
# Total weighted fitting error: 362.237
# Total weighted fitting error: 362.204
# Total weighted fitting error: 360.930
# Total weighted fitting error: 358.936
# Total weighted fitting error: 358.929
# Evidence 1731.405
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 4.84e-01
# Total weighted fitting error: 369.843
# Total weighted fitting error: 365.767
# Total weighted fitting error: 364.837
# Total weighted fitting error: 364.811
# Total weighted fitting error: 363.781
# Total weighted fitting error: 361.975
# Total weighted fitting error: 361.932
# Total weighted fitting error: 360.365
# Total weighted fitting error: 360.354
# Total weighted fitting error: 358.820
# Total weighted fitting error: 358.802
# Total weighted fitting error: 358.770
# Total weighted fitting error: 358.718
# Total weighted fitting error: 358.231
# Total weighted fitting error: 358.209
# Total weighted fitting error: 357.409
# Total weighted fitting error: 357.404
# Total weighted fitting error: 357.353
# Total weighted fitting error: 357.267
# Total weighted fitting error: 356.589
# Total weighted fitting error: 356.579
# Total weighted fitting error: 356.570
# Total weighted fitting error: 356.557
# Total weighted fitting error: 356.431
# Total weighted fitting error: 356.431
# Evidence 1751.415
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.45e-01
# Total weighted fitting error: 368.405
# Total weighted fitting error: 367.758
# Total weighted fitting error: 366.791
# Total weighted fitting error: 366.338
# Total weighted fitting error: 366.335
# Total weighted fitting error: 365.889
# Total weighted fitting error: 365.875
# Total weighted fitting error: 365.334
# Total weighted fitting error: 365.330
# Total weighted fitting error: 364.801
# Total weighted fitting error: 364.797
# Total weighted fitting error: 364.763
# Total weighted fitting error: 364.701
# Total weighted fitting error: 364.695
# Total weighted fitting error: 364.464
# Total weighted fitting error: 364.463
# Total weighted fitting error: 364.243
# Total weighted fitting error: 364.243
# Evidence 1765.555
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.01e-01
# Total weighted fitting error: 370.788
# Total weighted fitting error: 370.716
# Total weighted fitting error: 370.580
# Total weighted fitting error: 370.343
# Total weighted fitting error: 370.033
# Total weighted fitting error: 370.022
# Total weighted fitting error: 369.942
# Total weighted fitting error: 369.250
# Total weighted fitting error: 369.247
# Evidence 1770.405
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.87e-01
# Total weighted fitting error: 372.160
# Total weighted fitting error: 372.116
# Total weighted fitting error: 372.037
# Total weighted fitting error: 371.912
# Total weighted fitting error: 371.782
# Total weighted fitting error: 371.749
# Total weighted fitting error: 371.443
# Total weighted fitting error: 371.441
# Total weighted fitting error: 371.373
# Total weighted fitting error: 370.799
# Total weighted fitting error: 370.795
# Evidence 1773.064
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.67e-01
# Total weighted fitting error: 372.517
# Evidence 1773.659
# Pass count  1
# Total samples: 94, Updated regularization: 1.00e+00
# Total weighted fitting error: 13.035
# Total weighted fitting error: 7.978
# Total weighted fitting error: 6.169
# Total weighted fitting error: 5.998
# Total weighted fitting error: 5.717
# Total weighted fitting error: 5.567
# Total weighted fitting error: 5.529
# Total weighted fitting error: 5.507
# Total weighted fitting error: 5.503
# Total weighted fitting error: 5.501
# Total weighted fitting error: 5.500
# Total weighted fitting error: 5.500
# Total weighted fitting error: 5.500
# Total weighted fitting error: 5.500
# Total weighted fitting error: 5.500
# Total weighted fitting error: 5.500
# Total weighted fitting error: 5.500
# Total weighted fitting error: 5.500
# Total weighted fitting error: 5.500
# Total weighted fitting error: 5.500
# Evidence -48.600
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.75e+00
# Total weighted fitting error: 58.582
# Total weighted fitting error: 58.236
# Total weighted fitting error: 57.585
# Total weighted fitting error: 56.513
# Total weighted fitting error: 55.530
# Total weighted fitting error: 55.292
# Total weighted fitting error: 54.969
# Total weighted fitting error: 54.856
# Total weighted fitting error: 54.755
# Total weighted fitting error: 54.743
# Total weighted fitting error: 54.729
# Total weighted fitting error: 54.713
# Total weighted fitting error: 54.711
# Total weighted fitting error: 54.710
# Total weighted fitting error: 54.709
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Total weighted fitting error: 54.707
# Evidence 962.268
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.97e+00
# Total weighted fitting error: 194.432
# Total weighted fitting error: 192.309
# Total weighted fitting error: 189.362
# Total weighted fitting error: 189.281
# Total weighted fitting error: 188.594
# Total weighted fitting error: 187.716
# Total weighted fitting error: 187.693
# Total weighted fitting error: 187.516
# Total weighted fitting error: 187.289
# Total weighted fitting error: 187.280
# Total weighted fitting error: 187.265
# Total weighted fitting error: 187.255
# Total weighted fitting error: 187.238
# Total weighted fitting error: 187.206
# Total weighted fitting error: 187.205
# Total weighted fitting error: 187.172
# Total weighted fitting error: 187.167
# Total weighted fitting error: 187.128
# Total weighted fitting error: 187.126
# Total weighted fitting error: 187.123
# Total weighted fitting error: 187.100
# Total weighted fitting error: 187.098
# Total weighted fitting error: 187.096
# Total weighted fitting error: 187.092
# Total weighted fitting error: 187.085
# Total weighted fitting error: 187.085
# Total weighted fitting error: 187.080
# Total weighted fitting error: 187.079
# Total weighted fitting error: 187.078
# Total weighted fitting error: 187.073
# Total weighted fitting error: 187.073
# Evidence 1505.329
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.67e+00
# Total weighted fitting error: 323.899
# Total weighted fitting error: 321.325
# Total weighted fitting error: 317.124
# Total weighted fitting error: 311.454
# Total weighted fitting error: 311.086
# Total weighted fitting error: 307.998
# Total weighted fitting error: 307.733
# Total weighted fitting error: 305.654
# Total weighted fitting error: 305.609
# Total weighted fitting error: 305.200
# Total weighted fitting error: 304.545
# Total weighted fitting error: 304.522
# Total weighted fitting error: 304.315
# Total weighted fitting error: 304.216
# Total weighted fitting error: 304.198
# Total weighted fitting error: 304.053
# Total weighted fitting error: 304.051
# Total weighted fitting error: 303.982
# Total weighted fitting error: 303.982
# Total weighted fitting error: 303.959
# Total weighted fitting error: 303.949
# Total weighted fitting error: 303.948
# Total weighted fitting error: 303.937
# Total weighted fitting error: 303.937
# Total weighted fitting error: 303.933
# Total weighted fitting error: 303.930
# Total weighted fitting error: 303.930
# Total weighted fitting error: 303.929
# Evidence 1677.687
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.36e+00
# Total weighted fitting error: 360.281
# Total weighted fitting error: 358.484
# Total weighted fitting error: 355.612
# Total weighted fitting error: 352.623
# Total weighted fitting error: 352.371
# Total weighted fitting error: 351.964
# Total weighted fitting error: 351.292
# Total weighted fitting error: 350.436
# Total weighted fitting error: 350.423
# Total weighted fitting error: 350.402
# Total weighted fitting error: 350.231
# Total weighted fitting error: 350.228
# Total weighted fitting error: 350.138
# Total weighted fitting error: 350.132
# Total weighted fitting error: 350.082
# Total weighted fitting error: 350.081
# Total weighted fitting error: 350.069
# Total weighted fitting error: 350.049
# Total weighted fitting error: 350.049
# Total weighted fitting error: 350.044
# Total weighted fitting error: 350.042
# Evidence 1724.974
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 7.63e-01
# Total weighted fitting error: 369.464
# Total weighted fitting error: 368.842
# Total weighted fitting error: 368.324
# Total weighted fitting error: 367.685
# Total weighted fitting error: 367.575
# Total weighted fitting error: 367.386
# Total weighted fitting error: 367.091
# Total weighted fitting error: 367.080
# Total weighted fitting error: 366.977
# Total weighted fitting error: 366.800
# Total weighted fitting error: 366.778
# Total weighted fitting error: 366.605
# Total weighted fitting error: 366.603
# Total weighted fitting error: 366.589
# Total weighted fitting error: 366.561
# Total weighted fitting error: 366.513
# Total weighted fitting error: 366.512
# Total weighted fitting error: 366.482
# Total weighted fitting error: 366.482
# Total weighted fitting error: 366.473
# Total weighted fitting error: 366.459
# Total weighted fitting error: 366.458
# Total weighted fitting error: 366.457
# Total weighted fitting error: 366.457
# Total weighted fitting error: 366.457
# Total weighted fitting error: 366.454
# Total weighted fitting error: 366.450
# Total weighted fitting error: 366.450
# Evidence 1738.163
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 5.17e-01
# Total weighted fitting error: 372.856
# Total weighted fitting error: 372.666
# Total weighted fitting error: 372.361
# Total weighted fitting error: 371.943
# Total weighted fitting error: 371.814
# Total weighted fitting error: 371.806
# Total weighted fitting error: 371.729
# Total weighted fitting error: 371.591
# Total weighted fitting error: 371.444
# Total weighted fitting error: 371.419
# Total weighted fitting error: 371.414
# Total weighted fitting error: 371.366
# Total weighted fitting error: 371.286
# Total weighted fitting error: 371.284
# Total weighted fitting error: 371.228
# Total weighted fitting error: 371.224
# Total weighted fitting error: 371.182
# Total weighted fitting error: 371.182
# Total weighted fitting error: 371.169
# Total weighted fitting error: 371.145
# Total weighted fitting error: 371.136
# Total weighted fitting error: 371.133
# Total weighted fitting error: 371.132
# Total weighted fitting error: 371.121
# Total weighted fitting error: 371.120
# Total weighted fitting error: 371.113
# Total weighted fitting error: 371.104
# Total weighted fitting error: 371.104
# Total weighted fitting error: 371.104
# Total weighted fitting error: 371.103
# Evidence 1743.222
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 3.95e-01
# Total weighted fitting error: 373.568
# Total weighted fitting error: 373.199
# Total weighted fitting error: 372.724
# Total weighted fitting error: 372.493
# Total weighted fitting error: 372.425
# Total weighted fitting error: 372.405
# Total weighted fitting error: 372.247
# Total weighted fitting error: 372.244
# Total weighted fitting error: 372.130
# Total weighted fitting error: 372.129
# Total weighted fitting error: 372.070
# Total weighted fitting error: 371.984
# Total weighted fitting error: 371.983
# Total weighted fitting error: 371.980
# Total weighted fitting error: 371.975
# Total weighted fitting error: 371.968
# Total weighted fitting error: 371.967
# Total weighted fitting error: 371.926
# Total weighted fitting error: 371.924
# Total weighted fitting error: 371.909
# Total weighted fitting error: 371.908
# Total weighted fitting error: 371.902
# Total weighted fitting error: 371.891
# Total weighted fitting error: 371.890
# Total weighted fitting error: 371.890
# Total weighted fitting error: 371.886
# Total weighted fitting error: 371.885
# Total weighted fitting error: 371.885
# Total weighted fitting error: 371.882
# Total weighted fitting error: 371.882
# Total weighted fitting error: 371.881
# Total weighted fitting error: 371.880
# Total weighted fitting error: 371.880
# Total weighted fitting error: 371.879
# Total weighted fitting error: 371.879
# Evidence 1747.715
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.95e-01
# Total weighted fitting error: 373.565
# Total weighted fitting error: 373.092
# Total weighted fitting error: 372.665
# Total weighted fitting error: 372.652
# Total weighted fitting error: 372.534
# Total weighted fitting error: 372.331
# Total weighted fitting error: 372.312
# Total weighted fitting error: 372.149
# Total weighted fitting error: 372.147
# Total weighted fitting error: 372.062
# Total weighted fitting error: 372.051
# Total weighted fitting error: 371.946
# Total weighted fitting error: 371.945
# Total weighted fitting error: 371.903
# Total weighted fitting error: 371.829
# Total weighted fitting error: 371.821
# Total weighted fitting error: 371.805
# Total weighted fitting error: 371.779
# Total weighted fitting error: 371.779
# Evidence 1752.598
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 2.25e-01
# Total weighted fitting error: 373.580
# Total weighted fitting error: 373.207
# Total weighted fitting error: 372.857
# Total weighted fitting error: 372.820
# Total weighted fitting error: 372.491
# Total weighted fitting error: 372.487
# Total weighted fitting error: 372.332
# Total weighted fitting error: 372.259
# Total weighted fitting error: 372.241
# Total weighted fitting error: 372.079
# Total weighted fitting error: 372.077
# Total weighted fitting error: 371.904
# Total weighted fitting error: 371.903
# Total weighted fitting error: 371.764
# Total weighted fitting error: 371.746
# Total weighted fitting error: 371.732
# Total weighted fitting error: 371.725
# Total weighted fitting error: 371.653
# Total weighted fitting error: 371.652
# Total weighted fitting error: 371.613
# Total weighted fitting error: 371.599
# Total weighted fitting error: 371.597
# Total weighted fitting error: 371.512
# Total weighted fitting error: 371.512
# Total weighted fitting error: 371.491
# Total weighted fitting error: 371.471
# Total weighted fitting error: 371.471
# Total weighted fitting error: 371.454
# Total weighted fitting error: 371.450
# Total weighted fitting error: 371.449
# Total weighted fitting error: 371.448
# Total weighted fitting error: 371.447
# Total weighted fitting error: 371.447
# Total weighted fitting error: 371.403
# Total weighted fitting error: 371.402
# Total weighted fitting error: 371.396
# Total weighted fitting error: 371.394
# Total weighted fitting error: 371.393
# Total weighted fitting error: 371.388
# Total weighted fitting error: 371.387
# Total weighted fitting error: 371.387
# Total weighted fitting error: 371.374
# Total weighted fitting error: 371.374
# Total weighted fitting error: 371.373
# Total weighted fitting error: 371.370
# Total weighted fitting error: 371.370
# Total weighted fitting error: 371.369
# Total weighted fitting error: 371.363
# Total weighted fitting error: 371.363
# Total weighted fitting error: 371.363
# Total weighted fitting error: 371.360
# Total weighted fitting error: 371.360
# Total weighted fitting error: 371.360
# Total weighted fitting error: 371.357
# Evidence 1757.728
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.34e-01
# Total weighted fitting error: 370.357
# Total weighted fitting error: 370.215
# Total weighted fitting error: 368.917
# Total weighted fitting error: 367.705
# Total weighted fitting error: 367.697
# Total weighted fitting error: 367.638
# Total weighted fitting error: 367.529
# Total weighted fitting error: 367.352
# Total weighted fitting error: 367.351
# Evidence 1766.644
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.30e-01
# Total weighted fitting error: 371.764
# Total weighted fitting error: 371.602
# Total weighted fitting error: 370.250
# Total weighted fitting error: 368.206
# Total weighted fitting error: 368.174
# Evidence 1777.334
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.30e-01
# Total weighted fitting error: 373.021
# Total weighted fitting error: 372.906
# Total weighted fitting error: 371.969
# Total weighted fitting error: 370.582
# Total weighted fitting error: 370.566
# Evidence 1781.810
# Updating hyper-parameters...
# Total samples: 94, Updated regularization: 1.29e-01
# Total weighted fitting error: 373.510
# Evidence 1782.806
# Pass count  1
# Total samples: 96, Updated regularization: 1.00e+00
# Total weighted fitting error: 13.345
# Total weighted fitting error: 8.541
# Total weighted fitting error: 7.251
# Total weighted fitting error: 6.320
# Total weighted fitting error: 5.865
# Total weighted fitting error: 5.742
# Total weighted fitting error: 5.725
# Total weighted fitting error: 5.693
# Total weighted fitting error: 5.647
# Total weighted fitting error: 5.637
# Total weighted fitting error: 5.628
# Total weighted fitting error: 5.626
# Total weighted fitting error: 5.625
# Total weighted fitting error: 5.625
# Total weighted fitting error: 5.625
# Total weighted fitting error: 5.625
# Total weighted fitting error: 5.625
# Total weighted fitting error: 5.625
# Total weighted fitting error: 5.625
# Total weighted fitting error: 5.625
# Evidence -52.663
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.86e+00
# Total weighted fitting error: 60.277
# Total weighted fitting error: 58.388
# Total weighted fitting error: 57.316
# Total weighted fitting error: 57.063
# Total weighted fitting error: 56.675
# Total weighted fitting error: 56.440
# Total weighted fitting error: 56.411
# Total weighted fitting error: 56.375
# Total weighted fitting error: 56.372
# Total weighted fitting error: 56.365
# Total weighted fitting error: 56.358
# Total weighted fitting error: 56.353
# Total weighted fitting error: 56.353
# Total weighted fitting error: 56.352
# Total weighted fitting error: 56.352
# Total weighted fitting error: 56.352
# Total weighted fitting error: 56.351
# Total weighted fitting error: 56.351
# Total weighted fitting error: 56.351
# Total weighted fitting error: 56.351
# Total weighted fitting error: 56.351
# Total weighted fitting error: 56.351
# Evidence 962.095
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 3.40e+00
# Total weighted fitting error: 199.341
# Total weighted fitting error: 198.058
# Total weighted fitting error: 195.901
# Total weighted fitting error: 193.273
# Total weighted fitting error: 193.217
# Total weighted fitting error: 193.129
# Total weighted fitting error: 192.969
# Total weighted fitting error: 192.716
# Total weighted fitting error: 192.566
# Total weighted fitting error: 192.549
# Total weighted fitting error: 192.538
# Total weighted fitting error: 192.519
# Total weighted fitting error: 192.493
# Total weighted fitting error: 192.490
# Total weighted fitting error: 192.486
# Total weighted fitting error: 192.484
# Total weighted fitting error: 192.482
# Total weighted fitting error: 192.479
# Total weighted fitting error: 192.479
# Total weighted fitting error: 192.477
# Total weighted fitting error: 192.477
# Total weighted fitting error: 192.476
# Total weighted fitting error: 192.476
# Total weighted fitting error: 192.476
# Evidence 1501.988
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 3.28e+00
# Total weighted fitting error: 325.189
# Total weighted fitting error: 321.661
# Total weighted fitting error: 317.165
# Total weighted fitting error: 317.079
# Total weighted fitting error: 316.298
# Total weighted fitting error: 315.103
# Total weighted fitting error: 315.054
# Total weighted fitting error: 314.616
# Total weighted fitting error: 313.956
# Total weighted fitting error: 313.953
# Total weighted fitting error: 313.926
# Total weighted fitting error: 313.878
# Total weighted fitting error: 313.787
# Total weighted fitting error: 313.694
# Total weighted fitting error: 313.586
# Total weighted fitting error: 313.577
# Total weighted fitting error: 313.563
# Total weighted fitting error: 313.547
# Total weighted fitting error: 313.543
# Total weighted fitting error: 313.538
# Total weighted fitting error: 313.531
# Total weighted fitting error: 313.530
# Total weighted fitting error: 313.529
# Total weighted fitting error: 313.527
# Total weighted fitting error: 313.526
# Evidence 1677.015
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 2.52e+00
# Total weighted fitting error: 366.605
# Total weighted fitting error: 365.022
# Total weighted fitting error: 363.446
# Total weighted fitting error: 363.421
# Evidence 1712.090
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 2.51e+00
# Total weighted fitting error: 376.297
# Total weighted fitting error: 374.608
# Total weighted fitting error: 374.599
# Evidence 1721.424
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 2.43e+00
# Total weighted fitting error: 378.384
# Total weighted fitting error: 375.523
# Total weighted fitting error: 375.520
# Evidence 1729.602
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 2.22e+00
# Total weighted fitting error: 378.244
# Total weighted fitting error: 376.696
# Total weighted fitting error: 376.586
# Total weighted fitting error: 372.913
# Total weighted fitting error: 372.905
# Evidence 1740.259
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.85e+00
# Total weighted fitting error: 378.371
# Total weighted fitting error: 377.629
# Total weighted fitting error: 376.431
# Total weighted fitting error: 374.220
# Total weighted fitting error: 373.916
# Total weighted fitting error: 371.253
# Total weighted fitting error: 371.240
# Total weighted fitting error: 370.796
# Total weighted fitting error: 370.768
# Total weighted fitting error: 369.698
# Total weighted fitting error: 369.697
# Evidence 1754.535
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.46e+00
# Total weighted fitting error: 376.954
# Total weighted fitting error: 376.481
# Total weighted fitting error: 375.627
# Total weighted fitting error: 374.300
# Total weighted fitting error: 374.097
# Total weighted fitting error: 372.294
# Total weighted fitting error: 371.606
# Total weighted fitting error: 371.581
# Total weighted fitting error: 370.680
# Total weighted fitting error: 370.677
# Total weighted fitting error: 370.185
# Total weighted fitting error: 370.173
# Total weighted fitting error: 369.728
# Total weighted fitting error: 369.087
# Total weighted fitting error: 369.086
# Evidence 1769.199
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.09e+00
# Total weighted fitting error: 375.439
# Total weighted fitting error: 374.873
# Total weighted fitting error: 374.119
# Total weighted fitting error: 374.118
# Evidence 1778.642
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.08e+00
# Total weighted fitting error: 377.706
# Total weighted fitting error: 377.405
# Total weighted fitting error: 376.928
# Total weighted fitting error: 376.429
# Total weighted fitting error: 376.427
# Evidence 1782.792
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.05e+00
# Total weighted fitting error: 377.795
# Total weighted fitting error: 377.733
# Total weighted fitting error: 377.152
# Total weighted fitting error: 377.110
# Total weighted fitting error: 375.684
# Total weighted fitting error: 375.673
# Total weighted fitting error: 375.267
# Total weighted fitting error: 375.236
# Total weighted fitting error: 374.951
# Total weighted fitting error: 374.948
# Total weighted fitting error: 374.534
# Total weighted fitting error: 374.525
# Total weighted fitting error: 374.509
# Total weighted fitting error: 374.373
# Total weighted fitting error: 374.350
# Total weighted fitting error: 374.350
# Evidence 1787.022
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 8.51e-01
# Total weighted fitting error: 377.128
# Evidence 1789.125
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 8.47e-01
# Total weighted fitting error: 378.240
# Total weighted fitting error: 378.101
# Total weighted fitting error: 377.836
# Total weighted fitting error: 377.635
# Total weighted fitting error: 377.575
# Total weighted fitting error: 377.057
# Total weighted fitting error: 377.054
# Total weighted fitting error: 376.605
# Total weighted fitting error: 376.592
# Total weighted fitting error: 376.465
# Total weighted fitting error: 376.302
# Total weighted fitting error: 376.302
# Evidence 1790.608
# Pass count  1
# Total samples: 96, Updated regularization: 1.00e+00
# Total weighted fitting error: 11.569
# Total weighted fitting error: 6.796
# Total weighted fitting error: 5.728
# Total weighted fitting error: 5.549
# Total weighted fitting error: 5.284
# Total weighted fitting error: 4.957
# Total weighted fitting error: 4.898
# Total weighted fitting error: 4.841
# Total weighted fitting error: 4.829
# Total weighted fitting error: 4.822
# Total weighted fitting error: 4.820
# Total weighted fitting error: 4.819
# Total weighted fitting error: 4.818
# Total weighted fitting error: 4.818
# Total weighted fitting error: 4.818
# Total weighted fitting error: 4.818
# Total weighted fitting error: 4.818
# Total weighted fitting error: 4.818
# Total weighted fitting error: 4.818
# Total weighted fitting error: 4.818
# Total weighted fitting error: 4.818
# Evidence -48.585
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.80e+00
# Total weighted fitting error: 53.339
# Total weighted fitting error: 51.883
# Total weighted fitting error: 50.622
# Total weighted fitting error: 50.344
# Total weighted fitting error: 50.044
# Total weighted fitting error: 49.877
# Total weighted fitting error: 49.726
# Total weighted fitting error: 49.713
# Total weighted fitting error: 49.687
# Total weighted fitting error: 49.644
# Total weighted fitting error: 49.597
# Total weighted fitting error: 49.594
# Total weighted fitting error: 49.588
# Total weighted fitting error: 49.580
# Total weighted fitting error: 49.579
# Total weighted fitting error: 49.578
# Total weighted fitting error: 49.577
# Total weighted fitting error: 49.577
# Total weighted fitting error: 49.577
# Total weighted fitting error: 49.577
# Total weighted fitting error: 49.577
# Total weighted fitting error: 49.577
# Total weighted fitting error: 49.577
# Total weighted fitting error: 49.577
# Total weighted fitting error: 49.577
# Evidence 993.724
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 3.20e+00
# Total weighted fitting error: 190.665
# Total weighted fitting error: 190.088
# Total weighted fitting error: 189.057
# Total weighted fitting error: 187.545
# Total weighted fitting error: 185.502
# Total weighted fitting error: 185.314
# Total weighted fitting error: 184.966
# Total weighted fitting error: 184.405
# Total weighted fitting error: 183.955
# Total weighted fitting error: 183.928
# Total weighted fitting error: 183.905
# Total weighted fitting error: 183.872
# Total weighted fitting error: 183.869
# Total weighted fitting error: 183.863
# Total weighted fitting error: 183.855
# Total weighted fitting error: 183.855
# Total weighted fitting error: 183.853
# Total weighted fitting error: 183.851
# Total weighted fitting error: 183.851
# Total weighted fitting error: 183.851
# Evidence 1557.825
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 2.68e+00
# Total weighted fitting error: 326.177
# Total weighted fitting error: 321.136
# Total weighted fitting error: 316.360
# Total weighted fitting error: 315.627
# Total weighted fitting error: 315.345
# Total weighted fitting error: 314.854
# Total weighted fitting error: 314.220
# Total weighted fitting error: 314.204
# Total weighted fitting error: 314.176
# Total weighted fitting error: 314.126
# Total weighted fitting error: 314.053
# Total weighted fitting error: 314.048
# Total weighted fitting error: 314.040
# Total weighted fitting error: 314.028
# Total weighted fitting error: 314.027
# Total weighted fitting error: 314.026
# Total weighted fitting error: 314.024
# Total weighted fitting error: 314.024
# Evidence 1734.689
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.87e+00
# Total weighted fitting error: 368.085
# Total weighted fitting error: 365.777
# Total weighted fitting error: 363.527
# Total weighted fitting error: 363.494
# Total weighted fitting error: 363.436
# Total weighted fitting error: 363.329
# Total weighted fitting error: 363.132
# Total weighted fitting error: 362.948
# Total weighted fitting error: 362.932
# Total weighted fitting error: 362.792
# Total weighted fitting error: 362.596
# Total weighted fitting error: 362.592
# Total weighted fitting error: 362.586
# Total weighted fitting error: 362.538
# Total weighted fitting error: 362.533
# Total weighted fitting error: 362.529
# Total weighted fitting error: 362.523
# Total weighted fitting error: 362.513
# Total weighted fitting error: 362.512
# Total weighted fitting error: 362.505
# Total weighted fitting error: 362.505
# Total weighted fitting error: 362.503
# Total weighted fitting error: 362.503
# Total weighted fitting error: 362.503
# Total weighted fitting error: 362.502
# Total weighted fitting error: 362.502
# Evidence 1771.823
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.46e+00
# Total weighted fitting error: 377.425
# Total weighted fitting error: 376.791
# Total weighted fitting error: 375.992
# Total weighted fitting error: 375.163
# Total weighted fitting error: 375.120
# Total weighted fitting error: 375.066
# Total weighted fitting error: 374.967
# Total weighted fitting error: 374.802
# Total weighted fitting error: 374.794
# Total weighted fitting error: 374.728
# Total weighted fitting error: 374.719
# Total weighted fitting error: 374.648
# Total weighted fitting error: 374.612
# Total weighted fitting error: 374.610
# Total weighted fitting error: 374.589
# Total weighted fitting error: 374.587
# Total weighted fitting error: 374.582
# Total weighted fitting error: 374.582
# Total weighted fitting error: 374.572
# Total weighted fitting error: 374.572
# Total weighted fitting error: 374.570
# Total weighted fitting error: 374.567
# Total weighted fitting error: 374.567
# Total weighted fitting error: 374.563
# Total weighted fitting error: 374.563
# Total weighted fitting error: 374.563
# Total weighted fitting error: 374.563
# Total weighted fitting error: 374.563
# Evidence 1783.052
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.23e+00
# Total weighted fitting error: 379.895
# Total weighted fitting error: 379.682
# Total weighted fitting error: 379.295
# Total weighted fitting error: 378.682
# Total weighted fitting error: 378.645
# Total weighted fitting error: 378.347
# Total weighted fitting error: 378.346
# Total weighted fitting error: 378.285
# Total weighted fitting error: 378.178
# Total weighted fitting error: 378.165
# Total weighted fitting error: 378.065
# Total weighted fitting error: 378.064
# Total weighted fitting error: 378.042
# Total weighted fitting error: 378.004
# Total weighted fitting error: 378.001
# Total weighted fitting error: 377.979
# Total weighted fitting error: 377.978
# Total weighted fitting error: 377.978
# Total weighted fitting error: 377.969
# Total weighted fitting error: 377.969
# Total weighted fitting error: 377.969
# Total weighted fitting error: 377.965
# Total weighted fitting error: 377.965
# Total weighted fitting error: 377.963
# Total weighted fitting error: 377.961
# Total weighted fitting error: 377.960
# Total weighted fitting error: 377.960
# Total weighted fitting error: 377.960
# Total weighted fitting error: 377.959
# Total weighted fitting error: 377.959
# Total weighted fitting error: 377.959
# Total weighted fitting error: 377.959
# Total weighted fitting error: 377.958
# Total weighted fitting error: 377.958
# Total weighted fitting error: 377.958
# Evidence 1787.756
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 1.07e+00
# Total weighted fitting error: 380.566
# Total weighted fitting error: 380.437
# Total weighted fitting error: 380.194
# Total weighted fitting error: 380.162
# Total weighted fitting error: 379.866
# Total weighted fitting error: 379.372
# Total weighted fitting error: 379.368
# Total weighted fitting error: 379.201
# Total weighted fitting error: 378.917
# Total weighted fitting error: 378.915
# Total weighted fitting error: 378.909
# Total weighted fitting error: 378.724
# Total weighted fitting error: 378.722
# Total weighted fitting error: 378.719
# Total weighted fitting error: 378.714
# Total weighted fitting error: 378.666
# Total weighted fitting error: 378.659
# Total weighted fitting error: 378.600
# Total weighted fitting error: 378.598
# Total weighted fitting error: 378.579
# Total weighted fitting error: 378.548
# Total weighted fitting error: 378.546
# Total weighted fitting error: 378.543
# Total weighted fitting error: 378.520
# Total weighted fitting error: 378.520
# Evidence 1791.556
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 9.39e-01
# Total weighted fitting error: 380.646
# Total weighted fitting error: 380.557
# Total weighted fitting error: 379.852
# Total weighted fitting error: 379.798
# Total weighted fitting error: 379.328
# Total weighted fitting error: 379.326
# Total weighted fitting error: 378.997
# Total weighted fitting error: 378.967
# Total weighted fitting error: 378.711
# Total weighted fitting error: 378.708
# Total weighted fitting error: 378.565
# Total weighted fitting error: 378.548
# Total weighted fitting error: 378.518
# Total weighted fitting error: 378.462
# Total weighted fitting error: 378.430
# Total weighted fitting error: 378.423
# Total weighted fitting error: 378.361
# Total weighted fitting error: 378.259
# Total weighted fitting error: 378.254
# Total weighted fitting error: 378.246
# Total weighted fitting error: 378.232
# Total weighted fitting error: 378.229
# Total weighted fitting error: 378.125
# Total weighted fitting error: 378.124
# Evidence 1795.859
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 7.75e-01
# Total weighted fitting error: 380.726
# Total weighted fitting error: 380.668
# Total weighted fitting error: 380.575
# Total weighted fitting error: 379.870
# Total weighted fitting error: 379.866
# Total weighted fitting error: 379.325
# Total weighted fitting error: 379.290
# Total weighted fitting error: 378.116
# Total weighted fitting error: 378.095
# Evidence 1800.582
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 7.06e-01
# Total weighted fitting error: 380.957
# Total weighted fitting error: 380.837
# Total weighted fitting error: 380.612
# Total weighted fitting error: 380.214
# Total weighted fitting error: 379.568
# Total weighted fitting error: 379.562
# Evidence 1802.795
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 7.00e-01
# Total weighted fitting error: 381.116
# Total weighted fitting error: 381.040
# Total weighted fitting error: 380.388
# Total weighted fitting error: 380.382
# Total weighted fitting error: 379.434
# Total weighted fitting error: 379.432
# Evidence 1804.618
# Updating hyper-parameters...
# Total samples: 96, Updated regularization: 6.76e-01
# Total weighted fitting error: 381.249
# Total weighted fitting error: 381.189
# Total weighted fitting error: 380.646
# Total weighted fitting error: 380.558
# Total weighted fitting error: 379.758
# Total weighted fitting error: 379.757
# Evidence 1805.970
# Pass count  1
# Total samples: 96, Updated regularization: 1.00e+00
# Total weighted fitting error: 12.505
# Total weighted fitting error: 8.058
# Total weighted fitting error: 6.627
# Total weighted fitting error: 5.976
# Total weighted fitting error: 5.872
# Total weighted fitting error: 5.687
# Total weighted fitting error: 5.580
# Total weighted fitting error: 5.521
# Total weighted fitting error: 5.499
# Total weighted fitting error: 5.496
# Total weighted fitting error: 5.493
# Total weighted fitting error: 5.492
# Total weighted fitting error: 5.491
# Total weighted fitting error: 5.491
# Total weighted fitting error: 5.491
# Total weighted fitting error: 5.491
# Total weighted fitting error: 5.491
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_22755/1927727381.py in <module>
#      34
#      35         # fit to data
# ---> 36         model.fit(alpha_0=1.)
#      37
#      38         # plot fitness to data
#
# ~/Documents/VenturelliLab/Sulaiman_Cdiff_ExpDesign/exp2/glove/mse_model.py in fit(self, evidence_tol, nlp_tol, alpha_0, patience, max_fails, beta)
#     283
#     284             # fit using updated Alpha and Beta
# --> 285             self.res = minimize(fun=self.objective,
#     286                                 jac=self.jacobian_fwd,
#     287                                 hess=self.hessian,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     691         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     692     elif meth == 'newton-cg':
# --> 693         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     694                                  **options)
#     695     elif meth == 'l-bfgs-b':
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback, xtol, eps, maxiter, disp, return_all, **unknown_options)
#    2057         try:
#    2058             alphak, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 2059                      _line_search_wolfe12(f, fprime, xk, pk, gfk,
#    2060                                           old_fval, old_old_fval)
#    2061         except _LineSearchError:
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1158     extra_condition = kwargs.pop('extra_condition', None)
#    1159
# -> 1160     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1161                              old_fval, old_old_fval,
#    1162                              **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      82     derphi0 = np.dot(gfk, pk)
#      83
# ---> 84     stp, fval, old_fval = scalar_search_wolfe1(
#      85             phi, derphi, old_fval, old_old_fval, derphi0,
#      86             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     159             alpha1 = stp
#     160             phi1 = phi(stp)
# --> 161             derphi1 = derphi(stp)
#     162         else:
#     163             break
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_linesearch.py in derphi(s)
#      76
#      77     def derphi(s):
# ---> 78         gval[0] = fprime(xk + s*pk, *args)
#      79         gc[0] += 1
#      80         return np.dot(gval[0], pk)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in grad(self, x)
#     271         if not np.array_equal(x, self.x):
#     272             self._update_x_impl(x)
# --> 273         self._update_grad()
#     274         return self.g
#     275
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     254     def _update_grad(self):
#     255         if not self.g_updated:
# --> 256             self._update_grad_impl()
#     257             self.g_updated = True
#     258
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     165
#     166             def update_grad():
# --> 167                 self.g = grad_wrapped(self.x)
#     168
#     169         elif grad in FD_METHODS:
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in grad_wrapped(x)
#     162             def grad_wrapped(x):
#     163                 self.ngev += 1
# --> 164                 return np.atleast_1d(grad(np.copy(x), *args))
#     165
#     166             def update_grad():
#
# ~/Documents/VenturelliLab/Sulaiman_Cdiff_ExpDesign/exp2/glove/mse_model.py in jacobian_fwd(self, params)
#     459
#     460             # Determine error
# --> 461             Y_error = output[1:] - Y_measured[1:]
#     462
#     463             # sum over time and outputs to get gradient w.r.t params
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    4248   # All supported cases of indexing can be implemented as an XLA gather,
#    4249   # followed by an optional reverse and broadcast_in_dim.
# -> 4250   arr = asarray(arr)
#    4251   treedef, static_idx, dynamic_idx = _split_index_for_jit(idx, arr.shape)
#    4252   return _gather(arr, treedef, static_idx, dynamic_idx, indices_are_sorted,
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py in asarray(a, dtype, order)
#    2565   lax_internal._check_user_dtype_supported(dtype, "asarray")
#    2566   dtype = dtypes.canonicalize_dtype(dtype) if dtype is not None else dtype
# -> 2567   return array(a, dtype=dtype, copy=False, order=order)
#    2568
#    2569
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py in array(object, dtype, copy, order, ndmin)
#    2546     raise TypeError("Unexpected input type for array: {}".format(type(object)))
#    2547
# -> 2548   out = lax_internal._convert_element_type(out, dtype, weak_type=weak_type)
#    2549   if ndmin > ndim(out):
#    2550     out = lax.expand_dims(out, range(ndmin - ndim(out)))
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/lax/lax.py in _convert_element_type(operand, new_dtype, weak_type)
#     502   new_weak_type = bool(weak_type)
#     503
# --> 504   if (dtypes.issubdtype(old_dtype, np.complexfloating) and
#     505       not dtypes.issubdtype(new_dtype, np.complexfloating)):
#     506     msg = "Casting complex values to real discards the imaginary part"
#
# ~/anaconda3/lib/python3.9/site-packages/jax/_src/dtypes.py in issubdtype(a, b)
#     217     # explicitly cast the second argument to a NumPy type object.
#     218     b = np.dtype(b).type
# --> 219   return np.issubdtype(a, b)
#     220
#     221 can_cast = np.can_cast
#
# KeyboardInterrupt:

# %%
    # save prediction results to a .csv
    strain = file.split("_")[1]
    kfold_df = pd.DataFrame()
    kfold_df['species'] = all_pred_species
    kfold_df['true'] = all_true
    kfold_df['pred'] = all_pred
    kfold_df['stdv'] = all_stdv
    # kfold_df.to_csv(f"kfold/{strain}_kfold.csv", index=False)
        
    # show prediction performance of individual species
    for sp in species:
        sp_inds = all_pred_species == sp
        R = linregress(all_true[sp_inds], all_pred[sp_inds]).rvalue
        plt.scatter(all_true[sp_inds], all_pred[sp_inds], label=f"{sp} " + "R={:.3f}".format(R))
        plt.errorbar(all_true[sp_inds], all_pred[sp_inds], yerr=all_stdv[sp_inds], 
                     fmt='.', capsize=3)
    plt.legend()
    plt.show()

# %%
for file in files:
    strain = file.split("_")[1]
    kfold_df = pd.read_csv(f"kfold/{strain}_kfold.csv")
        
    all_pred_species = kfold_df['species'].values
    all_true = kfold_df['true'].values 
    all_pred = kfold_df['pred'].values
    all_stdv = kfold_df['stdv'].values
        
    R_overall = linregress(all_true, all_pred).rvalue
        
    # show prediction performance of individual species
    for sp in species:
        sp_inds = all_pred_species == sp
        R = linregress(all_true[sp_inds], all_pred[sp_inds]).rvalue
        plt.scatter(all_true[sp_inds], all_pred[sp_inds], label=f"{sp} " + "R={:.3f}".format(R))
        plt.errorbar(all_true[sp_inds], all_pred[sp_inds], yerr=all_stdv[sp_inds], 
                     fmt='.', capsize=3)

    plt.xlabel("Measured OD")
    plt.ylabel("Predicted OD")
    plt.legend()
    plt.title(strain + " R={:.2f}".format(R_overall))
    plt.show()

# %% [markdown]
# # Show fit

# %%
pred_species, true, pred, stdv = predict(train_df, species)

for sp in species:
    sp_inds = pred_species == sp
    if sum(true[sp_inds]) > 0:
        R = linregress(true[sp_inds], pred[sp_inds]).rvalue
        plt.scatter(true[sp_inds], pred[sp_inds], label=f"{sp} " + "R={:.3f}".format(R))
        plt.errorbar(true[sp_inds], pred[sp_inds], yerr= stdv[sp_inds], 
                     fmt='.', capsize=3)
plt.legend()
plt.show()
