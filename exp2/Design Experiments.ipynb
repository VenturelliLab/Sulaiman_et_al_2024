# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy.stats import norm

import os
import time
import itertools

from glove.model import *

# %% [markdown]
# # Import data

# %%
# import file names
files = os.listdir("data/")
files = [f for f in files if "processed" in f and "passage" not in f]

# %% [markdown]
# # Design experiments for each strain

# %%
def gen_exp_name(species_names):
    exp_name = ""
    for s in species_names:
        exp_name += s
        exp_name += "-"
    return exp_name[:-1]

# %%
# define possible evaluation times 
t_eval = np.array([0, 24])

# %%
exp_names = []
for file in files:
    # import data
    df = pd.read_csv(f"data/{file}")

    # determine name of strain
    strain = file.split("_")[1]
    
    # make sure that experiment names are sorted alphabetically 
    exp_names = [gen_exp_name(np.sort(name.split("_")[0].replace(strain, "CD").split("-"))) for name in df.Treatments.values]
    df['Treatments'] = exp_names
    
    # determine species names 
    species = df.columns.values[2:]

    # instantiate gLV fit 
    model = gLV(species, df)

    # fit to data 
    model.fit()

    ### design experiment ###

    # create matrix of all possible communities
    dim = len(species)
    Xlist = [np.reshape(np.array(i), (1, dim)) for i in itertools.product([0, 1], repeat = dim)]
    # remove all zeros community
    X = np.array(np.concatenate(Xlist)[1:, :][::-1], float)
    # exclude mono cultures
    non_mono_inds = np.sum(X, 1) > 1
    X = X[non_mono_inds]

    # scale initial conditions 
    total_OD = .01 
    X = total_OD * np.einsum("ij,i->ij", X, 1/np.sum(X, 1))

    # generate design matrix 
    design_df = pd.DataFrame()
    for i,x in enumerate(X):
        exp_name = gen_exp_name(np.sort(species[x>0]))
        if exp_name not in exp_names:
            # eval time [0, 24]
            x_mat = np.empty([2, dim])
            x_mat[:] = np.nan
            x_mat[0] = x
            df_exp = pd.DataFrame()
            df_exp['Treatments'] = 2*[exp_name]
            df_exp['Time'] = t_eval
            df_exp[species] = x_mat
            design_df = pd.concat((design_df, df_exp))
            
    # remove samples that don't have C. diff
    CD_inds = np.in1d(design_df.Treatments.values, [exp_name for exp_name in np.unique(design_df.Treatments.values) if "CD" in exp_name])
    design_df = design_df.iloc[CD_inds].copy()
            
    # remove samples that have already been collected 
    prev_exp = np.unique(df.Treatments.values)
    dup_inds = np.in1d(design_df.Treatments.values, prev_exp)
    design_df = design_df.iloc[~dup_inds].copy()

    # determine best set of new experiments to collect 
    # N is the total number of measurements (corresponds to number of wells in 96 well plate)
    new_exp = model.design(design_df, N=16)
    exp_names += new_exp

    # new data to collect
    inds = np.in1d(design_df.Treatments.values, new_exp)
    new_df = design_df.iloc[inds].copy()

    # save design
    fname = f"designs/" + strain + "_design.csv"
    new_df.to_csv(fname, index=False)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Total samples: 38, Initial regularization: 1.00e-03
# Loss: 9.201, Residuals: -0.311
# Loss: 5.629, Residuals: 0.134
# Loss: 5.099, Residuals: 0.124
# Loss: 4.127, Residuals: 0.090
# Loss: 3.579, Residuals: 0.072
# Loss: 2.831, Residuals: 0.007
# Loss: 2.577, Residuals: 0.028
# Loss: 2.387, Residuals: 0.021
# Loss: 2.194, Residuals: -0.021
# Loss: 2.160, Residuals: -0.013
# Loss: 2.108, Residuals: -0.019
# Loss: 2.107, Residuals: -0.009
# Loss: 2.066, Residuals: -0.021
# Loss: 2.065, Residuals: -0.016
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 8.80e-01
# Loss: 114.478, Residuals: 0.003
# Loss: 113.869, Residuals: 0.000
# Loss: 112.828, Residuals: -0.005
# Loss: 111.205, Residuals: -0.006
# Loss: 111.002, Residuals: -0.001
# Loss: 109.329, Residuals: 0.002
# Loss: 108.990, Residuals: 0.002
# Loss: 108.528, Residuals: 0.004
# Loss: 108.504, Residuals: 0.006
# Loss: 108.302, Residuals: 0.007
# Loss: 108.272, Residuals: 0.006
# Loss: 108.217, Residuals: 0.007
# Loss: 108.213, Residuals: 0.007
# Optimization terminated successfully.
# Evidence 464.671
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.31e+00
# Loss: 135.260, Residuals: 0.016
# Optimization terminated successfully.
# Evidence 480.736
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.39e+00
# Loss: 145.078, Residuals: 0.010
# Loss: 144.711, Residuals: 0.014
# Loss: 144.621, Residuals: 0.014
# Loss: 144.464, Residuals: 0.013
# Loss: 144.442, Residuals: 0.011
# Loss: 144.248, Residuals: 0.012
# Loss: 143.987, Residuals: 0.013
# Loss: 143.984, Residuals: 0.014
# Optimization terminated successfully.
# Evidence 485.841
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.46e+00
# Loss: 147.398, Residuals: 0.014
# Loss: 147.312, Residuals: 0.015
# Loss: 147.212, Residuals: 0.015
# Loss: 147.207, Residuals: 0.015
# Optimization terminated successfully.
# Evidence 488.316
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.48e+00
# Loss: 148.825, Residuals: 0.013
# Loss: 148.684, Residuals: 0.015
# Loss: 148.680, Residuals: 0.016
# Optimization terminated successfully.
# Evidence 489.662
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.48e+00
# Loss: 149.492, Residuals: 0.015
# Loss: 149.446, Residuals: 0.016
# Loss: 149.438, Residuals: 0.016
# Optimization terminated successfully.
# Evidence 490.320
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.48e+00
# Loss: 149.862, Residuals: 0.017
# Loss: 149.786, Residuals: 0.016
# Loss: 149.784, Residuals: 0.015
# Optimization terminated successfully.
# Evidence 490.880
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.47e+00
# Loss: 150.062, Residuals: 0.016
# Loss: 150.044, Residuals: 0.015
# Loss: 150.018, Residuals: 0.015
# Loss: 150.002, Residuals: 0.015
# Loss: 150.002, Residuals: 0.015
# Optimization terminated successfully.
# Evidence 491.149
# Pass count  1
# Processing design dataframe...
# Computing sensitivies...
# Picked BU-BV-CA-CD-CH-CS
# Picked BU-CA-CD-CS-DP
# Picked BU-BV-CD-CH-CS-DP
# Picked CA-CD-CH-CS-DP
# Picked BU-BV-CA-CD-CS
# Picked BU-CD-CH-DP
# Picked duplicate!
# Picked BU-CA-CD-CH-CS
# Picked BV-CD-CH-CS-DP
# Picked BU-BV-CA-CD-CH-DP
# Picked BU-BV-CD-CH-CS
# Picked BV-CA-CD-CH-CS
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked BV-CA-CD-CH-CS-DP
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked BU-CA-CD-CS
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked BU-BV-CD-CH-DP
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked BV-CA-CD-DP
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked BU-BV-CA-CD-CH
# Dropped BU-CA-CD-CS-DP
# Picked BU-CA-CD-CS-DP

# %%
for file in files:
    fname = f"designs/" + file.split("_")[1] + "_design.csv"
    eval_times = pd.read_csv(fname)['Time'].values
    print(fname, sum(eval_times>0))
# Out:
# designs/MS001_design.csv 16
# designs/MS014_design.csv 16
# designs/MS008_design.csv 16
# designs/DSM_design.csv 16

# %% [markdown]
# # Design non-CD conditions

# %%
non_cd = np.in1d(df.Treatments.values, [exp for exp in df.Treatments.values if "CD" not in exp])
species = np.array([s for s in species if "CD" not in s])
species
# Out:
# array(['BT', 'BV', 'CH', 'BU', 'CS', 'CA', 'DP'], dtype='<U2')

# %%
non_cd_df = df.iloc[non_cd][["Treatments", "Time"] + list(species)].copy()
non_cd_df
# Out:
#                Treatments  Time        BT        BV        CH        BU
# 0    BT-BU-BV-CA-CH-CS-DP     0  0.001429  0.001429  0.001429  0.001429  \
# 1    BT-BU-BV-CA-CH-CS-DP    12  1.104770  0.179778  0.212016  0.401491
# 2    BT-BU-BV-CA-CH-CS-DP    24  1.043519  0.026562  0.191175  0.303696
# 18                  BT-CA     0  0.005000  0.000000  0.000000  0.000000
# 19                  BT-CA    12  1.715623  0.000000  0.000000  0.000000
# ..                    ...   ...       ...       ...       ...       ...
# 169         MonocultureDP    12  0.000000  0.000000  0.000000  0.000000
# 170         MonocultureDP    15  0.000000  0.000000  0.000000  0.000000
# 171         MonocultureDP    18  0.000000  0.000000  0.000000  0.000000
# 172         MonocultureDP    21  0.000000  0.000000  0.000000  0.000000
# 173         MonocultureDP    24  0.000000  0.000000  0.000000  0.000000
#
#            CS        CA        DP
# 0    0.001429  0.001429  0.001429
# 1    0.021472  0.018854  0.046787
# 2    0.039351  0.028246  0.059284
# 18   0.000000  0.005000  0.000000
# 19   0.000000  0.048044  0.000000
# ..        ...       ...       ...
# 169  0.000000  0.000000  0.120400
# 170  0.000000  0.000000  0.126867
# 171  0.000000  0.000000  0.138367
# 172  0.000000  0.000000  0.156267
# 173  0.000000  0.000000  0.172033
#
# [129 rows x 9 columns]

# %%
# instantiate gLV fit 
model = gLV(species, non_cd_df)

# fit to data 
model.fit()

### design experiment ###

# create matrix of all possible communities
dim = len(species)
Xlist = [np.reshape(np.array(i), (1, dim)) for i in itertools.product([0, 1], repeat = dim)]
# remove all zeros community
X = np.array(np.concatenate(Xlist)[1:, :][::-1], float)
# exclude mono cultures
non_mono_inds = np.sum(X, 1) > 1
X = X[non_mono_inds]

# scale initial conditions 
total_OD = .01 
X = total_OD * np.einsum("ij,i->ij", X, 1/np.sum(X, 1))

# generate design matrix 
design_df = pd.DataFrame()
for i,x in enumerate(X):
    exp_name = gen_exp_name(np.sort(species[x>0]))
    if exp_name not in exp_names:
        # eval time [0, 24]
        x_mat = np.empty([2, dim])
        x_mat[:] = np.nan
        x_mat[0] = x
        df_exp = pd.DataFrame()
        df_exp['Treatments'] = 2*[exp_name]
        df_exp['Time'] = t_eval
        df_exp[species] = x_mat
        design_df = pd.concat((design_df, df_exp))

# remove samples that have already been collected 
prev_exp = np.unique(non_cd_df.Treatments.values)
dup_inds = np.in1d(design_df.Treatments.values, prev_exp)
design_df = design_df.iloc[~dup_inds].copy()

# determine best set of new experiments to collect 
# N is the total number of measurements (corresponds to number of wells in 96 well plate)
new_exp = model.design(design_df, N=30)

# new data to collect
inds = np.in1d(design_df.Treatments.values, new_exp)
new_df = design_df.iloc[inds].copy()

# save design
fname = f"designs/universal_design.csv"
new_df.to_csv(fname, index=False)
# Out:
# Total samples: 22, Initial regularization: 1.00e-03
# Loss: 4.334, Residuals: -0.044
# Loss: 3.006, Residuals: 0.075
# Loss: 2.328, Residuals: 0.035
# Loss: 2.048, Residuals: 0.015
# Loss: 1.802, Residuals: 0.003
# Loss: 1.706, Residuals: 0.040
# Loss: 1.660, Residuals: 0.030
# Loss: 1.641, Residuals: 0.017
Residuals: 0.010
# Optimization terminated successfully.
# Evidence 234.155
# Updating hyper-parameters...
# Total samples: 22, Updated regularization: 1.90e+00
# Loss: 75.089, Residuals: 0.011
# Loss: 75.039, Residuals: 0.009
# Loss: 75.015, Residuals: 0.009
# Loss: 75.012, Residuals: 0.008
# Optimization terminated successfully.
# Evidence 234.595
# Updating hyper-parameters...
# Total samples: 22, Updated regularization: 1.89e+00
# Loss: 74.966, Residuals: 0.016
# Loss: 74.870, Residuals: 0.011
# Loss: 74.859, Residuals: 0.010
# Optimization terminated successfully.
# Evidence 235.179
# Updating hyper-parameters...
# Total samples: 22, Updated regularization: 1.88e+00
# Loss: 74.875, Residuals: 0.018
# Loss: 74.779, Residuals: 0.013
# Loss: 74.754, Residuals: 0.014
# Loss: 74.729, Residuals: 0.013
# Loss: 74.728, Residuals: 0.013
# Optimization terminated successfully.
# Evidence 235.890
# Updating hyper-parameters...
# Total samples: 22, Updated regularization: 1.83e+00
# Loss: 74.840, Residuals: 0.020
# Loss: 74.814, Residuals: 0.016
# Loss: 74.780, Residuals: 0.016
# Loss: 74.763, Residuals: 0.016
# Loss: 74.756, Residuals: 0.016
# Loss: 74.751, Residuals: 0.015
# Loss: 74.750, Residuals: 0.016
# Optimization terminated successfully.
# Evidence 236.645
# Updating hyper-parameters...
# Total samples: 22, Updated regularization: 1.79e+00
# Loss: 74.923, Residuals: 0.020
# Optimization terminated successfully.
# Evidence 237.049
# Updating hyper-parameters...
# Total samples: 22, Updated regularization: 1.78e+00
# Loss: 75.146, Residuals: 0.024
# Optimization terminated successfully.
# Evidence 237.291
# Updating hyper-parameters...
# Total samples: 22, Updated regularization: 1.78e+00
# Loss: 75.214, Residuals: 0.021
# Loss: 75.204, Residuals: 0.016
# Optimization terminated successfully.
# Evidence 237.638
# Updating hyper-parameters...
# Total samples: 22, Updated regularization: 1.77e+00
# Loss: 75.252, Residuals: 0.018
# Optimization terminated successfully.
# Evidence 237.759
# Pass count  1
# Processing design dataframe...
# Computing sensitivies...
# Picked BU-BV-CA-CH-CS-DP
# Picked BU-BV-CA-CS
# Picked BU-BV-CS-DP
# Picked BT-BU-CH-DP
# Picked BV-CA-CS-DP
# Picked BT-BU-CA-CH-CS
# Picked BV-CA-CH
# Picked BU-CA-CH-DP
# Picked BT-BU-CA-CS-DP
# Picked BU-BV-CH-CS
# Picked BT-CA-CH-CS-DP
# Picked BT-BU-CA-CH
# Picked BU-BV-CA-CH-CS
# Picked BV-CH-CS-DP
# Picked BT-BV-CA-CS-DP
# Picked BU-BV-CA-CH-DP
# Picked BU-CA-CS
# Picked duplicate!
# Picked duplicate!
# Picked BV-CH-CS
# Picked duplicate!
# Picked duplicate!
# Picked BU-CA-CS-DP
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked BT-BU-BV-CA-CS-DP
# Picked duplicate!
# Picked duplicate!
# Picked BV-CA-CH-CS-DP
# Picked duplicate!
# Picked duplicate!
# Picked BV-CA-CH-CS
# Picked duplicate!
# Picked BT-BV-CH-DP
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked BU-BV-CA-DP
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked BT-BU-BV-CA-DP
# Picked duplicate!
# Picked duplicate!
# Picked BV-CH-DP
# Picked duplicate!
# Picked duplicate!
# Picked BU-BV-CA-CH
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked BU-BV-DP
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked BU-CA-CH-CS
# Picked duplicate!
# Picked duplicate!
# Picked duplicate!
# Picked CA-CS-DP
# Dropped BT-BU-CH-DP
# Picked BT-BU-CH-DP

# %%
new_df.iloc[new_df.Time.values == 0].to_csv("designs/unversal_t0.csv", index=False)

# %%
new_df.iloc[new_df.Time.values == 0]
# Out:
#           Treatments  Time        BT        BV        CH        BU        CS
# 0        BT-BV-CH-DP     0  0.002500  0.002500  0.002500  0.000000  0.000000  \
# 0  BT-BU-BV-CA-CS-DP     0  0.001667  0.001667  0.000000  0.001667  0.001667
# 0     BT-BU-BV-CA-DP     0  0.002000  0.002000  0.000000  0.002000  0.000000
# 0     BT-BV-CA-CS-DP     0  0.002000  0.002000  0.000000  0.000000  0.002000
# 0     BT-BU-CA-CH-CS     0  0.002000  0.000000  0.002000  0.002000  0.002000
# 0        BT-BU-CA-CH     0  0.002500  0.000000  0.002500  0.002500  0.000000
# 0        BT-BU-CH-DP     0  0.002500  0.000000  0.002500  0.002500  0.000000
# 0     BT-CA-CH-CS-DP     0  0.002000  0.000000  0.002000  0.000000  0.002000
# 0     BT-BU-CA-CS-DP     0  0.002000  0.000000  0.000000  0.002000  0.002000
# 0  BU-BV-CA-CH-CS-DP     0  0.000000  0.001667  0.001667  0.001667  0.001667
# 0     BU-BV-CA-CH-CS     0  0.000000  0.002000  0.002000  0.002000  0.002000
# 0        BU-BV-CH-CS     0  0.000000  0.002500  0.002500  0.002500  0.002500
# 0     BU-BV-CA-CH-DP     0  0.000000  0.002000  0.002000  0.002000  0.000000
# 0        BU-BV-CA-CH     0  0.000000  0.002500  0.002500  0.002500  0.000000
# 0     BV-CA-CH-CS-DP     0  0.000000  0.002000  0.002000  0.000000  0.002000
# 0        BV-CA-CH-CS     0  0.000000  0.002500  0.002500  0.000000  0.002500
# 0        BV-CH-CS-DP     0  0.000000  0.002500  0.002500  0.000000  0.002500
# 0           BV-CH-CS     0  0.000000  0.003333  0.003333  0.000000  0.003333
# 0           BV-CA-CH     0  0.000000  0.003333  0.003333  0.000000  0.000000
# 0           BV-CH-DP     0  0.000000  0.003333  0.003333  0.000000  0.000000
# 0        BU-BV-CA-CS     0  0.000000  0.002500  0.000000  0.002500  0.002500
# 0        BU-BV-CS-DP     0  0.000000  0.002500  0.000000  0.002500  0.002500
# 0        BU-BV-CA-DP     0  0.000000  0.002500  0.000000  0.002500  0.000000
# 0           BU-BV-DP     0  0.000000  0.003333  0.000000  0.003333  0.000000
# 0        BV-CA-CS-DP     0  0.000000  0.002500  0.000000  0.000000  0.002500
# 0        BU-CA-CH-CS     0  0.000000  0.000000  0.002500  0.002500  0.002500
# 0        BU-CA-CH-DP     0  0.000000  0.000000  0.002500  0.002500  0.000000
# 0        BU-CA-CS-DP     0  0.000000  0.000000  0.000000  0.002500  0.002500
# 0           BU-CA-CS     0  0.000000  0.000000  0.000000  0.003333  0.003333
# 0           CA-CS-DP     0  0.000000  0.000000  0.000000  0.000000  0.003333
#
#          CA        DP
# 0  0.000000  0.002500
# 0  0.001667  0.001667
# 0  0.002000  0.002000
# 0  0.002000  0.002000
# 0  0.002000  0.000000
# 0  0.002500  0.000000
# 0  0.000000  0.002500
# 0  0.002000  0.002000
# 0  0.002000  0.002000
# 0  0.001667  0.001667
# 0  0.002000  0.000000
# 0  0.000000  0.000000
# 0  0.002000  0.002000
# 0  0.002500  0.000000
# 0  0.002000  0.002000
# 0  0.002500  0.000000
# 0  0.000000  0.002500
# 0  0.000000  0.000000
# 0  0.003333  0.000000
# 0  0.000000  0.003333
# 0  0.002500  0.000000
# 0  0.000000  0.002500
# 0  0.002500  0.002500
# 0  0.000000  0.003333
# 0  0.002500  0.002500
# 0  0.002500  0.000000
# 0  0.002500  0.002500
# 0  0.002500  0.002500
# 0  0.003333  0.000000
# 0  0.003333  0.003333
