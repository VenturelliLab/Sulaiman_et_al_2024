# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy.stats import norm, linregress

import os
import time
import itertools

from glove.mse_model import *

from sklearn.model_selection import KFold
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# import file names
files = os.listdir("data/")
files = [f for f in files if "processed" in f]
files = files[:1]
files
# Out:
# ['MS014_processed_mono.csv']

# %% [markdown]
# # fit gLV models

# %%
def predict_df(df, species):
    
    # save measured and predicted values
    pred_species = []
    pred = []
    stdv = []
    true = []

    # pull just the community data
    test_data = process_df(df, species) 

    # plot the results
    for exp, t_span, Y_m in test_data:

        # increase evaluation time
        t_eval = np.linspace(t_span[0], t_span[-1])

        # predict 
        Y_p, Y_l, _ = model.predict(Y_m, t_eval)
        Y_std = Y_p - Y_l
        
        # set NaN to zero
        Y_p = np.nan_to_num(Y_p)
        Y_std = np.nan_to_num(Y_std)

        ### append only end-point prediction results for non-zero outcomes ###
        inds_pos = Y_m[-1,:] > 0 
        pred_species.append(np.array(species)[inds_pos])
        true.append(Y_m[-1,:][inds_pos])
        pred.append(Y_p[-1,:][inds_pos])
        stdv.append(Y_std[-1,:][inds_pos])
        
    # concatenate list
    pred_species = np.concatenate(pred_species)
    true = np.concatenate(true)
    pred = np.concatenate(pred)
    stdv = np.concatenate(stdv)
        
    return pred_species, true, pred, stdv

# %%
# run kfold for each file 
for file in files:
    
    # import data
    df = pd.read_csv(f"data/{file}")

    # determine species names 
    species = df.columns.values[2:]

    # separate mono culture data 
    mono_df = pd.concat([df_i for name, df_i in df.groupby("Treatments") if "Mono" in name])
    dfs = [df_i for name, df_i in df.groupby("Treatments") if "Mono" not in name]

    # init kfold object
    kf = KFold(n_splits=5, shuffle=True, random_state=21)

    # keep track of all predictions
    all_pred_species = []
    all_true = []
    all_pred = []
    all_stdv = []

    # run Kfold 
    # for train_index, test_index in kf.split(dfs):
    train_index, test_index = next(iter(kf.split(dfs)))
        
    # get train df 
    train_df = pd.concat([dfs[i] for i in train_index])
    # train_df = pd.concat((mono_df, train_df))

    # get test df
    test_df = pd.concat([dfs[i] for i in test_index])

    # instantiate gLV fit 
    model = gLV(species, train_df)

    # fit to data 
    model.fit()

    # plot fitness to data
    pred_species, true, pred, stdv = predict_df(test_df, species)

    # append predictions 
    all_pred_species = np.append(all_pred_species, pred_species)
    all_true = np.append(all_true, true)
    all_pred = np.append(all_pred, pred)
    all_stdv = np.append(all_stdv, stdv)

    # save prediction results to a .csv
    strain = file.split("_")[0]
    kfold_df = pd.DataFrame()
    kfold_df['species'] = all_pred_species
    kfold_df['true'] = all_true
    kfold_df['pred'] = all_pred
    kfold_df['stdv'] = all_stdv
    # kfold_df.to_csv(f"kfold/{strain}_kfold.csv", index=False)
        
    # show prediction performance of individual species
    for sp in species:
        sp_inds = all_pred_species == sp
        R = linregress(all_true[sp_inds], all_pred[sp_inds]).rvalue
        plt.scatter(all_true[sp_inds], all_pred[sp_inds], label=f"{sp} " + "R={:.3f}".format(R))
        plt.errorbar(all_true[sp_inds], all_pred[sp_inds], yerr=all_stdv[sp_inds], 
                     fmt='.', capsize=3)

    plt.xlabel("Measured OD")
    plt.ylabel("Predicted OD")
    plt.legend()
    plt.title(strain)
    # plt.savefig(f"kfold/{strain}_kfold.pdf", dpi=300)
    plt.show()
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Total samples: 90, Updated regularization: 1.00e-03
# Total weighted fitting error: 5.971
# Total weighted fitting error: 2.323
# Total weighted fitting error: 1.964
# Total weighted fitting error: 1.868
# Total weighted fitting error: 1.690
# Total weighted fitting error: 1.381
# Total weighted fitting error: 0.987
# Total weighted fitting error: 0.969
# Total weighted fitting error: 0.828
# Total weighted fitting error: 0.815
# Total weighted fitting error: 0.720
# Total weighted fitting error: 0.709
# Total weighted fitting error: 0.688
# Total weighted fitting error: 0.654
# Total weighted fitting error: 0.637
# Total weighted fitting error: 0.610
# Total weighted fitting error: 0.604
# Total weighted fitting error: 0.594
# Total weighted fitting error: 0.579
# Total weighted fitting error: 0.579
# Total weighted fitting error: 0.578
# Total weighted fitting error: 0.576
# Total weighted fitting error: 0.573
# Total weighted fitting error: 0.569
# Total weighted fitting error: 0.569
# Total weighted fitting error: 0.568
# Total weighted fitting error: 0.566
# Total weighted fitting error: 0.566
# Total weighted fitting error: 0.566
# Total weighted fitting error: 0.566
# Total weighted fitting error: 0.565
# Total weighted fitting error: 0.565
# Total weighted fitting error: 0.565
# Total weighted fitting error: 0.565
# Total weighted fitting error: 0.565
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Total weighted fitting error: 0.564
# Evidence -228.914
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 2.26e-02
# Total weighted fitting error: 7.931
# Total weighted fitting error: 7.767
# Total weighted fitting error: 7.696
# Total weighted fitting error: 7.596
# Total weighted fitting error: 7.503
# Total weighted fitting error: 7.501
# Total weighted fitting error: 7.499
# Total weighted fitting error: 7.494
# Total weighted fitting error: 7.487
# Total weighted fitting error: 7.480
# Total weighted fitting error: 7.476
# Total weighted fitting error: 7.471
# Total weighted fitting error: 7.470
# Total weighted fitting error: 7.469
# Total weighted fitting error: 7.466
# Total weighted fitting error: 7.466
# Total weighted fitting error: 7.465
# Total weighted fitting error: 7.462
# Total weighted fitting error: 7.462
# Total weighted fitting error: 7.461
# Total weighted fitting error: 7.460
# Total weighted fitting error: 7.459
# Total weighted fitting error: 7.459
# Total weighted fitting error: 7.458
# Total weighted fitting error: 7.458
# Total weighted fitting error: 7.458
# Total weighted fitting error: 7.457
# Total weighted fitting error: 7.457
# Total weighted fitting error: 7.457
# Total weighted fitting error: 7.456
# Total weighted fitting error: 7.456
# Total weighted fitting error: 7.456
# Total weighted fitting error: 7.456
# Total weighted fitting error: 7.456
# Total weighted fitting error: 7.456
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.455
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Total weighted fitting error: 7.454
# Evidence 716.458
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 1.72e-01
# Total weighted fitting error: 63.011
# Total weighted fitting error: 62.777
# Total weighted fitting error: 62.636
# Total weighted fitting error: 62.441
# Total weighted fitting error: 62.428
# Total weighted fitting error: 62.330
# Total weighted fitting error: 62.267
# Total weighted fitting error: 62.238
# Total weighted fitting error: 62.236
# Total weighted fitting error: 62.210
# Total weighted fitting error: 62.166
# Total weighted fitting error: 62.161
# Total weighted fitting error: 62.121
# Total weighted fitting error: 62.114
# Total weighted fitting error: 62.100
# Total weighted fitting error: 62.099
# Total weighted fitting error: 62.084
# Total weighted fitting error: 62.083
# Total weighted fitting error: 62.075
# Total weighted fitting error: 62.062
# Total weighted fitting error: 62.060
# Total weighted fitting error: 62.056
# Total weighted fitting error: 62.051
# Total weighted fitting error: 62.049
# Total weighted fitting error: 62.048
# Total weighted fitting error: 62.043
# Total weighted fitting error: 62.043
# Total weighted fitting error: 62.040
# Total weighted fitting error: 62.039
# Total weighted fitting error: 62.039
# Total weighted fitting error: 62.038
# Total weighted fitting error: 62.038
# Evidence 1468.123
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 7.43e-01
# Total weighted fitting error: 213.505
# Total weighted fitting error: 212.262
# Total weighted fitting error: 210.562
# Total weighted fitting error: 210.173
# Total weighted fitting error: 210.096
# Total weighted fitting error: 209.504
# Total weighted fitting error: 209.409
# Total weighted fitting error: 209.239
# Total weighted fitting error: 208.986
# Total weighted fitting error: 208.979
# Total weighted fitting error: 208.917
# Total weighted fitting error: 208.900
# Total weighted fitting error: 208.870
# Total weighted fitting error: 208.824
# Total weighted fitting error: 208.822
# Total weighted fitting error: 208.810
# Total weighted fitting error: 208.809
# Total weighted fitting error: 208.806
# Total weighted fitting error: 208.801
# Total weighted fitting error: 208.800
# Total weighted fitting error: 208.798
# Total weighted fitting error: 208.796
# Total weighted fitting error: 208.796
# Total weighted fitting error: 208.796
# Total weighted fitting error: 208.795
# Evidence 1861.328
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 1.05e+00
# Total weighted fitting error: 320.558
# Total weighted fitting error: 318.683
# Total weighted fitting error: 317.458
# Total weighted fitting error: 316.015
# Total weighted fitting error: 315.912
# Total weighted fitting error: 315.722
# Total weighted fitting error: 315.415
# Total weighted fitting error: 315.049
# Total weighted fitting error: 315.039
# Total weighted fitting error: 315.021
# Total weighted fitting error: 314.990
# Total weighted fitting error: 314.942
# Total weighted fitting error: 314.938
# Total weighted fitting error: 314.930
# Total weighted fitting error: 314.918
# Total weighted fitting error: 314.917
# Total weighted fitting error: 314.914
# Total weighted fitting error: 314.914
# Total weighted fitting error: 314.913
# Total weighted fitting error: 314.911
# Total weighted fitting error: 314.911
# Total weighted fitting error: 314.910
# Total weighted fitting error: 314.909
# Total weighted fitting error: 314.909
# Total weighted fitting error: 314.908
# Total weighted fitting error: 314.908
# Evidence 1951.245
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 1.05e+00
# Total weighted fitting error: 347.919
# Total weighted fitting error: 347.147
# Total weighted fitting error: 346.233
# Total weighted fitting error: 346.082
# Total weighted fitting error: 345.818
# Total weighted fitting error: 345.451
# Total weighted fitting error: 345.443
# Total weighted fitting error: 345.429
# Total weighted fitting error: 345.319
# Total weighted fitting error: 345.306
# Total weighted fitting error: 345.283
# Total weighted fitting error: 345.253
# Total weighted fitting error: 345.252
# Total weighted fitting error: 345.240
# Total weighted fitting error: 345.236
# Total weighted fitting error: 345.227
# Total weighted fitting error: 345.227
# Total weighted fitting error: 345.220
# Total weighted fitting error: 345.208
# Total weighted fitting error: 345.208
# Evidence 1968.598
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 9.95e-01
# Total weighted fitting error: 353.709
# Total weighted fitting error: 353.067
# Total weighted fitting error: 352.303
# Total weighted fitting error: 352.151
# Total weighted fitting error: 351.881
# Total weighted fitting error: 351.450
# Total weighted fitting error: 351.441
# Total weighted fitting error: 351.425
# Total weighted fitting error: 351.275
# Total weighted fitting error: 351.099
# Total weighted fitting error: 351.093
# Total weighted fitting error: 351.040
# Total weighted fitting error: 351.021
# Total weighted fitting error: 350.984
# Total weighted fitting error: 350.983
# Total weighted fitting error: 350.933
# Total weighted fitting error: 350.851
# Total weighted fitting error: 350.850
# Evidence 1977.430
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 9.34e-01
# Total weighted fitting error: 354.571
# Total weighted fitting error: 354.108
# Total weighted fitting error: 353.364
# Total weighted fitting error: 353.162
# Total weighted fitting error: 352.813
# Total weighted fitting error: 352.688
# Total weighted fitting error: 352.468
# Total weighted fitting error: 352.466
# Total weighted fitting error: 352.114
# Total weighted fitting error: 352.055
# Total weighted fitting error: 351.950
# Total weighted fitting error: 351.945
# Total weighted fitting error: 351.738
# Total weighted fitting error: 351.713
# Total weighted fitting error: 351.708
# Total weighted fitting error: 351.652
# Total weighted fitting error: 351.556
# Total weighted fitting error: 351.555
# Evidence 1985.547
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 8.66e-01
# Total weighted fitting error: 354.641
# Total weighted fitting error: 354.306
# Total weighted fitting error: 353.779
# Total weighted fitting error: 353.260
# Total weighted fitting error: 353.224
# Total weighted fitting error: 352.893
# Total weighted fitting error: 352.557
# Total weighted fitting error: 352.530
# Total weighted fitting error: 352.495
# Total weighted fitting error: 352.211
# Total weighted fitting error: 352.210
# Total weighted fitting error: 352.089
# Total weighted fitting error: 352.085
# Total weighted fitting error: 352.077
# Total weighted fitting error: 352.067
# Total weighted fitting error: 352.067
# Total weighted fitting error: 352.049
# Total weighted fitting error: 352.019
# Total weighted fitting error: 352.018
# Total weighted fitting error: 351.990
# Total weighted fitting error: 351.990
# Evidence 1992.920
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 7.87e-01
# Total weighted fitting error: 354.674
# Total weighted fitting error: 354.274
# Total weighted fitting error: 353.722
# Total weighted fitting error: 353.415
# Total weighted fitting error: 353.340
# Total weighted fitting error: 353.206
# Total weighted fitting error: 352.975
# Total weighted fitting error: 352.837
# Total weighted fitting error: 352.829
# Total weighted fitting error: 352.816
# Total weighted fitting error: 352.715
# Total weighted fitting error: 352.713
# Total weighted fitting error: 352.654
# Total weighted fitting error: 352.653
# Total weighted fitting error: 352.638
# Total weighted fitting error: 352.635
# Total weighted fitting error: 352.634
# Total weighted fitting error: 352.620
# Evidence 1999.352
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 7.36e-01
# Total weighted fitting error: 354.642
# Total weighted fitting error: 354.285
# Total weighted fitting error: 353.811
# Total weighted fitting error: 353.483
# Total weighted fitting error: 353.471
# Total weighted fitting error: 353.370
# Total weighted fitting error: 353.245
# Total weighted fitting error: 353.244
# Total weighted fitting error: 353.238
# Total weighted fitting error: 353.181
# Total weighted fitting error: 353.180
# Total weighted fitting error: 353.166
# Total weighted fitting error: 353.163
# Total weighted fitting error: 353.158
# Total weighted fitting error: 353.148
# Total weighted fitting error: 353.148
# Total weighted fitting error: 353.141
# Total weighted fitting error: 353.140
# Total weighted fitting error: 353.138
# Total weighted fitting error: 353.135
# Total weighted fitting error: 353.134
# Evidence 2004.565
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 6.93e-01
# Total weighted fitting error: 354.825
# Total weighted fitting error: 354.535
# Total weighted fitting error: 354.215
# Total weighted fitting error: 353.919
# Total weighted fitting error: 353.916
# Total weighted fitting error: 353.912
# Total weighted fitting error: 353.875
# Total weighted fitting error: 353.824
# Total weighted fitting error: 353.820
# Total weighted fitting error: 353.812
# Total weighted fitting error: 353.798
# Total weighted fitting error: 353.797
# Total weighted fitting error: 353.790
# Total weighted fitting error: 353.778
# Total weighted fitting error: 353.777
# Total weighted fitting error: 353.772
# Evidence 2008.469
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 6.66e-01
# Total weighted fitting error: 355.077
# Total weighted fitting error: 354.995
# Total weighted fitting error: 354.857
# Total weighted fitting error: 354.660
# Total weighted fitting error: 354.508
# Total weighted fitting error: 354.499
# Total weighted fitting error: 354.489
# Total weighted fitting error: 354.472
# Total weighted fitting error: 354.444
# Total weighted fitting error: 354.444
# Total weighted fitting error: 354.439
# Total weighted fitting error: 354.429
# Total weighted fitting error: 354.429
# Total weighted fitting error: 354.422
# Total weighted fitting error: 354.413
# Total weighted fitting error: 354.413
# Total weighted fitting error: 354.413
# Evidence 2011.170
# Updating hyper-parameters...
# Total samples: 90, Updated regularization: 6.46e-01
# Total weighted fitting error: 355.304
# Total weighted fitting error: 355.230
# Total weighted fitting error: 355.122
# Total weighted fitting error: 354.987
# Total weighted fitting error: 354.983
# Total weighted fitting error: 354.946
# Total weighted fitting error: 354.941
# Total weighted fitting error: 354.929
# Total weighted fitting error: 354.911
# Total weighted fitting error: 354.907
# Total weighted fitting error: 354.899
# Total weighted fitting error: 354.899
# Total weighted fitting error: 354.897
# Total weighted fitting error: 354.893
# Total weighted fitting error: 354.888
# Total weighted fitting error: 354.887
# Total weighted fitting error: 354.887
# Total weighted fitting error: 354.887
# Total weighted fitting error: 354.886
# Total weighted fitting error: 354.886
# Evidence 2013.046
# Pass count  1

# %%
# for file in files:
#     strain = file.split("_")[0]
#     kfold_df = pd.read_csv(f"kfold/{strain}_kfold.csv")
        
#     all_pred_species = kfold_df['species'].values
#     all_true = kfold_df['true'].values 
#     all_pred = kfold_df['pred'].values
#     all_stdv = kfold_df['stdv'].values
        
#     R_overall = linregress(all_true, all_pred).rvalue
        
#     # show prediction performance of individual species
#     for sp in species:
#         sp_inds = all_pred_species == sp
#         R = linregress(all_true[sp_inds], all_pred[sp_inds]).rvalue
#         plt.scatter(all_true[sp_inds], all_pred[sp_inds], label=f"{sp} " + "R={:.3f}".format(R))
#         plt.errorbar(all_true[sp_inds], all_pred[sp_inds], yerr=all_stdv[sp_inds], 
#                      fmt='.', capsize=3)

#     plt.xlabel("Measured OD")
#     plt.ylabel("Predicted OD")
#     plt.legend()
#     plt.title(strain + " R={:.2f}".format(R_overall))
#     plt.show()
