# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy.stats import norm

import os
import time
import itertools

from glove.model import *

params = {
    'figure.figsize': (18, 18),       # Figure size in inches
    'figure.dpi': 300,               # Resolution in dots per inch
    'axes.labelsize': 24,            # Font size of the axes labels
    'axes.titlesize': 24,            # Font size of the subplot titles
    'axes.titlepad': 20,             # Spacing between the subplot title and the plot
    'axes.linewidth': 2.,           # Width of the axis lines
    'xtick.labelsize': 16,           # Font size of the x-axis tick labels
    'ytick.labelsize': 16,           # Font size of the y-axis tick labels
    'legend.fontsize': 16,           # Font size of the legend
    'legend.frameon': True,          # Whether to draw a frame around the legend
    'legend.facecolor': 'inherit',   # Background color of the legend
    'legend.edgecolor': '0.8',       # Edge color of the legend
    'legend.framealpha': 0.8,        # Transparency of the legend frame
    'legend.loc': 'best',            # Location of the legend ('best', 'upper right', 'upper left', 'lower left', etc.)
    'legend.title_fontsize': 20,     # Font size of the legend title
    'pdf.fonttype': 42               # Output font type for PDF files
}

plt.rcParams.update(params)

# %%
# import file names
files = os.listdir("data/")
files = [f for f in files if "processed" in f and "passage" not in f]
files
# Out:
# ['EXP0019_MS001_processed.csv',
#  'EXP0019_MS014_processed.csv',
#  'EXP0019_MS008_processed.csv',
#  'EXP0019_DSM27147_processed.csv']

# %% [markdown]
# # fit gLV models

# %%
exp_names = []
for file in files:
    # import data
    df = pd.read_csv(f"data/{file}")

    # determine species names 
    species = df.columns.values[2:]

    # instantiate gLV fit 
    model = gLV(species, df)

    # fit to data 
    model.fit()
    
    # list of parameter names 
    param_names = []
    for s1 in species:
        for s2 in species:
            param_names += [s1+"*"+s2]
    param_names = list(species) + param_names
    
    # plot parameter distribution
    n_species = len(species)
    Avec = model.params[n_species:]
    Aij_std = np.sqrt(np.diag(model.Ainv))[n_species:]

    # plot
    k = 0
    for i in range(n_species):
        for j in range(n_species):
            plt.subplot(n_species, n_species, k+1)
            a = np.linspace(Avec[k]-np.std(Avec), Avec[k]+np.std(Avec))
            plt.plot(a, norm.pdf(a,Avec[k],Aij_std[k]), linewidth=3)
            plt.axvline(x=0, c='k', alpha=.5)
            k += 1
            if j == 0:
                plt.ylabel(species[i])
            if i == n_species-1:
                plt.xlabel(species[j])

    plt.suptitle(file.split("_")[0], fontsize=24)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.savefig("figures/"+file.split("_")[0]+".pdf")
    plt.show()
    plt.close()
    
    # compute Wald test for each parameter
    std_errors = np.sqrt(np.diag(model.Ainv))
    walds = model.params/std_errors
    wald_p_vals = 2*norm.cdf(-np.abs(walds))

    # save to df 
    df = pd.DataFrame()
    df["Param name"] = param_names
    df["Param value"] = model.params
    df["Param stdv"]  = np.sqrt(np.diag(model.Ainv))
    df["Param p-value"] = wald_p_vals
    for j, param_name in enumerate(param_names):
        df[param_name]  = model.Ainv[:, j]
    df.to_csv("params/"+file.split("_")[1]+".csv", index=False)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Total samples: 38, Initial regularization: 1.00e-03
# Loss: 9.201, Residuals: -0.311
# Loss: 5.629, Residuals: 0.134
# Loss: 5.099, Residuals: 0.124
# Loss: 4.127, Residuals: 0.090
# Loss: 3.578, Residuals: 0.072
# Loss: 2.824, Residuals: 0.015
# Loss: 2.538, Residuals: 0.000
# Loss: 2.257, Residuals: -0.017
# Loss: 2.222, Residuals: 0.010
# Loss: 2.164, Residuals: -0.002
# Loss: 2.151, Residuals: 0.001
# Loss: 2.127, Residuals: -0.006
# Loss: 2.088, Residuals: -0.018
# Loss: 2.087, Residuals: -0.011
# Loss: 2.055, Residuals: -0.023
# Loss: 2.044, Residuals: -0.020
# Loss: 2.025, Residuals: -0.029
# Loss: 2.024, Residuals: -0.020
# Loss: 2.013, Residuals: -0.024
# Loss: 2.013, Residuals: -0.025
# Loss: 2.003, Residuals: -0.030
# Loss: 2.002, Residuals: -0.029
# Loss: 1.996, Residuals: -0.033
# Loss: 1.987, Residuals: -0.037
# Loss: 1.985, Residuals: -0.037
# Loss: 1.985, Residuals: -0.037
# Loss: 1.979, Residuals: -0.040
# Loss: 1.979, Residuals: -0.040
# Optimization terminated successfully.
# Evidence -40.159
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 8.07e-01
# Loss: 23.461, Residuals: 0.032
# Loss: 23.045, Residuals: 0.001
# Loss: 22.589, Residuals: 0.001
# Loss: 22.532, Residuals: 0.010
# Loss: 22.431, Residuals: 0.010
# Loss: 22.276, Residuals: 0.010
# Loss: 22.148, Residuals: 0.015
# Loss: 22.140, Residuals: 0.017
# Loss: 22.129, Residuals: 0.018
# Loss: 22.120, Residuals: 0.020
# Loss: 22.120, Residuals: 0.019
# Optimization terminated successfully.
# Evidence 263.805
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.72e+00
# Loss: 65.170, Residuals: 0.020
# Loss: 64.862, Residuals: 0.020
# Loss: 64.476, Residuals: 0.017
# Loss: 64.453, Residuals: 0.020
# Loss: 64.411, Residuals: 0.020
# Loss: 64.347, Residuals: 0.020
# Loss: 64.337, Residuals: 0.021
# Loss: 64.327, Residuals: 0.022
# Loss: 64.314, Residuals: 0.022
# Loss: 64.311, Residuals: 0.022
# Optimization terminated successfully.
# Evidence 415.802
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.37e+00
# Loss: 110.795, Residuals: 0.010
# Loss: 110.113, Residuals: 0.015
# Loss: 109.648, Residuals: 0.019
# Loss: 109.605, Residuals: 0.020
# Loss: 109.571, Residuals: 0.020
# Loss: 109.518, Residuals: 0.020
# Loss: 109.487, Residuals: 0.020
# Loss: 109.485, Residuals: 0.020
# Optimization terminated successfully.
# Evidence 475.503
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.42e+00
# Loss: 134.926, Residuals: 0.014
# Loss: 134.556, Residuals: 0.015
# Loss: 134.356, Residuals: 0.016
# Loss: 134.348, Residuals: 0.015
# Optimization terminated successfully.
# Evidence 493.341
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.32e+00
# Loss: 144.592, Residuals: 0.015
# Loss: 144.434, Residuals: 0.013
# Loss: 144.335, Residuals: 0.013
# Loss: 144.324, Residuals: 0.013
# Loss: 144.320, Residuals: 0.013
# Optimization terminated successfully.
# Evidence 498.296
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.23e+00
# Loss: 148.104, Residuals: 0.012
# Loss: 148.035, Residuals: 0.012
# Loss: 147.960, Residuals: 0.012
# Loss: 147.959, Residuals: 0.011
# Optimization terminated successfully.
# Evidence 500.021
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.17e+00
# Loss: 149.423, Residuals: 0.012
# Loss: 149.387, Residuals: 0.011
# Loss: 149.338, Residuals: 0.011
# Loss: 149.338, Residuals: 0.011
# Optimization terminated successfully.
# Evidence 500.794
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.13e+00
# Loss: 149.981, Residuals: 0.010
# Loss: 149.958, Residuals: 0.010
# Loss: 149.925, Residuals: 0.010
# Loss: 149.925, Residuals: 0.010
# Optimization terminated successfully.
# Evidence 501.250
# Pass count  1
# Total samples: 31, Initial regularization: 1.00e-03
# Loss: 8.161, Residuals: -0.400
# Loss: 3.413, Residuals: 0.075
# Loss: 2.183, Residuals: 0.177
# Loss: 2.030, Residuals: 0.084
# Loss: 1.757, Residuals: 0.049
# Loss: 1.316, Residuals: 0.029
# Loss: 1.183, Residuals: 0.003
# Loss: 0.989, Residuals: -0.013
# Loss: 0.970, Residuals: 0.023
# Loss: 0.949, Residuals: 0.043
# Loss: 0.911, Residuals: 0.034
# Loss: 0.848, Residuals: 0.017
# Loss: 0.830, Residuals: 0.018
# Loss: 0.800, Residuals: 0.005
# Loss: 0.764, Residuals: -0.022
# Loss: 0.763, Residuals: -0.022
# Loss: 0.762, Residuals: -0.021
# Loss: 0.761, Residuals: -0.021
# Loss: 0.751, Residuals: -0.027
# Loss: 0.751, Residuals: -0.026
# Loss: 0.749, Residuals: -0.028
# Loss: 0.745, Residuals: -0.032
# Loss: 0.745, Residuals: -0.032
# Loss: 0.745, Residuals: -0.030
# Loss: 0.743, Residuals: -0.032
# Loss: 0.743, Residuals: -0.033
# Loss: 0.742, Residuals: -0.034
# Loss: 0.741, Residuals: -0.036
# Loss: 0.741, Residuals: -0.035
# Loss: 0.741, Residuals: -0.037
# Loss: 0.741, Residuals: -0.037
# Loss: 0.740, Residuals: -0.037
# Loss: 0.740, Residuals: -0.038
# Loss: 0.740, Residuals: -0.039
# Loss: 0.740, Residuals: -0.038
# Loss: 0.740, Residuals: -0.039
# Loss: 0.740, Residuals: -0.039
# Loss: 0.740, Residuals: -0.039
# Loss: 0.739, Residuals: -0.040
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Loss: 0.739, Residuals: -0.039
# Warning: Desired error not necessarily achieved due to precision loss.
# Evidence -52.673
# Updating hyper-parameters...
# Total samples: 31, Updated regularization: 8.63e-01
# Loss: 14.927, Residuals: -0.016
# Loss: 14.578, Residuals: 0.033
# Loss: 13.935, Residuals: 0.037
# Loss: 12.983, Residuals: 0.050
# Loss: 12.963, Residuals: 0.043
# Optimization terminated successfully.
# Evidence 171.313
# Updating hyper-parameters...
# Total samples: 31, Updated regularization: 1.35e+00
# Loss: 36.292, Residuals: 0.041
# Loss: 35.975, Residuals: 0.042
# Loss: 35.766, Residuals: 0.045
# Loss: 35.676, Residuals: 0.046
# Loss: 35.622, Residuals: 0.044
# Loss: 35.590, Residuals: 0.044
# Loss: 35.581, Residuals: 0.044
# Loss: 35.511, Residuals: 0.045
# Loss: 35.471, Residuals: 0.048
# Loss: 35.470, Residuals: 0.047
# Optimization terminated successfully.
# Evidence 306.194
# Updating hyper-parameters...
# Total samples: 31, Updated regularization: 2.40e+00
# Loss: 70.490, Residuals: 0.039
# Loss: 70.022, Residuals: 0.037
# Loss: 69.702, Residuals: 0.031
# Loss: 69.648, Residuals: 0.033
# Loss: 69.625, Residuals: 0.033
# Loss: 69.592, Residuals: 0.032
# Loss: 69.590, Residuals: 0.032
# Optimization terminated successfully.
# Evidence 377.961
# Updating hyper-parameters...
# Total samples: 31, Updated regularization: 2.74e+00
# Loss: 98.628, Residuals: 0.040
# Optimization terminated successfully.
# Evidence 401.334
# Updating hyper-parameters...
# Total samples: 31, Updated regularization: 3.01e+00
# Loss: 112.712, Residuals: 0.013
# Loss: 112.256, Residuals: 0.014
# Loss: 112.167, Residuals: 0.021
# Loss: 112.013, Residuals: 0.020
# Loss: 111.799, Residuals: 0.017
# Loss: 111.716, Residuals: 0.015
# Loss: 111.701, Residuals: 0.015
# Loss: 111.695, Residuals: 0.015
# Optimization terminated successfully.
# Evidence 411.390
# Updating hyper-parameters...
# Total samples: 31, Updated regularization: 2.59e+00
# Loss: 117.405, Residuals: 0.009
# Loss: 117.281, Residuals: 0.007
# Loss: 117.255, Residuals: 0.009
# Loss: 117.207, Residuals: 0.009
# Loss: 117.136, Residuals: 0.008
# Loss: 117.103, Residuals: 0.007
# Loss: 117.101, Residuals: 0.007
# Optimization terminated successfully.
# Evidence 416.364
# Updating hyper-parameters...
# Total samples: 31, Updated regularization: 2.37e+00
# Loss: 119.869, Residuals: 0.005
# Loss: 119.828, Residuals: 0.004
# Loss: 119.775, Residuals: 0.003
# Loss: 119.754, Residuals: 0.003
# Loss: 119.752, Residuals: 0.003
# Optimization terminated successfully.
# Evidence 418.618
# Updating hyper-parameters...
# Total samples: 31, Updated regularization: 2.25e+00
# Loss: 121.069, Residuals: 0.003
# Loss: 121.051, Residuals: 0.001
# Loss: 121.032, Residuals: 0.000
# Loss: 121.023, Residuals: 0.001
# Loss: 121.018, Residuals: -0.000
# Loss: 121.017, Residuals: 0.000
# Loss: 121.015, Residuals: -0.000
# Optimization terminated successfully.
# Evidence 419.701
# Updating hyper-parameters...
# Total samples: 31, Updated regularization: 2.20e+00
# Loss: 121.664, Residuals: 0.000
# Loss: 121.644, Residuals: -0.002
# Loss: 121.637, Residuals: -0.002
# Loss: 121.635, Residuals: -0.002
# Loss: 121.634, Residuals: -0.002
# Optimization terminated successfully.
# Evidence 420.335
# Updating hyper-parameters...
# Total samples: 31, Updated regularization: 2.16e+00
# Loss: 121.959, Residuals: -0.002
# Loss: 121.951, Residuals: -0.003
# Optimization terminated successfully.
# Evidence 420.602
# Pass count  1
# Total samples: 38, Initial regularization: 1.00e-03
# Loss: 9.346, Residuals: -0.313
# Loss: 5.660, Residuals: 0.133
# Loss: 5.093, Residuals: 0.127
# Loss: 4.053, Residuals: 0.088
# Loss: 3.248, Residuals: 0.055
# Loss: 2.696, Residuals: 0.006
# Loss: 2.485, Residuals: 0.005
# Loss: 2.229, Residuals: -0.008
# Loss: 2.225, Residuals: -0.013
# Loss: 2.192, Residuals: -0.015
# Loss: 2.135, Residuals: -0.017
# Loss: 2.128, Residuals: -0.001
# Loss: 2.115, Residuals: -0.005
# Loss: 2.091, Residuals: -0.012
# Loss: 2.053, Residuals: -0.022
# Loss: 2.052, Residuals: -0.015
# Loss: 2.050, Residuals: -0.014
# Loss: 2.048, Residuals: -0.013
# Loss: 2.025, Residuals: -0.019
# Loss: 2.020, Residuals: -0.011
# Loss: 2.010, Residuals: -0.015
# Loss: 1.994, Residuals: -0.022
# Loss: 1.993, Residuals: -0.017
# Loss: 1.991, Residuals: -0.018
# Loss: 1.990, Residuals: -0.017
# Loss: 1.988, Residuals: -0.018
# Loss: 1.983, Residuals: -0.022
# Loss: 1.983, Residuals: -0.022
# Optimization terminated successfully.
# Evidence -40.116
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 8.19e-01
# Loss: 25.308, Residuals: 0.016
# Loss: 24.894, Residuals: -0.005
# Loss: 24.291, Residuals: -0.003
# Loss: 23.273, Residuals: 0.014
# Loss: 22.412, Residuals: 0.043
# Loss: 22.343, Residuals: 0.029
# Loss: 22.292, Residuals: 0.024
# Loss: 22.238, Residuals: 0.022
# Loss: 22.233, Residuals: 0.023
# Loss: 22.228, Residuals: 0.024
# Loss: 22.225, Residuals: 0.024
# Loss: 22.225, Residuals: 0.024
# Loss: 22.224, Residuals: 0.024
# Optimization terminated successfully.
# Evidence 264.980
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.79e+00
# Loss: 66.049, Residuals: 0.022
# Loss: 65.717, Residuals: 0.022
# Loss: 65.366, Residuals: 0.023
# Loss: 65.342, Residuals: 0.027
# Loss: 65.311, Residuals: 0.027
# Loss: 65.266, Residuals: 0.027
# Loss: 65.261, Residuals: 0.027
# Optimization terminated successfully.
# Evidence 415.817
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.48e+00
# Loss: 110.977, Residuals: 0.023
# Loss: 110.313, Residuals: 0.020
# Loss: 110.169, Residuals: 0.022
# Loss: 110.095, Residuals: 0.023
# Loss: 109.971, Residuals: 0.023
# Loss: 109.841, Residuals: 0.022
# Loss: 109.831, Residuals: 0.022
# Loss: 109.820, Residuals: 0.022
# Loss: 109.819, Residuals: 0.022
# Optimization terminated successfully.
# Evidence 474.756
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.50e+00
# Loss: 134.964, Residuals: 0.016
# Loss: 134.464, Residuals: 0.014
# Loss: 134.397, Residuals: 0.016
# Loss: 134.307, Residuals: 0.016
# Loss: 134.297, Residuals: 0.016
# Loss: 134.282, Residuals: 0.016
# Loss: 134.275, Residuals: 0.016
# Loss: 134.274, Residuals: 0.016
# Optimization terminated successfully.
# Evidence 492.306
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.37e+00
# Loss: 144.558, Residuals: 0.014
# Loss: 144.309, Residuals: 0.012
# Loss: 144.276, Residuals: 0.013
# Loss: 144.226, Residuals: 0.013
# Loss: 144.198, Residuals: 0.012
# Loss: 144.196, Residuals: 0.012
# Optimization terminated successfully.
# Evidence 497.390
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.29e+00
# Loss: 147.980, Residuals: 0.013
# Loss: 147.892, Residuals: 0.012
# Loss: 147.880, Residuals: 0.011
# Optimization terminated successfully.
# Evidence 499.117
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.29e+00
# Loss: 149.319, Residuals: 0.010
# Loss: 149.249, Residuals: 0.010
# Loss: 149.241, Residuals: 0.010
# Loss: 149.231, Residuals: 0.010
# Loss: 149.230, Residuals: 0.010
# Optimization terminated successfully.
# Evidence 499.961
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.25e+00
# Loss: 149.860, Residuals: 0.010
# Loss: 149.823, Residuals: 0.010
# Loss: 149.817, Residuals: 0.010
# Loss: 149.808, Residuals: 0.010
# Loss: 149.808, Residuals: 0.010
# Optimization terminated successfully.
# Evidence 500.502
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 2.22e+00
# Loss: 150.169, Residuals: 0.009
# Loss: 150.147, Residuals: 0.010
# Loss: 150.133, Residuals: 0.009
# Loss: 150.133, Residuals: 0.010
# Optimization terminated successfully.
# Evidence 500.882
# Pass count  1
# Total samples: 38, Initial regularization: 1.00e-03
# Loss: 8.534, Residuals: -0.361
# Loss: 5.497, Residuals: 0.186
# Loss: 4.583, Residuals: 0.143
# Loss: 4.162, Residuals: 0.112
# Loss: 3.636, Residuals: 0.041
# Loss: 3.525, Residuals: 0.011
# Loss: 3.323, Residuals: 0.001
# Loss: 3.002, Residuals: 0.001
# Loss: 2.750, Residuals: 0.009
# Loss: 2.673, Residuals: 0.025
# Loss: 2.548, Residuals: 0.006
# Loss: 2.514, Residuals: 0.011
# Loss: 2.457, Residuals: -0.003
# Loss: 2.384, Residuals: -0.027
# Loss: 2.373, Residuals: -0.019
# Loss: 2.358, Residuals: -0.023
# Loss: 2.334, Residuals: -0.028
# Loss: 2.333, Residuals: -0.022
# Loss: 2.320, Residuals: -0.026
# Loss: 2.297, Residuals: -0.032
# Loss: 2.290, Residuals: -0.024
# Loss: 2.289, Residuals: -0.020
# Loss: 2.263, Residuals: -0.028
# Loss: 2.257, Residuals: -0.021
# Loss: 2.257, Residuals: -0.022
# Loss: 2.238, Residuals: -0.029
# Loss: 2.237, Residuals: -0.025
# Loss: 2.226, Residuals: -0.027
# Loss: 2.226, Residuals: -0.028
# Loss: 2.210, Residuals: -0.027
# Loss: 2.210, Residuals: -0.027
# Loss: 2.208, Residuals: -0.025
# Loss: 2.192, Residuals: -0.024
# Loss: 2.191, Residuals: -0.025
# Loss: 2.189, Residuals: -0.023
# Loss: 2.173, Residuals: -0.026
# Loss: 2.173, Residuals: -0.026
# Loss: 2.171, Residuals: -0.024
# Loss: 2.161, Residuals: -0.025
# Loss: 2.161, Residuals: -0.026
# Loss: 2.160, Residuals: -0.025
# Loss: 2.153, Residuals: -0.026
# Loss: 2.153, Residuals: -0.026
# Optimization terminated successfully.
# Evidence -43.693
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 6.19e-01
# Loss: 29.853, Residuals: -0.076
# Loss: 26.828, Residuals: -0.029
# Loss: 26.758, Residuals: -0.022
# Optimization terminated successfully.
# Evidence 266.779
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 6.60e-01
# Loss: 69.302, Residuals: -0.017
# Optimization terminated successfully.
# Evidence 410.525
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 8.40e-01
# Loss: 116.084, Residuals: -0.007
# Loss: 114.000, Residuals: -0.011
# Loss: 112.186, Residuals: -0.010
# Loss: 112.154, Residuals: -0.012
# Optimization terminated successfully.
# Evidence 459.066
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 9.65e-01
# Loss: 137.555, Residuals: -0.002
# Loss: 137.531, Residuals: -0.003
# Optimization terminated successfully.
# Evidence 472.133
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.01e+00
# Loss: 144.616, Residuals: -0.002
# Loss: 144.483, Residuals: 0.003
# Loss: 143.242, Residuals: 0.002
# Loss: 141.096, Residuals: 0.004
# Loss: 139.586, Residuals: 0.003
# Loss: 139.487, Residuals: 0.003
# Loss: 139.379, Residuals: 0.005
# Loss: 139.201, Residuals: 0.006
# Loss: 139.193, Residuals: 0.006
# Optimization terminated successfully.
# Evidence 479.349
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.27e+00
# Loss: 146.077, Residuals: 0.010
# Optimization terminated successfully.
# Evidence 484.438
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.29e+00
# Loss: 148.442, Residuals: 0.008
# Loss: 148.034, Residuals: 0.010
# Loss: 147.993, Residuals: 0.009
# Loss: 147.651, Residuals: 0.011
# Loss: 147.641, Residuals: 0.011
# Optimization terminated successfully.
# Evidence 486.618
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.37e+00
# Loss: 148.940, Residuals: 0.016
# Loss: 148.838, Residuals: 0.011
# Loss: 148.655, Residuals: 0.012
# Loss: 148.394, Residuals: 0.014
# Loss: 148.391, Residuals: 0.015
# Optimization terminated successfully.
# Evidence 488.530
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.42e+00
# Loss: 149.293, Residuals: 0.016
# Loss: 149.205, Residuals: 0.014
# Loss: 149.073, Residuals: 0.016
# Loss: 149.071, Residuals: 0.017
# Optimization terminated successfully.
# Evidence 489.540
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.43e+00
# Loss: 149.701, Residuals: 0.017
# Loss: 149.642, Residuals: 0.015
# Loss: 149.637, Residuals: 0.016
# Optimization terminated successfully.
# Evidence 490.148
# Updating hyper-parameters...
# Total samples: 38, Updated regularization: 1.44e+00
# Loss: 149.991, Residuals: 0.016
# Loss: 149.982, Residuals: 0.015
# Optimization terminated successfully.
# Evidence 490.509
# Pass count  1
